# %%
# Added cell to set Working Directory to your location
import os
import ast
import glob
import numpy as np
import pandas as pd
import json
import time

# %%
os.chdir("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Exploration_short/")

# %%
# Columns to keep from the raw data.
Keep = ["SubjectID", "Session", "SessionSubsection",'timeStampDataPointStart', 'timeStampDataPointEnd', 'timeStampGetVerboseData','pupilDiameterMillimetersLeft', 'pupilDiameterMillimetersRight','combinedGazeValidityBitmask','rayCastHitsCombinedEyes','eyePositionCombinedWorld.x', 'eyePositionCombinedWorld.y', 'eyePositionCombinedWorld.z','eyeDirectionCombinedWorld.y', 
 'eyeDirectionCombinedWorld.z', 'eyeDirectionCombinedLocal.x', 'eyeDirectionCombinedLocal.y', 'eyeDirectionCombinedLocal.z','hmdPosition.x', 'hmdPosition.y', 'hmdPosition.z', 'hmdDirectionForward.x', 'hmdDirectionForward.y', 'hmdDirectionForward.z', 
 'hmdRotation.x', 'hmdRotation.y', 'hmdRotation.z', 'hmdDirectionUp.x', 'hmdDirectionUp.y', 'hmdDirectionUp.z','playerBodyPosition.x', 'playerBodyPosition.y', 'playerBodyPosition.z', 'bodyTrackerPosition.x', 'bodyTrackerPosition.y', 
 'bodyTrackerPosition.z', 'bodyTrackerRotation.x', 'bodyTrackerRotation.y', 'bodyTrackerRotation.z']

# %%
data_path = os.getcwd()

# Getting the Folder without hidden files in ascending order
DATA_FOLDER = sorted([f for f in os.listdir(data_path) if not f.startswith('.')], key=str.lower)
subIDs = []
for sub in DATA_FOLDER:
    if sub[0:4].isdigit():
        subIDs.append(int(sub[0:4]))
    else:
        pass
subIDs = np.unique(subIDs)
#Sincesome participant IDs start with 0, we format them to show it in the string type
IDstrings = ['{:04d}'.format(id) for id in subIDs]
print(IDstrings)
# Out:
# ['0365', '0479', '1754', '2258', '2361', '2693', '3246', '3310', '3572', '3976', '4176', '4597', '4796', '4917', '5238', '5531', '5741', '6642', '7093', '7264', '7412', '7842', '8007', '8469', '8673', '8695', '9472', '9502', '9586', '9601']

# %%
#Create a generalized path for all json files per participant
paths = [ID +  "/*.json" for ID in IDstrings]
print(paths)
#Create a sorted list of the paths to open de jsons
Sorted_individual_jsons = sorted([filename for path in paths for filename in glob.glob(path)], key=str.lower)
# Out:
# ['0365/*.json', '0479/*.json', '1754/*.json', '2258/*.json', '2361/*.json', '2693/*.json', '3246/*.json', '3310/*.json', '3572/*.json', '3976/*.json', '4176/*.json', '4597/*.json', '4796/*.json', '4917/*.json', '5238/*.json', '5531/*.json', '5741/*.json', '6642/*.json', '7093/*.json', '7264/*.json', '7412/*.json', '7842/*.json', '8007/*.json', '8469/*.json', '8673/*.json', '8695/*.json', '9472/*.json', '9502/*.json', '9586/*.json', '9601/*.json']

# %%
filename = "/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Exploration_short/0365/0365_Expl_S_01_ET_1_1635519946.47664.json"

with open(filename, 'r') as file:
    try:
        # make json files parsable
        data = "[" + file.read()
        data = data[:len(data)] + "]"
        raw = json.loads(data)
    except:
        print("reading did not work")
    # Uneast the higher level of each file
    currentDF_raw = pd.json_normalize(raw[0]['trials'][0]['dataPoints'])
    print( "Subject " + str(filename[5:9]) + " Session " + str(filename[17:19]) +" Section " + str(filename[23:24]) + " has been normalized")
# Out:
# Subject mes/ Session /0 Section e has been normalized

# %%
currentDF_raw.columns
# Out:
# Index(['timeStampDataPointStart', 'timeStampDataPointEnd',
#        'timeStampGetVerboseData', 'eyeOpennessLeft', 'eyeOpennessRight',
#        'pupilDiameterMillimetersLeft', 'pupilDiameterMillimetersRight',
#        'leftGazeValidityBitmask', 'rightGazeValidityBitmask',
#        'combinedGazeValidityBitmask', 'rayCastHitsCombinedEyes',
#        'rayCastHitsLeftEye', 'rayCastHitsRightEye',
#        'eyePositionCombinedWorld.x', 'eyePositionCombinedWorld.y',
#        'eyePositionCombinedWorld.z', 'eyeDirectionCombinedWorld.x',
#        'eyeDirectionCombinedWorld.y', 'eyeDirectionCombinedWorld.z',
#        'eyeDirectionCombinedLocal.x', 'eyeDirectionCombinedLocal.y',
#        'eyeDirectionCombinedLocal.z', 'eyePositionLeftWorld.x',
#        'eyePositionLeftWorld.y', 'eyePositionLeftWorld.z',
#        'eyeDirectionLeftWorld.x', 'eyeDirectionLeftWorld.y',
#        'eyeDirectionLeftWorld.z', 'eyeDirectionLeftLocal.x',
#        'eyeDirectionLeftLocal.y', 'eyeDirectionLeftLocal.z',
#        'eyePositionRightWorld.x', 'eyePositionRightWorld.y',
#        'eyePositionRightWorld.z', 'eyeDirectionRightWorld.x',
#        'eyeDirectionRightWorld.y', 'eyeDirectionRightWorld.z',
#        'eyeDirectionRightLocal.x', 'eyeDirectionRightLocal.y',
#        'eyeDirectionRightLocal.z', 'hmdPosition.x', 'hmdPosition.y',
#        'hmdPosition.z', 'hmdDirectionForward.x', 'hmdDirectionForward.y',
#        'hmdDirectionForward.z', 'hmdDirectionRight.x', 'hmdDirectionRight.y',
#        'hmdDirectionRight.z', 'hmdRotation.x', 'hmdRotation.y',
#        'hmdRotation.z', 'hmdDirectionUp.x', 'hmdDirectionUp.y',
#        'hmdDirectionUp.z', 'handLeftPosition.x', 'handLeftPosition.y',
#        'handLeftPosition.z', 'handLeftRotation.x', 'handLeftRotation.y',
#        'handLeftRotation.z', 'handLeftScale.x', 'handLeftScale.y',
#        'handLeftScale.z', 'handLeftDirectionForward.x',
#        'handLeftDirectionForward.y', 'handLeftDirectionForward.z',
#        'handLeftDirectionRight.x', 'handLeftDirectionRight.y',
#        'handLeftDirectionRight.z', 'handLeftDirectionUp.x',
#        'handLeftDirectionUp.y', 'handLeftDirectionUp.z', 'handRightPosition.x',
#        'handRightPosition.y', 'handRightPosition.z', 'handRightRotation.x',
#        'handRightRotation.y', 'handRightRotation.z', 'handRightScale.x',
#        'handRightScale.y', 'handRightScale.z', 'handRightDirectionForward.x',
#        'handRightDirectionForward.y', 'handRightDirectionForward.z',
#        'handRightDirectionRight.x', 'handRightDirectionRight.y',
#        'handRightDirectionRight.z', 'handRightDirectionUp.x',
#        'handRightDirectionUp.y', 'handRightDirectionUp.z',
#        'playerBodyPosition.x', 'playerBodyPosition.y', 'playerBodyPosition.z',
#        'bodyTrackerPosition.x', 'bodyTrackerPosition.y',
#        'bodyTrackerPosition.z', 'bodyTrackerRotation.x',
#        'bodyTrackerRotation.y', 'bodyTrackerRotation.z'],
#       dtype='object')

# %%
data_raw = pd.DataFrame()

# read every file name in folder
for path in paths:
    for filename in glob.glob(path):
        with open(filename, 'r') as file:
            try:
                # make json files parsable
                data = "[" + file.read()
                data = data[:len(data)] + "]"
                raw = json.loads(data)
            except:
                print("reading did not work")
                

            # Uneast the higher level of each file
            currentDF_raw = pd.json_normalize(raw[0]['trials'][0]['dataPoints'])
            print( "Subject " + str(filename[5:9]) + " Session " + str(filename[17:19]) +" Section " + str(filename[23:24]) + " has been normalized")
            #Reduce columns to just necessary information
            print('time is: ', time.ctime())

            # insert participant id and session information from the file name
            currentDF_raw.insert(0, "SubjectID", [int(filename[5:9])] * currentDF_raw.shape[0], True)
            currentDF_raw.insert(1, "Session", [int(filename[17:19])] * currentDF_raw.shape[0], True)
            currentDF_raw.insert(2, "SessionSubsection", [int(filename[23:24])] * currentDF_raw.shape[0], True)
            
            #Take out the unnecesary information
            Reduced= currentDF_raw[Keep] # For PCA I'm keeping everything now, in old versions I had the reduced version 

            #Normalize the collider hits
            Raycast = currentDF_raw['rayCastHitsCombinedEyes'].explode().apply(pd.Series)
            Combined = pd.concat([currentDF_raw, Raycast], axis=1)
            print('Combined')

        data_raw = pd.concat([data_raw, Combined], ignore_index=True)
        print('Appended')
        currentDF_raw = pd.DataFrame()
    data_raw.sort_values(by=["SubjectID","Session","SessionSubsection"], inplace=True)
    data_raw.to_csv("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/" + str(filename[5:9]) + ".csv", index=False)
    print('Saved')
    data_raw = pd.DataFrame()
# Out:
# Subject 0365 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:12:39 2025
# Combined
# Appended
# Subject 0365 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:12:52 2025
# Combined
# Appended
# Subject 0365 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:13:05 2025
# Combined
# Appended
# Subject 0365 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:13:19 2025
# Combined
# Appended
# Subject 0365 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:13:33 2025
# Combined
# Appended
# Subject 0365 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:13:47 2025
# Combined
# Appended
# Subject 0365 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:14:02 2025
# Combined
# Appended
# Subject 0365 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:14:16 2025
# Combined
# Appended
# Subject 0365 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:14:31 2025
# Combined
# Appended
# Subject 0365 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:14:49 2025
# Combined
# Appended
# Subject 0365 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 13:15:05 2025
# Combined
# Appended
# Subject 0365 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:15:19 2025
# Combined
# Appended
# Subject 0365 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:15:37 2025
# Combined
# Appended
# Subject 0365 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:15:53 2025
# Combined
# Appended
# Subject 0365 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:16:10 2025
# Combined
# Appended
# Saved
# Subject 0479 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:17:58 2025
# Combined
# Appended
# Subject 0479 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:18:10 2025
# Combined
# Appended
# Subject 0479 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:18:23 2025
# Combined
# Appended
# Subject 0479 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:18:37 2025
# Combined
# Appended
# Subject 0479 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:18:51 2025
# Combined
# Appended
# Subject 0479 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:19:07 2025
# Combined
# Appended
# Subject 0479 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:19:23 2025
# Combined
# Appended
# Subject 0479 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:19:39 2025
# Combined
# Appended
# Subject 0479 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:19:57 2025
# Combined
# Appended
# reading did not work
# Subject 0479 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:20:11 2025
# Combined
# Appended
# Subject 0479 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:20:25 2025
# Combined
# Appended
# reading did not work
# Subject 0479 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:20:37 2025
# Combined
# Appended
# Subject 0479 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:20:50 2025
# Combined
# Appended
# Subject 0479 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:21:08 2025
# Combined
# Appended
# Subject 0479 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:21:23 2025
# Combined
# Appended
# Saved
# Subject 1754 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:23:08 2025
# Combined
# Appended
# Subject 1754 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:23:22 2025
# Combined
# Appended
# Subject 1754 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:23:35 2025
# Combined
# Appended
# Subject 1754 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:23:50 2025
# Combined
# Appended
# Subject 1754 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:24:04 2025
# Combined
# Appended
# Subject 1754 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:30:32 2025
# Combined
# Appended
# Subject 1754 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:30:49 2025
# Combined
# Appended
# Subject 1754 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:31:05 2025
# Combined
# Appended
# Subject 1754 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:31:24 2025
# Combined
# Appended
# Subject 1754 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:32:25 2025
# Combined
# Appended
# Subject 1754 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:32:43 2025
# Combined
# Appended
# Subject 1754 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 13:33:00 2025
# Combined
# Appended
# Subject 1754 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:33:21 2025
# Combined
# Appended
# Subject 1754 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:33:49 2025
# Combined
# Appended
# Subject 1754 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:34:06 2025
# Combined
# Appended
# Saved
# Subject 2258 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:36:42 2025
# Combined
# Appended
# Subject 2258 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:36:55 2025
# Combined
# Appended
# Subject 2258 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:37:09 2025
# Combined
# Appended
# Subject 2258 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:37:24 2025
# Combined
# Appended
# Subject 2258 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:37:38 2025
# Combined
# Appended
# Subject 2258 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:37:53 2025
# Combined
# Appended
# Subject 2258 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:38:09 2025
# Combined
# Appended
# Subject 2258 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:38:24 2025
# Combined
# Appended
# Subject 2258 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:38:41 2025
# Combined
# Appended
# Subject 2258 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:38:58 2025
# Combined
# Appended
# Subject 2258 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:39:15 2025
# Combined
# Appended
# Subject 2258 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 13:39:30 2025
# Combined
# Appended
# Subject 2258 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:39:48 2025
# Combined
# Appended
# Subject 2258 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:40:05 2025
# Combined
# Appended
# Subject 2258 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:40:23 2025
# Combined
# Appended
# Saved
# reading did not work
# Subject 2361 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:42:16 2025
# Combined
# Appended
# reading did not work
# Subject 2361 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:42:27 2025
# Combined
# Appended
# reading did not work
# Subject 2361 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 13:42:39 2025
# Combined
# Appended
# reading did not work
# Subject 2361 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:42:51 2025
# Combined
# Appended
# Subject 2361 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:43:05 2025
# Combined
# Appended
# Subject 2361 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:43:19 2025
# Combined
# Appended
# Subject 2361 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:43:34 2025
# Combined
# Appended
# Subject 2361 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:43:50 2025
# Combined
# Appended
# Subject 2361 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:44:05 2025
# Combined
# Appended
# Subject 2361 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:44:21 2025
# Combined
# Appended
# Subject 2361 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:44:38 2025
# Combined
# Appended
# Subject 2361 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 13:44:54 2025
# Combined
# Appended
# Subject 2361 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:45:11 2025
# Combined
# Appended
# Subject 2361 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:45:29 2025
# Combined
# Appended
# Subject 2361 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:45:45 2025
# Combined
# Appended
# Saved
# Subject 2693 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:47:39 2025
# Combined
# Appended
# Subject 2693 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 13:47:50 2025
# Combined
# Appended
# Subject 2693 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:48:04 2025
# Combined
# Appended
# Subject 2693 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:48:18 2025
# Combined
# Appended
# Subject 2693 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:48:32 2025
# Combined
# Appended
# Subject 2693 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:48:46 2025
# Combined
# Appended
# Subject 2693 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:49:01 2025
# Combined
# Appended
# Subject 2693 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:49:15 2025
# Combined
# Appended
# Subject 2693 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:49:30 2025
# Combined
# Appended
# Subject 2693 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:49:45 2025
# Combined
# Appended
# Subject 2693 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:50:01 2025
# Combined
# Appended
# Subject 2693 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 13:50:16 2025
# Combined
# Appended
# Subject 2693 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:50:33 2025
# Combined
# Appended
# Subject 2693 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:50:49 2025
# Combined
# Appended
# Subject 2693 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 13:51:05 2025
# Combined
# Appended
# Saved
# Subject 3246 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:52:48 2025
# Combined
# Appended
# Subject 3246 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:53:01 2025
# Combined
# Appended
# Subject 3246 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:53:14 2025
# Combined
# Appended
# Subject 3246 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:53:28 2025
# Combined
# Appended
# Subject 3246 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:53:43 2025
# Combined
# Appended
# Subject 3246 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:53:59 2025
# Combined
# Appended
# Subject 3246 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:54:15 2025
# Combined
# Appended
# Subject 3246 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:54:30 2025
# Combined
# Appended
# reading did not work
# Subject 3246 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:54:46 2025
# Combined
# Appended
# reading did not work
# Subject 3246 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 13:55:00 2025
# Combined
# Appended
# reading did not work
# Subject 3246 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 13:55:15 2025
# Combined
# Appended
# Subject 3246 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:55:33 2025
# Combined
# Appended
# Subject 3246 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 13:55:49 2025
# Combined
# Appended
# reading did not work
# Subject 3246 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 13:56:03 2025
# Combined
# Appended
# Saved
# Subject 3310 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 13:57:50 2025
# Combined
# Appended
# Subject 3310 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 13:58:02 2025
# Combined
# Appended
# Subject 3310 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 13:58:16 2025
# Combined
# Appended
# Subject 3310 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 13:58:30 2025
# Combined
# Appended
# Subject 3310 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 13:58:44 2025
# Combined
# Appended
# Subject 3310 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 13:58:59 2025
# Combined
# Appended
# Subject 3310 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 13:59:14 2025
# Combined
# Appended
# Subject 3310 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 13:59:30 2025
# Combined
# Appended
# Subject 3310 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 13:59:46 2025
# Combined
# Appended
# Subject 3310 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:00:00 2025
# Combined
# Appended
# Subject 3310 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:00:08 2025
# Combined
# Appended
# Subject 3310 Session 04 Section 4 has been normalized
# time is:  Tue Jun 10 14:00:20 2025
# Combined
# Appended
# Subject 3310 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:00:35 2025
# Combined
# Appended
# Subject 3310 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:00:53 2025
# Combined
# Appended
# Subject 3310 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:01:09 2025
# Combined
# Appended
# Subject 3310 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:01:26 2025
# Combined
# Appended
# Saved
# Subject 3572 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:03:12 2025
# Combined
# Appended
# Subject 3572 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:03:24 2025
# Combined
# Appended
# Subject 3572 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:03:38 2025
# Combined
# Appended
# Subject 3572 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:03:53 2025
# Combined
# Appended
# Subject 3572 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:04:08 2025
# Combined
# Appended
# Subject 3572 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:04:23 2025
# Combined
# Appended
# Subject 3572 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:04:39 2025
# Combined
# Appended
# Subject 3572 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:04:54 2025
# Combined
# Appended
# Subject 3572 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:05:11 2025
# Combined
# Appended
# Subject 3572 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:05:28 2025
# Combined
# Appended
# Subject 3572 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:05:45 2025
# Combined
# Appended
# Subject 3572 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:06:01 2025
# Combined
# Appended
# Saved
# Subject 3976 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:07:33 2025
# Combined
# Appended
# Subject 3976 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:07:37 2025
# Combined
# Appended
# Subject 3976 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:07:48 2025
# Combined
# Appended
# reading did not work
# Subject 3976 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 14:07:59 2025
# Combined
# Appended
# Subject 3976 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:08:12 2025
# Combined
# Appended
# Subject 3976 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:08:26 2025
# Combined
# Appended
# Subject 3976 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:08:40 2025
# Combined
# Appended
# reading did not work
# Subject 3976 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:08:53 2025
# Combined
# Appended
# Subject 3976 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:09:08 2025
# Combined
# Appended
# reading did not work
# Subject 3976 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:09:21 2025
# Combined
# Appended
# Subject 3976 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:09:36 2025
# Combined
# Appended
# Subject 3976 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:09:50 2025
# Combined
# Appended
# Subject 3976 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:10:07 2025
# Combined
# Appended
# Subject 3976 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:10:23 2025
# Combined
# Appended
# Subject 3976 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:10:39 2025
# Combined
# Appended
# Saved
# Subject 4176 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:12:22 2025
# Combined
# Appended
# Subject 4176 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:12:36 2025
# Combined
# Appended
# Subject 4176 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:12:50 2025
# Combined
# Appended
# Subject 4176 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:13:04 2025
# Combined
# Appended
# Subject 4176 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:13:20 2025
# Combined
# Appended
# Subject 4176 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:13:35 2025
# Combined
# Appended
# Subject 4176 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:13:52 2025
# Combined
# Appended
# Subject 4176 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:14:09 2025
# Combined
# Appended
# Subject 4176 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:14:25 2025
# Combined
# Appended
# Subject 4176 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:14:41 2025
# Combined
# Appended
# Subject 4176 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:14:57 2025
# Combined
# Appended
# Subject 4176 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:15:15 2025
# Combined
# Appended
# Subject 4176 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:15:34 2025
# Combined
# Appended
# Subject 4176 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:15:51 2025
# Combined
# Appended
# Subject 4176 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:16:09 2025
# Combined
# Appended
# Saved
# Subject 4597 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:18:05 2025
# Combined
# Appended
# Subject 4597 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:18:18 2025
# Combined
# Appended
# Subject 4597 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:18:32 2025
# Combined
# Appended
# Subject 4597 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:18:46 2025
# Combined
# Appended
# Subject 4597 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:19:01 2025
# Combined
# Appended
# Subject 4597 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:19:16 2025
# Combined
# Appended
# Subject 4597 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:19:32 2025
# Combined
# Appended
# Subject 4597 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:19:49 2025
# Combined
# Appended
# Subject 4597 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:20:05 2025
# Combined
# Appended
# Subject 4597 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:20:21 2025
# Combined
# Appended
# Subject 4597 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:20:38 2025
# Combined
# Appended
# Subject 4597 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:20:54 2025
# Combined
# Appended
# Subject 4597 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:21:12 2025
# Combined
# Appended
# Subject 4597 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:21:29 2025
# Combined
# Appended
# Subject 4597 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:21:47 2025
# Combined
# Appended
# Saved
# Subject 4796 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:23:40 2025
# Combined
# Appended
# Subject 4796 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:23:53 2025
# Combined
# Appended
# Subject 4796 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:24:07 2025
# Combined
# Appended
# Subject 4796 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:24:20 2025
# Combined
# Appended
# Subject 4796 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:24:34 2025
# Combined
# Appended
# Subject 4796 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:24:49 2025
# Combined
# Appended
# Subject 4796 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:25:04 2025
# Combined
# Appended
# Subject 4796 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:25:19 2025
# Combined
# Appended
# Subject 4796 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:25:36 2025
# Combined
# Appended
# Subject 4796 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:25:53 2025
# Combined
# Appended
# Subject 4796 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:26:10 2025
# Combined
# Appended
# Subject 4796 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:26:26 2025
# Combined
# Appended
# Subject 4796 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:26:44 2025
# Combined
# Appended
# Subject 4796 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:27:00 2025
# Combined
# Appended
# Subject 4796 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:27:18 2025
# Combined
# Appended
# Saved
# Subject 4917 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:29:08 2025
# Combined
# Appended
# Subject 4917 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:29:22 2025
# Combined
# Appended
# Subject 4917 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:29:36 2025
# Combined
# Appended
# Subject 4917 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:29:51 2025
# Combined
# Appended
# Subject 4917 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:30:06 2025
# Combined
# Appended
# Subject 4917 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:30:20 2025
# Combined
# Appended
# Subject 4917 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:30:36 2025
# Combined
# Appended
# Subject 4917 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:30:51 2025
# Combined
# Appended
# Subject 4917 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:31:07 2025
# Combined
# Appended
# Subject 4917 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:31:23 2025
# Combined
# Appended
# Subject 4917 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:31:41 2025
# Combined
# Appended
# Subject 4917 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:31:59 2025
# Combined
# Appended
# Subject 4917 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:32:15 2025
# Combined
# Appended
# Subject 4917 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:32:32 2025
# Combined
# Appended
# Subject 4917 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:32:53 2025
# Combined
# Appended
# Saved
# Subject 5238 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:34:47 2025
# Combined
# Appended
# Subject 5238 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:34:59 2025
# Combined
# Appended
# Subject 5238 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:35:13 2025
# Combined
# Appended
# Subject 5238 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:35:28 2025
# Combined
# Appended
# Subject 5238 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:35:43 2025
# Combined
# Appended
# Subject 5238 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:35:58 2025
# Combined
# Appended
# Subject 5238 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:36:14 2025
# Combined
# Appended
# Subject 5238 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:36:29 2025
# Combined
# Appended
# Subject 5238 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:36:46 2025
# Combined
# Appended
# Subject 5238 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:37:03 2025
# Combined
# Appended
# Subject 5238 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:37:20 2025
# Combined
# Appended
# Subject 5238 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:37:37 2025
# Combined
# Appended
# Saved
# Subject 5531 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:39:14 2025
# Combined
# Appended
# Subject 5531 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:39:26 2025
# Combined
# Appended
# reading did not work
# Subject 5531 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:39:39 2025
# Combined
# Appended
# reading did not work
# Subject 5531 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:39:51 2025
# Combined
# Appended
# reading did not work
# Subject 5531 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:40:03 2025
# Combined
# Appended
# Subject 5531 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:40:17 2025
# Combined
# Appended
# Subject 5531 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:40:31 2025
# Combined
# Appended
# Subject 5531 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:40:46 2025
# Combined
# Appended
# Subject 5531 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:41:01 2025
# Combined
# Appended
# Subject 5531 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:41:17 2025
# Combined
# Appended
# Subject 5531 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:41:34 2025
# Combined
# Appended
# Subject 5531 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:41:50 2025
# Combined
# Appended
# Subject 5531 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:42:07 2025
# Combined
# Appended
# Subject 5531 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:42:25 2025
# Combined
# Appended
# Saved
# Subject 5741 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:44:08 2025
# Combined
# Appended
# Subject 5741 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:44:21 2025
# Combined
# Appended
# Subject 5741 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:44:35 2025
# Combined
# Appended
# Subject 5741 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:44:50 2025
# Combined
# Appended
# Subject 5741 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:45:05 2025
# Combined
# Appended
# Subject 5741 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:45:19 2025
# Combined
# Appended
# Subject 5741 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:45:35 2025
# Combined
# Appended
# Subject 5741 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:45:50 2025
# Combined
# Appended
# Subject 5741 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:46:08 2025
# Combined
# Appended
# Subject 5741 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:46:20 2025
# Combined
# Appended
# Subject 5741 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:46:30 2025
# Combined
# Appended
# Subject 5741 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:46:41 2025
# Combined
# Appended
# Subject 5741 Session 04 Section 4 has been normalized
# time is:  Tue Jun 10 14:46:57 2025
# Combined
# Appended
# Subject 5741 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:47:15 2025
# Combined
# Appended
# Subject 5741 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:47:32 2025
# Combined
# Appended
# Subject 5741 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:47:47 2025
# Combined
# Appended
# Subject 5741 Session 05 Section 4 has been normalized
# time is:  Tue Jun 10 14:47:57 2025
# Combined
# Appended
# Saved
# Subject 6642 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 14:49:43 2025
# Combined
# Appended
# Subject 6642 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:49:54 2025
# Combined
# Appended
# Subject 6642 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 14:50:05 2025
# Combined
# Appended
# Subject 6642 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:50:19 2025
# Combined
# Appended
# Subject 6642 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:50:33 2025
# Combined
# Appended
# Subject 6642 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:50:47 2025
# Combined
# Appended
# Subject 6642 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:51:02 2025
# Combined
# Appended
# Subject 6642 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:51:17 2025
# Combined
# Appended
# Subject 6642 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:51:33 2025
# Combined
# Appended
# Subject 6642 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:51:49 2025
# Combined
# Appended
# Subject 6642 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:52:04 2025
# Combined
# Appended
# Subject 6642 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:52:22 2025
# Combined
# Appended
# Subject 6642 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:52:40 2025
# Combined
# Appended
# Subject 6642 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:52:56 2025
# Combined
# Appended
# Subject 6642 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:53:12 2025
# Combined
# Appended
# Saved
# Subject 7093 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 14:55:03 2025
# Combined
# Appended
# Subject 7093 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 14:55:16 2025
# Combined
# Appended
# Subject 7093 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 14:55:29 2025
# Combined
# Appended
# Subject 7093 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 14:55:44 2025
# Combined
# Appended
# Subject 7093 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 14:55:59 2025
# Combined
# Appended
# Subject 7093 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 14:56:13 2025
# Combined
# Appended
# Subject 7093 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 14:56:29 2025
# Combined
# Appended
# Subject 7093 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 14:56:44 2025
# Combined
# Appended
# Subject 7093 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 14:57:02 2025
# Combined
# Appended
# Subject 7093 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 14:57:18 2025
# Combined
# Appended
# Subject 7093 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 14:57:33 2025
# Combined
# Appended
# Subject 7093 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 14:57:51 2025
# Combined
# Appended
# Subject 7093 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 14:58:07 2025
# Combined
# Appended
# Subject 7093 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 14:58:26 2025
# Combined
# Appended
# Subject 7093 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 14:58:43 2025
# Combined
# Appended
# Saved
# Subject 7264 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:00:36 2025
# Combined
# Appended
# Subject 7264 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:00:47 2025
# Combined
# Appended
# Subject 7264 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:00:57 2025
# Combined
# Appended
# Subject 7264 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 15:01:02 2025
# Combined
# Appended
# Subject 7264 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:01:08 2025
# Combined
# Appended
# Subject 7264 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:01:22 2025
# Combined
# Appended
# Subject 7264 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:01:36 2025
# Combined
# Appended
# Subject 7264 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:01:50 2025
# Combined
# Appended
# Subject 7264 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:02:06 2025
# Combined
# Appended
# Subject 7264 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:02:23 2025
# Combined
# Appended
# Subject 7264 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:02:38 2025
# Combined
# Appended
# Subject 7264 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:02:55 2025
# Combined
# Appended
# Subject 7264 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:03:10 2025
# Combined
# Appended
# Subject 7264 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:03:27 2025
# Combined
# Appended
# Subject 7264 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:03:43 2025
# Combined
# Appended
# Subject 7264 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:04:02 2025
# Combined
# Appended
# Saved
# Subject 7412 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:05:48 2025
# Combined
# Appended
# Subject 7412 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:06:00 2025
# Combined
# Appended
# Subject 7412 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:06:14 2025
# Combined
# Appended
# Subject 7412 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:06:30 2025
# Combined
# Appended
# Subject 7412 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:06:45 2025
# Combined
# Appended
# Subject 7412 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:07:00 2025
# Combined
# Appended
# Subject 7412 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:07:16 2025
# Combined
# Appended
# Subject 7412 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:07:31 2025
# Combined
# Appended
# Subject 7412 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:07:46 2025
# Combined
# Appended
# Subject 7412 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:08:03 2025
# Combined
# Appended
# Subject 7412 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:08:21 2025
# Combined
# Appended
# Subject 7412 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:08:39 2025
# Combined
# Appended
# Subject 7412 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:08:58 2025
# Combined
# Appended
# Subject 7412 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:09:15 2025
# Combined
# Appended
# Subject 7412 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:09:32 2025
# Combined
# Appended
# Saved
# Subject 7842 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:11:27 2025
# Combined
# Appended
# Subject 7842 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:11:40 2025
# Combined
# Appended
# Subject 7842 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:11:54 2025
# Combined
# Appended
# Subject 7842 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:12:09 2025
# Combined
# Appended
# Subject 7842 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:12:24 2025
# Combined
# Appended
# Subject 7842 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:12:39 2025
# Combined
# Appended
# Subject 7842 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:12:54 2025
# Combined
# Appended
# Subject 7842 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:13:09 2025
# Combined
# Appended
# Subject 7842 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:13:26 2025
# Combined
# Appended
# Subject 7842 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:13:42 2025
# Combined
# Appended
# Subject 7842 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:13:57 2025
# Combined
# Appended
# Subject 7842 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:14:15 2025
# Combined
# Appended
# Subject 7842 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:14:33 2025
# Combined
# Appended
# Subject 7842 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:14:49 2025
# Combined
# Appended
# Subject 7842 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:15:06 2025
# Combined
# Appended
# Saved
# Subject 8007 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:16:56 2025
# Combined
# Appended
# Subject 8007 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:17:09 2025
# Combined
# Appended
# Subject 8007 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:17:22 2025
# Combined
# Appended
# Subject 8007 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:17:38 2025
# Combined
# Appended
# Subject 8007 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:17:53 2025
# Combined
# Appended
# Subject 8007 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:18:07 2025
# Combined
# Appended
# Subject 8007 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:18:22 2025
# Combined
# Appended
# Subject 8007 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:18:37 2025
# Combined
# Appended
# Subject 8007 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:18:55 2025
# Combined
# Appended
# Subject 8007 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:19:11 2025
# Combined
# Appended
# Subject 8007 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:19:28 2025
# Combined
# Appended
# Subject 8007 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:19:43 2025
# Combined
# Appended
# Subject 8007 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:20:02 2025
# Combined
# Appended
# Subject 8007 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:20:19 2025
# Combined
# Appended
# Subject 8007 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:20:36 2025
# Combined
# Appended
# Saved
# Subject 8469 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:22:27 2025
# Combined
# Appended
# Subject 8469 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:22:37 2025
# Combined
# Appended
# Subject 8469 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:22:45 2025
# Combined
# Appended
# Subject 8469 Session 01 Section 4 has been normalized
# time is:  Tue Jun 10 15:22:55 2025
# Combined
# Appended
# Subject 8469 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:23:10 2025
# Combined
# Appended
# Subject 8469 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:23:24 2025
# Combined
# Appended
# Subject 8469 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:23:39 2025
# Combined
# Appended
# Subject 8469 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:23:55 2025
# Combined
# Appended
# Subject 8469 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:24:09 2025
# Combined
# Appended
# Subject 8469 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:24:24 2025
# Combined
# Appended
# Subject 8469 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:24:40 2025
# Combined
# Appended
# Subject 8469 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:24:55 2025
# Combined
# Appended
# Subject 8469 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:25:12 2025
# Combined
# Appended
# Subject 8469 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:25:30 2025
# Combined
# Appended
# Subject 8469 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:25:47 2025
# Combined
# Appended
# Subject 8469 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:26:04 2025
# Combined
# Appended
# Saved
# Subject 8673 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:27:55 2025
# Combined
# Appended
# Subject 8673 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:28:09 2025
# Combined
# Appended
# Subject 8673 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:28:24 2025
# Combined
# Appended
# Subject 8673 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:28:39 2025
# Combined
# Appended
# Subject 8673 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:28:53 2025
# Combined
# Appended
# Subject 8673 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:29:09 2025
# Combined
# Appended
# Subject 8673 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:29:25 2025
# Combined
# Appended
# Subject 8673 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:29:40 2025
# Combined
# Appended
# Subject 8673 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:29:55 2025
# Combined
# Appended
# Subject 8673 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:30:13 2025
# Combined
# Appended
# Subject 8673 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:30:28 2025
# Combined
# Appended
# Subject 8673 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:30:45 2025
# Combined
# Appended
# Subject 8673 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:31:01 2025
# Combined
# Appended
# Subject 8673 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:31:21 2025
# Combined
# Appended
# Subject 8673 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:31:38 2025
# Combined
# Appended
# Saved
# Subject 8695 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:33:27 2025
# Combined
# Appended
# Subject 8695 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:33:40 2025
# Combined
# Appended
# Subject 8695 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:33:54 2025
# Combined
# Appended
# Subject 8695 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:34:09 2025
# Combined
# Appended
# Subject 8695 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:34:24 2025
# Combined
# Appended
# Subject 8695 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:34:39 2025
# Combined
# Appended
# Subject 8695 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:34:55 2025
# Combined
# Appended
# Subject 8695 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:35:11 2025
# Combined
# Appended
# Subject 8695 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:35:29 2025
# Combined
# Appended
# Subject 8695 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:35:46 2025
# Combined
# Appended
# Subject 8695 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:36:03 2025
# Combined
# Appended
# Subject 8695 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:36:20 2025
# Combined
# Appended
# Saved
# Subject 9472 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:37:56 2025
# Combined
# Appended
# Subject 9472 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:38:08 2025
# Combined
# Appended
# Subject 9472 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:38:21 2025
# Combined
# Appended
# Subject 9472 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:38:34 2025
# Combined
# Appended
# Subject 9472 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:38:48 2025
# Combined
# Appended
# Subject 9472 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:39:02 2025
# Combined
# Appended
# Subject 9472 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:39:17 2025
# Combined
# Appended
# Subject 9472 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:39:31 2025
# Combined
# Appended
# Subject 9472 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:39:48 2025
# Combined
# Appended
# Subject 9472 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:40:04 2025
# Combined
# Appended
# Subject 9472 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:40:21 2025
# Combined
# Appended
# Subject 9472 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:40:35 2025
# Combined
# Appended
# Subject 9472 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:40:53 2025
# Combined
# Appended
# Subject 9472 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:41:09 2025
# Combined
# Appended
# Subject 9472 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:41:26 2025
# Combined
# Appended
# Saved
# Subject 9502 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:43:13 2025
# Combined
# Appended
# Subject 9502 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:43:26 2025
# Combined
# Appended
# Subject 9502 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:43:39 2025
# Combined
# Appended
# Subject 9502 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:43:54 2025
# Combined
# Appended
# Subject 9502 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:44:09 2025
# Combined
# Appended
# Subject 9502 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:44:23 2025
# Combined
# Appended
# Subject 9502 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:44:39 2025
# Combined
# Appended
# Subject 9502 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:44:54 2025
# Combined
# Appended
# Subject 9502 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:45:09 2025
# Combined
# Appended
# Subject 9502 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:45:26 2025
# Combined
# Appended
# Subject 9502 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:45:40 2025
# Combined
# Appended
# Subject 9502 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:45:58 2025
# Combined
# Appended
# Subject 9502 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:46:15 2025
# Combined
# Appended
# Subject 9502 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:46:34 2025
# Combined
# Appended
# Subject 9502 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:46:52 2025
# Combined
# Appended
# Saved
# Subject 9586 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:48:44 2025
# Combined
# Appended
# Subject 9586 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:48:56 2025
# Combined
# Appended
# Subject 9586 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:49:10 2025
# Combined
# Appended
# Subject 9586 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:49:23 2025
# Combined
# Appended
# Subject 9586 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:49:38 2025
# Combined
# Appended
# Subject 9586 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:49:52 2025
# Combined
# Appended
# Subject 9586 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:50:07 2025
# Combined
# Appended
# Subject 9586 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:50:23 2025
# Combined
# Appended
# Subject 9586 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:50:39 2025
# Combined
# Appended
# Subject 9586 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:50:55 2025
# Combined
# Appended
# Subject 9586 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:51:12 2025
# Combined
# Appended
# Subject 9586 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:51:27 2025
# Combined
# Appended
# Subject 9586 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:51:45 2025
# Combined
# Appended
# Subject 9586 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:52:01 2025
# Combined
# Appended
# Subject 9586 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:52:18 2025
# Combined
# Appended
# Saved
# Subject 9601 Session 01 Section 1 has been normalized
# time is:  Tue Jun 10 15:54:03 2025
# Combined
# Appended
# Subject 9601 Session 01 Section 2 has been normalized
# time is:  Tue Jun 10 15:54:15 2025
# Combined
# Appended
# Subject 9601 Session 01 Section 3 has been normalized
# time is:  Tue Jun 10 15:54:29 2025
# Combined
# Appended
# Subject 9601 Session 02 Section 1 has been normalized
# time is:  Tue Jun 10 15:54:43 2025
# Combined
# Appended
# Subject 9601 Session 02 Section 2 has been normalized
# time is:  Tue Jun 10 15:54:57 2025
# Combined
# Appended
# Subject 9601 Session 02 Section 3 has been normalized
# time is:  Tue Jun 10 15:55:12 2025
# Combined
# Appended
# Subject 9601 Session 03 Section 1 has been normalized
# time is:  Tue Jun 10 15:55:27 2025
# Combined
# Appended
# Subject 9601 Session 03 Section 2 has been normalized
# time is:  Tue Jun 10 15:55:41 2025
# Combined
# Appended
# Subject 9601 Session 03 Section 3 has been normalized
# time is:  Tue Jun 10 15:55:56 2025
# Combined
# Appended
# Subject 9601 Session 04 Section 2 has been normalized
# time is:  Tue Jun 10 15:56:12 2025
# Combined
# Appended
# Subject 9601 Session 04 Section 3 has been normalized
# time is:  Tue Jun 10 15:56:29 2025
# Combined
# Appended
# Subject 9601 Session 05 Section 1 has been normalized
# time is:  Tue Jun 10 15:56:44 2025
# Combined
# Appended
# Subject 9601 Session 05 Section 2 has been normalized
# time is:  Tue Jun 10 15:57:02 2025
# Combined
# Appended
# Subject 9601 Session 05 Section 3 has been normalized
# time is:  Tue Jun 10 15:57:18 2025
# Combined
# Appended
# Subject 9601 Session 04 Section 1 has been normalized
# time is:  Tue Jun 10 15:57:35 2025
# Combined
# Appended
# Saved
