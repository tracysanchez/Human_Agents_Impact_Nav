# %% [markdown]
# # Extracting information from the randomization file

# %%
import os
import re
import glob
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Added cell to set Working Directory to your location
os.chdir('/Volumes/TwoTeras/0_Experiment_1/Pointing_Task/')
os.getcwd()
# Out:
# '/Volumes/TwoTeras/0_Experiment_1/Pointing_Task'

# %% [markdown]
# ## Importing the individual randomization files per participant

# %%
# specify data folder
# with wildcard for every file with a certain name
path = "Randomizations/*.json"

# %%
## Extracting all subject IDs from the data folder
subIDs = []
for sub in glob.glob(path):
    if sub[15].isdigit():
        subIDs.append(int(sub[15:19]))
    else:
        pass
subIDs = np.unique(subIDs)
print(subIDs)
# Out:
# [ 365  479 1754 2258 2361 2693 3246 3310 3572 3976 4176 4597 4796 4917
#  5238 5531 5741 6642 7093 7264 7412 7842 8007 8469 8673 8695 9472 9502
#  9586 9601]

# %%
# create empty dataframe
df = pd.DataFrame()

# read every file name in folder
for filename in glob.glob(path):
    with open(filename, 'r') as file:
        # make json files parsable
        data = "[" + file.read()
        data = data[:len(data)-1] + "]"

        # read data per file
        subjectdf = pd.read_json(data)

        # insert participant id in every line
        subjectdf.insert(0, "SubjectID", [int(filename[15:19])] * subjectdf.shape[0], True)
        df = df.append(subjectdf, ignore_index=True)
df.head(8)
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       9601           9601  [PointingTask]  English
# 1       8007           8007  [PointingTask]  English
# 2       9502           9502  [PointingTask]  English
# 3       9472           9472  [PointingTask]  Deutsch
# 4        479            479  [PointingTask]  English
# 5       8695           8695  [PointingTask]  English
# 6       8469           8469  [PointingTask]  Deutsch
# 7       5531           5531  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 1  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 2  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 3  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 4  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 5  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 6  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 7  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 1  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 2  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 3  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 4  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 5  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 6  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 7  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                        PointingTaskStartingLocations  \
# 0  [24, 3, 0, 14, 4, 20, 25, 26, 1, 10, 7, 8, 13,...
# 1  [24, 25, 6, 17, 0, 27, 11, 18, 8, 3, 22, 15, 5...
# 2  [27, 7, 21, 16, 2, 3, 26, 22, 20, 14, 13, 5, 2...
# 3  [13, 8, 11, 23, 20, 17, 6, 14, 1, 24, 15, 27, ...
# 4  [7, 16, 27, 6, 22, 20, 21, 1, 25, 11, 26, 4, 1...
# 5  [26, 22, 5, 19, 7, 15, 27, 18, 6, 17, 0, 3, 11...
# 6  [13, 3, 15, 23, 14, 12, 5, 1, 7, 22, 24, 8, 6,...
# 7  [19, 23, 17, 3, 7, 10, 9, 5, 6, 15, 4, 13, 1, ...
#
#                                PointingTaskTargets_1  \
# 0   [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
# 1     [30, 47, 3, 53, 69, 77, 30, 40, 56, 43, 88, 2]
# 2     [8, 93, 76, 46, 56, 21, 72, 78, 55, 64, 62, 5]
# 3  [7, 46, 54, 56, 60, 101, 68, 67, 70, 94, 29, 101]
# 4   [9, 45, 44, 14, 79, 51, 40, 104, 97, 52, 40, 94]
# 5  [100, 53, 93, 79, 62, 27, 65, 79, 101, 55, 79,...
# 6  [20, 12, 23, 106, 68, 14, 104, 96, 77, 98, 25,...
# 7  [110, 91, 77, 103, 33, 41, 86, 9, 41, 11, 103,...
#
#                                PointingTaskTargets_2  \
# 0    [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
#
[103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
# 1  [101, 106, 110, 61, 94, 89, 105, 85, 93, 101, ...
# 2   [3, 55, 111, 91, 65, 73, 43, 50, 20, 34, 23, 26]
# 3   [71, 98, 106, 1, 44, 49, 31, 30, 49, 53, 48, 29]
# 4       [8, 8, 40, 20, 8, 48, 36, 40, 8, 54, 22, 44]
# 5    [56, 32, 5, 41, 75, 55, 23, 63, 33, 41, 20, 30]
# 6      [91, 91, 99, 67, 55, 1, 1, 15, 81, 71, 43, 5]
# 7  [54, 65, 57, 65, 22, 92, 78, 41, 69, 107, 28, 82]
#
#                               PointingTaskTargets_28
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 1  [80, 79, 79, 58, 61, 105, 102, 64, 66, 98, 100...
# 2     [44, 3, 44, 54, 51, 47, 43, 27, 46, 8, 12, 14]
# 3     [50, 54, 32, 44, 21, 9, 35, 35, 51, 13, 53, 9]
# 4     [6, 50, 50, 30, 16, 46, 26, 18, 0, 48, 36, 10]
# 5    [14, 84, 92, 96, 106, 52, 92, 52, 4, 18, 4, 40]
# 6      [87, 37, 25, 71, 35, 7, 19, 1, 35, 15, 27, 5]
# 7   [98, 64, 108, 80, 22, 8, 40, 24, 32, 22, 54, 36]
#
# [8 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle', 'TriggerPressedFreq',
#        'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
#        'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
#        'PhotoReleasedTimeStamps', 'ParticipantPosition_x',
#        'ParticipantPosition_y', 'ParticipantPosition_z', 'ParticipantPosition',
#        'ParticipantRotation_x', 'ParticipantRotation_y',
#        'ParticipantRotation_z', 'ParticipantRotation', 'PointerPosition_x',
#        'PointerPosition_y', 'PointerPosition_z', 'PointerPosition',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding'],
#       dtype='object')

# %%
df.PointerDirection_y.describe()
# Out:
# count    10080.000000
# mean         0.036223
# std          0.054334
# min         -0.512495
# 25%          0.005792
# 50%          0.025947
# 75%          0.053298
# max          0.842834
# Name: PointerDirection_y, dtype: float64

# %%
df.tail(10)
# Out:
#     SubjectID  ParticipantID       TaskOrder Language  \
# 20       4796           4796  [PointingTask]  English
# 21       2361           2361  [PointingTask]  English
# 22       4597           4597  [PointingTask]  Deutsch
# 23       4176           4176  [PointingTask]  English
# 24       4917           4917  [PointingTask]  Deutsch
# 25       3572           3572  [PointingTask]  Deutsch
# 26        365            365  [PointingTask]  English
# 27       3246           3246  [PointingTask]  English
# 28       2258           2258  [PointingTask]  Deutsch
# 29       1754           1754  [PointingTask]  Deutsch
#
#                                    InitialOrientation  \
# 20  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 21  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 22  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 23  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 24  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 25  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 26  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 27  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 28  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 29  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                PointingTaskRandomised  \
# 20  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 21  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 22  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 23  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 24  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 25  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 26  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 27  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 28  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 29  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                         PointingTaskStartingLocations  \
# 20  [17, 20, 11, 22, 16, 6, 4, 13, 27, 5, 19, 3, 1...
# 21  [19, 10, 21, 4, 12, 17, 8, 7, 25, 23, 9, 11, 2...
# 22  [26, 17, 12, 0, 7, 9, 20, 5, 11, 3, 15, 4, 19,...
# 23  [25, 16, 18, 12, 19, 17, 21, 9, 22, 13, 5, 15,...
# 24  [1, 11, 22, 21, 13, 26, 27, 0, 18, 12, 3, 14, ...
# 25  [4, 18, 26, 21, 8, 10, 14, 15, 6, 1, 5, 13, 25...
# 22  [66, 13, 33, 54, 65, 72, 91, 83, 21, 110, 29, 41]
# 23       [6, 50, 44, 50, 30, 2, 8, 28, 8, 16, 28, 20]
# 24  [46, 76, 104, 90, 12, 106, 40, 36, 50, 16, 30,...
# 25   [40, 71, 99, 78, 5, 103, 89, 28, 17, 99, 46, 66]
# 26     [21, 84, 0, 79, 8, 33, 61, 10, 47, 26, 92, 85]
# 27   [89, 76, 49, 41, 24, 41, 36, 18, 52, 54, 30, 48]
# 28  [21, 107, 95, 59, 0, 56, 109, 75, 102, 88, 92,...
# 29   [64, 14, 94, 49, 77, 89, 94, 5, 39, 40, 110, 71]
#
#                                PointingTaskTargets_27  \
# 20   [76, 70, 1, 108, 24, 92, 0, 61, 108, 37, 51, 81]
# 21  [53, 42, 70, 27, 97, 50, 95, 97, 102, 26, 57, 59]
# 22  [82, 35, 60, 24, 60, 107, 61, 76, 101, 73, 79,...
# 23   [30, 30, 34, 44, 32, 22, 22, 14, 30, 28, 30, 48]
# 24      [42, 24, 38, 16, 12, 8, 0, 32, 30, 4, 16, 40]
# 25  [82, 66, 109, 47, 82, 42, 60, 85, 11, 30, 22, 32]
# 26    [9, 94, 79, 43, 59, 2, 106, 107, 18, 29, 39, 8]
# 27     [25, 26, 31, 22, 5, 37, 19, 42, 23, 6, 51, 26]
# 28     [107, 72, 33, 0, 23, 95, 33, 31, 3, 14, 0, 15]
# 29   [2, 108, 104, 82, 5, 84, 55, 78, 52, 29, 86, 49]
#
#                                PointingTaskTargets_28
# 20    [26, 44, 38, 32, 22, 45, 24, 18, 19, 35, 9, 37]
# 21  [72, 46, 22, 93, 52, 93, 104, 43, 36, 9, 91, 103]
# 22    [58, 34, 25, 18, 39, 48, 13, 39, 5, 37, 21, 11]
# 23      [26, 4, 14, 8, 24, 54, 10, 38, 16, 2, 28, 54]
# 24     [44, 50, 46, 8, 26, 30, 0, 20, 52, 24, 44, 52]
# 25    [37, 33, 38, 62, 29, 9, 25, 20, 42, 50, 24, 32]
# 26     [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
# 27    [40, 43, 44, 26, 10, 36, 22, 24, 32, 28, 38, 6]
# 28    [53, 54, 44, 10, 38, 48, 12, 35, 28, 14, 18, 6]
# 29   [57, 93, 5, 84, 27, 90, 14, 79, 89, 63, 99, 101]
#
# [10 rows x 35 columns]

# %% [markdown]
# ## Detangling starting positions
#
# `.explote('VariableName')` is a method that transforms each element of a list-like
# **in this case the list of start locations contained on** to a row, replicating index values

# %%
StartingPoints = pd.DataFrame(df.explode('PointingTaskStartingLocations', ignore_index=True))
StartingPoints.head(29)
# Out:
#     SubjectID  ParticipantID       TaskOrder Language  \
# 0        9601           9601  [PointingTask]  English
# 1        9601           9601  [PointingTask]  English
# 2        9601           9601  [PointingTask]  English
# 3        9601           9601  [PointingTask]  English
# 4        9601           9601  [PointingTask]  English
# 5        9601           9601  [PointingTask]  English
# 6        9601           9601  [PointingTask]  English
[51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 1   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 2   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 3   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 4   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 5   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 6   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 7   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 8   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 9   [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 10  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 11  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 12  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 13  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 14  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 15  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 16  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 17  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 18  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 19  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 20  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 21  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 22  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 23  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 24  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 25  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 26  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 27  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]
# 28  [80, 79, 79, 58, 61, 105, 102, 64, 66, 98, 100...
#
# [29 rows x 35 columns]

# %%
StartingPoints.shape
# Out:
# (840, 35)

# %%
StartingPoints = pd.DataFrame(df.explode('PointingTaskStartingLocations'))

# %% [markdown]
# ### Creating StartingPoint ID
#
# We have 28 starting locations, `np.arange(1,29,1)` creates a list starting at 1 and stopping at 28 in 1 unit incrementals and repeats that for the lenght of participants in the data base `len(StartingPoints.ParticipantID.unique()`.

# %%
StartingPoints['StartPointID']= np.tile(np.arange(1,29,1), len(StartingPoints.ParticipantID.unique()))
StartingPoints.head()
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       9601           9601  [PointingTask]  English
# 0       9601           9601  [PointingTask]  English
# 0       9601           9601  [PointingTask]  English
# 0       9601           9601  [PointingTask]  English
# 0       9601           9601  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#   PointingTaskStartingLocations  \
# 0                            24
# 0                             3
# 0                             0
# 0                            14
# 0                             4
#
#                               PointingTaskTargets_1  \
# 0  [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
# 0  [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
# 0  [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
# 0  [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
# 0  [52, 7, 18, 41, 10, 91, 102, 61, 75, 51, 13, 66]
#
#                              PointingTaskTargets_2  \
# 0  [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
# 0  [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
# 0  [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
# 0  [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
# 0  [9, 10, 82, 3, 24, 30, 55, 19, 102, 15, 77, 60]
#
#                               PointingTaskTargets_3  ...  \
# 0  [43, 78, 10, 4, 17, 65, 10, 44, 83, 38, 54, 105]  ...
# 0  [43, 78, 10, 4, 17, 65, 10, 44, 83, 38, 54, 105]  ...
# 0  [43, 78, 10, 4, 17, 65, 10, 44, 83, 38, 54, 105]  ...
# 0  [43, 78, 10, 4, 17, 65, 10, 44, 83, 38, 54, 105]  ...
# 0  [43, 78, 10, 4, 17, 65, 10, 44, 83, 38, 54, 105]  ...
#
#                               PointingTaskTargets_20  \
# 0  [14, 35, 18, 12, 15, 102, 63, 54, 79, 11, 53, 55]
# 0  [14, 35, 18, 12, 15, 102, 63, 54, 79, 11, 53, 55]
# 0  [14, 35, 18, 12, 15, 102, 63, 54, 79, 11, 53, 55]
# 0  [14, 35, 18, 12, 15, 102, 63, 54, 79, 11, 53, 55]
# 0  [14, 35, 18, 12, 15, 102, 63, 54, 79, 11, 53, 55]
#
#                               PointingTaskTargets_21  \
# 0  [110, 106, 80, 57, 53, 93, 44, 18, 15, 45, 100...
# 0  [110, 106, 80, 57, 53, 93, 44, 18, 15, 45, 100...
# 0  [110, 106, 80, 57, 53, 93, 44, 18, 15, 45, 100...
# 0  [110, 106, 80, 57, 53, 93, 44, 18, 15, 45, 100...
# 0  [110, 106, 80, 57, 53, 93, 44, 18, 15, 45, 100...
#
#                             PointingTaskTargets_22  \
# 0  [90, 43, 94, 4, 27, 85, 94, 36, 21, 108, 2, 86]
# 0  [90, 43, 94, 4, 27, 85, 94, 36, 21, 108, 2, 86]
# 0  [90, 43, 94, 4, 27, 85, 94, 36, 21, 108, 2, 86]
# 0  [90, 43, 94, 4, 27, 85, 94, 36, 21, 108, 2, 86]
# 0  [90, 43, 94, 4, 27, 85, 94, 36, 21, 108, 2, 86]
#
#                               PointingTaskTargets_23  \
# 0  [99, 50, 64, 107, 53, 103, 53, 103, 67, 21, 95...
# 0  [99, 50, 64, 107, 53, 103, 53, 103, 67, 21, 95...
# 0  [99, 50, 64, 107, 53, 103, 53, 103, 67, 21, 95...
# 0  [99, 50, 64, 107, 53, 103, 53, 103, 67, 21, 95...
# 0  [99, 50, 64, 107, 53, 103, 53, 103, 67, 21, 95...
#
#                               PointingTaskTargets_24  \
# 0  [108, 90, 12, 102, 44, 89, 80, 80, 47, 73, 33,...
# 0  [108, 90, 12, 102, 44, 89, 80, 80, 47, 73, 33,...
# 0  [108, 90, 12, 102, 44, 89, 80, 80, 47, 73, 33,...
# 0  [108, 90, 12, 102, 44, 89, 80, 80, 47, 73, 33,...
# 0  [108, 90, 12, 102, 44, 89, 80, 80, 47, 73, 33,...
#
#                              PointingTaskTargets_25  \
# 0  [8, 59, 26, 105, 28, 16, 34, 1, 104, 106, 70, 3]
# 0  [8, 59, 26, 105, 28, 16, 34, 1, 104, 106, 70, 3]
# 0  [8, 59, 26, 105, 28, 16, 34, 1, 104, 106, 70, 3]
# 0  [8, 59, 26, 105, 28, 16, 34, 1, 104, 106, 70, 3]
# 0  [8, 59, 26, 105, 28, 16, 34, 1, 104, 106, 70, 3]
#
#                               PointingTaskTargets_26  \
# 0  [29, 77, 24, 104, 109, 100, 69, 59, 67, 7, 73,...
# 0  [29, 77, 24, 104, 109, 100, 69, 59, 67, 7, 73,...
# 0  [29, 77, 24, 104, 109, 100, 69, 59, 67, 7, 73,...
# 0  [29, 77, 24, 104, 109, 100, 69, 59, 67, 7, 73,...
# 0  [29, 77, 24, 104, 109, 100, 69, 59, 67, 7, 73,...
#
#                               PointingTaskTargets_27  \
# 0  [103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
# 0  [103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
# 0  [103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
# 0  [103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
# 0  [103, 43, 27, 33, 38, 25, 16, 98, 106, 76, 59,...
#
#                               PointingTaskTargets_28 StartPointID
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]            1
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]            2
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]            3
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]            4
# 0  [51, 99, 93, 34, 73, 108, 88, 89, 67, 61, 59, 77]            5
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Exploding the target places accordingly
#
# Since it's necessary to explote 28 diferent variables into specific row ranges, this process starts by creating a list of the future row range conditionals `ExploteID` and a list of the variables to explote `ColumnList`.
#
# This two list are then merge into a dictionary `ExploteDic`

# %%
# Create list of future conditionals for query
ExploteID = []
for item in range(1,29):
    step = 'StartPointID == '  + str(item)
    ExploteID.append(step)

# %%
# Create a list of the column names of variables to explote
ColumnList = list(StartingPoints.iloc[:,7:35].columns)

# %%
# Create dictionary 
ExploteDic = dict(zip(ExploteID, ColumnList))
ExploteDic
# Out:
# {'StartPointID == 1': 'PointingTaskTargets_1',
#  'StartPointID == 2': 'PointingTaskTargets_2',
#  'StartPointID == 3': 'PointingTaskTargets_3',
#  'StartPointID == 4': 'PointingTaskTargets_4',
#  'StartPointID == 5': 'PointingTaskTargets_5',
#  'StartPointID == 6': 'PointingTaskTargets_6',
#  'StartPointID == 7': 'PointingTaskTargets_7',
#  'StartPointID == 8': 'PointingTaskTargets_8',
#  'StartPointID == 9': 'PointingTaskTargets_9',
#  'StartPointID == 10': 'PointingTaskTargets_10',
#  'StartPointID == 11': 'PointingTaskTargets_11',
#  'StartPointID == 12': 'PointingTaskTargets_12',
#  'StartPointID == 13': 'PointingTaskTargets_13',
#  'StartPointID == 14': 'PointingTaskTargets_14',
#  'StartPointID == 15': 'PointingTaskTargets_15',
#  'StartPointID == 16': 'PointingTaskTargets_16',
#  'StartPointID == 17': 'PointingTaskTargets_17',
#  'StartPointID == 18': 'PointingTaskTargets_18',
#  'StartPointID == 19': 'PointingTaskTargets_19',
#  'StartPointID == 20': 'PointingTaskTargets_20',
#  'StartPointID == 21': 'PointingTaskTargets_21',
#  'StartPointID == 22': 'PointingTaskTargets_22',
#  'StartPointID == 23': 'PointingTaskTargets_23',
#  'StartPointID == 24': 'PointingTaskTargets_24',
#  'StartPointID == 25': 'PointingTaskTargets_25',
#  'StartPointID == 26': 'PointingTaskTargets_26',
#  'StartPointID == 27': 'PointingTaskTargets_27',
#  'StartPointID == 28': 'PointingTaskTargets_28'}

# %%
def explote_multiple(dataframe, dic):
    
    """ Creates a list of dataframes that include one exploted variable based row conditionals derivated from
    keys, values contain of a Dictionary
    
Parameters
-------------
     
     :dataframe: your data frame,
     :dic: Dictionary contains a list of key values that will inform a query of the df
     and values that contain the names of columns to explote. 
returns 
----------

    List of DataFrames
     """

    tempdf = [] #Empty list to store each exploted data set
    for conditional, variable_to_explote in dic.items():
        data_q = dataframe.query(conditional).explode(variable_to_explote)
        ques = pd.DataFrame(data_q)
        tempdf.append(ques)
    data_frames_list = pd.concat(tempdf, axis=0)
    return data_frames_list

# %%
ExploteAplication = explote_multiple(StartingPoints, ExploteDic)
ExploteAplication.shape
# Out:
# (10080, 36)

# %%
ExploteAplication.set_index(['ParticipantID', 'StartPointID'], inplace= True)

# %%
# Probe of concept how to just retain integers AKA the exploted data
b = pd.DataFrame( ExploteAplication['PointingTaskTargets_1'][ExploteAplication['PointingTaskTargets_1'].map(type)==int])
b.tail()
# Out:
#                            PointingTaskTargets_1
# ParticipantID StartPointID
# 1754          1                               15
#               1                              111
#               1                               77
#               1                               49
#               1                              101

# %%
def integrate_explote(dataframe, list_variables):
    empty = []
    for l in  list_variables:
        step = dataframe[l][dataframe[l].map(type)==int]
        empty.append(step)
    finals = pd.DataFrame(pd.concat(empty, axis=0), columns= ['Target'])
    dataframe['Trials'] = finals['Target']
    return dataframe

# %%
Integrated = integrate_explote(ExploteAplication, ColumnList)
Integrated.info()
print(Integrated.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10080 entries, (9601, 1) to (1754, 28)
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      10080 non-null  int64
#  1   TaskOrder                      10080 non-null  object
#  2   Language                       10080 non-null  object
#  3   InitialOrientation             10080 non-null  object
#  4   PointingTaskRandomised         10080 non-null  object
#  5   PointingTaskStartingLocations  10080 non-null  object
#  6   PointingTaskTargets_1          10080 non-null  object
#  7   PointingTaskTargets_2          10080 non-null  object
#  8   PointingTaskTargets_3          10080 non-null  object
#  9   PointingTaskTargets_4          10080 non-null  object
#  10  PointingTaskTargets_5          10080 non-null  object
#  11  PointingTaskTargets_6          10080 non-null  object
#  12  PointingTaskTargets_7          10080 non-null  object
#  13  PointingTaskTargets_8          10080 non-null  object
#  14  PointingTaskTargets_9          10080 non-null  object
#  15  PointingTaskTargets_10         10080 non-null  object
#  16  PointingTaskTargets_11         10080 non-null  object
#  17  PointingTaskTargets_12         10080 non-null  object
#  18  PointingTaskTargets_13         10080 non-null  object
#  19  PointingTaskTargets_14         10080 non-null  object
#  20  PointingTaskTargets_15         10080 non-null  object
#  21  PointingTaskTargets_16         10080 non-null  object
#  22  PointingTaskTargets_17         10080 non-null  object
#  23  PointingTaskTargets_18         10080 non-null  object
#  24  PointingTaskTargets_19         10080 non-null  object
#  25  PointingTaskTargets_20         10080 non-null  object
#  26  PointingTaskTargets_21         10080 non-null  object
#  27  PointingTaskTargets_22         10080 non-null  object
#  28  PointingTaskTargets_23         10080 non-null  object
#  29  PointingTaskTargets_24         10080 non-null  object
#  30  PointingTaskTargets_25         10080 non-null  object
#  31  PointingTaskTargets_26         10080 non-null  object
#  32  PointingTaskTargets_27         10080 non-null  object
#  33  PointingTaskTargets_28         10080 non-null  object
#  34  Trials                         10080 non-null  object
# dtypes: int64(1), object(34)
# memory usage: 2.7+ MB
#                             SubjectID       TaskOrder Language  \
# ParticipantID StartPointID
# 1754          28                 1754  [PointingTask]  Deutsch
#               28                 1754  [PointingTask]  Deutsch
#               28                 1754  [PointingTask]  Deutsch
#               28                 1754  [PointingTask]  Deutsch
#               28                 1754  [PointingTask]  Deutsch
#
#                                                            InitialOrientation  \
# ParticipantID StartPointID
# 1754          28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                                        PointingTaskRandomised  \
# ParticipantID StartPointID
# 1754          28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                            PointingTaskStartingLocations  \
# ParticipantID StartPointID
# 1754          28                                      26
#               28                                      26
#               28                                      26
#               28                                      26
#               28                                      26
#
#                                                         PointingTaskTargets_1  \
# ParticipantID StartPointID
# 1754          28            [95, 83, 44, 13, 77, 23, 45, 15, 111, 77, 49, ...
#               28            [95, 83, 44, 13, 77, 23, 45, 15, 111, 77, 49, ...
#               28            [95, 83, 44, 13, 77, 23, 45, 15, 111, 77, 49, ...
#               28            [95, 83, 44, 13, 77, 23, 45, 15, 111, 77, 49, ...
#               28            [95, 83, 44, 13, 77, 23, 45, 15, 111, 77, 49, ...
#
#                                                        PointingTaskTargets_2  \
# ParticipantID StartPointID
# 1754          28            [111, 52, 63, 85, 10, 99, 14, 82, 49, 98, 0, 30]
#               28            [111, 52, 63, 85, 10, 99, 14, 82, 49, 98, 0, 30]
#               28            [111, 52, 63, 85, 10, 99, 14, 82, 49, 98, 0, 30]
#               28            [111, 52, 63, 85, 10, 99, 14, 82, 49, 98, 0, 30]
#               28            [111, 52, 63, 85, 10, 99, 14, 82, 49, 98, 0, 30]
#
#                                                        PointingTaskTargets_3  \
# ParticipantID StartPointID
# 1754          28            [96, 84, 74, 18, 79, 81, 10, 102, 58, 90, 2, 53]
#               28            [96, 84, 74, 18, 79, 81, 10, 102, 58, 90, 2, 53]
#               28            [96, 84, 74, 18, 79, 81, 10, 102, 58, 90, 2, 53]
#               28            [96, 84, 74, 18, 79, 81, 10, 102, 58, 90, 2, 53]
#               28            [96, 84, 74, 18, 79, 81, 10, 102, 58, 90, 2, 53]
#
#                                                         PointingTaskTargets_4  \
# ParticipantID StartPointID
# 1754          28            [89, 103, 50, 57, 8, 101, 73, 36, 26, 70, 47, 98]
#               28            [89, 103, 50, 57, 8, 101, 73, 36, 26, 70, 47, 98]
#               28            [89, 103, 50, 57, 8, 101, 73, 36, 26, 70, 47, 98]
#               28            [89, 103, 50, 57, 8, 101, 73, 36, 26, 70, 47, 98]
#               28            [89, 103, 50, 57, 8, 101, 73, 36, 26, 70, 47, 98]
#
#                             ...  \
# ParticipantID StartPointID  ...
# 1754          28            ...
#               28            ...
#               28            ...
#               28            ...
#               28            ...
#
#                                                      PointingTaskTargets_20  \
# ParticipantID StartPointID
# 1754          28            [106, 4, 97, 30, 65, 75, 39, 53, 9, 84, 65, 18]
#               28            [106, 4, 97, 30, 65, 75, 39, 53, 9, 84, 65, 18]
#               28            [106, 4, 97, 30, 65, 75, 39, 53, 9, 84, 65, 18]
#               28            [106, 4, 97, 30, 65, 75, 39, 53, 9, 84, 65, 18]
#               28            [106, 4, 97, 30, 65, 75, 39, 53, 9, 84, 65, 18]
#
#                                                        PointingTaskTargets_21  \
# ParticipantID StartPointID
# 1754          28            [35, 11, 52, 39, 43, 5, 17, 72, 41, 110, 42, 101]
#               28            [35, 11, 52, 39, 43, 5, 17, 72, 41, 110, 42, 101]
#               28            [35, 11, 52, 39, 43, 5, 17, 72, 41, 110, 42, 101]
#               28            [35, 11, 52, 39, 43, 5, 17, 72, 41, 110, 42, 101]
# 1754          28                               79     79
#               28                               89     89
#               28                               63     63
#               28                               99     99
#               28                              101    101
#
# [5 rows x 35 columns]

# %%
Integrated.sort_index(level= ['ParticipantID'], inplace=True)
Integrated.head()
# Out:
#                             SubjectID       TaskOrder Language  \
# ParticipantID StartPointID
# 365           1                   365  [PointingTask]  English
#               1                   365  [PointingTask]  English
#               1                   365  [PointingTask]  English
#               1                   365  [PointingTask]  English
#               1                   365  [PointingTask]  English
#
#                                                            InitialOrientation  \
# ParticipantID StartPointID
# 365           1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                                        PointingTaskRandomised  \
# ParticipantID StartPointID
# 365           1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                            PointingTaskStartingLocations  \
# ParticipantID StartPointID
# 365           1                                       21
#               1                                       21
#               1                                       21
#               1                                       21
#               1                                       21
#
#                            PointingTaskTargets_1  \
# ParticipantID StartPointID
# 365           1                               90
#               1                               88
#               1                               25
#               1                               80
#               1                               71
#
#                                                         PointingTaskTargets_2  \
# ParticipantID StartPointID
# 365           1             [84, 78, 59, 43, 86, 44, 21, 62, 88, 76, 99, 107]
#               1             [84, 78, 59, 43, 86, 44, 21, 62, 88, 76, 99, 107]
#               1             [84, 78, 59, 43, 86, 44, 21, 62, 88, 76, 99, 107]
#               1             [84, 78, 59, 43, 86, 44, 21, 62, 88, 76, 99, 107]
#               1             [84, 78, 59, 43, 86, 44, 21, 62, 88, 76, 99, 107]
#
#                                                      PointingTaskTargets_3  \
# ParticipantID StartPointID
# 365           1             [47, 67, 33, 87, 0, 18, 72, 8, 36, 38, 80, 18]
#               1             [47, 67, 33, 87, 0, 18, 72, 8, 36, 38, 80, 18]
#               1             [47, 67, 33, 87, 0, 18, 72, 8, 36, 38, 80, 18]
#               1             [47, 67, 33, 87, 0, 18, 72, 8, 36, 38, 80, 18]
#               1             [47, 67, 33, 87, 0, 18, 72, 8, 36, 38, 80, 18]
#
#                                                         PointingTaskTargets_4  \
# ParticipantID StartPointID
# 365           1             [111, 77, 16, 50, 46, 47, 53, 58, 15, 84, 97, ...
#               1             [111, 77, 16, 50, 46, 47, 53, 58, 15, 84, 97, ...
#               1             [111, 77, 16, 50, 46, 47, 53, 58, 15, 84, 97, ...
#               1             [111, 77, 16, 50, 46, 47, 53, 58, 15, 84, 97, ...
#               1             [111, 77, 16, 50, 46, 47, 53, 58, 15, 84, 97, ...
#
#                             ...  \
# ParticipantID StartPointID  ...
# 365           1             ...
#               1             ...
#               1             ...
#               1             ...
#               1             ...
#
#                                                     PointingTaskTargets_20  \
# ParticipantID StartPointID
# 365           1             [59, 37, 103, 14, 62, 87, 41, 83, 86, 1, 7, 1]
#               1             [59, 37, 103, 14, 62, 87, 41, 83, 86, 1, 7, 1]
#               1             [59, 37, 103, 14, 62, 87, 41, 83, 86, 1, 7, 1]
#               1             [59, 37, 103, 14, 62, 87, 41, 83, 86, 1, 7, 1]
#               1             [59, 37, 103, 14, 62, 87, 41, 83, 86, 1, 7, 1]
#
#                                                        PointingTaskTargets_21  \
# ParticipantID StartPointID
# 365           1             [60, 88, 62, 111, 88, 48, 17, 81, 95, 62, 61, 37]
#               1             [9, 94, 79, 43, 59, 2, 106, 107, 18, 29, 39, 8]
#               1             [9, 94, 79, 43, 59, 2, 106, 107, 18, 29, 39, 8]
#               1             [9, 94, 79, 43, 59, 2, 106, 107, 18, 29, 39, 8]
#
#                                                     PointingTaskTargets_28  \
# ParticipantID StartPointID
# 365           1             [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
#               1             [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
#               1             [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
#               1             [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
#               1             [55, 1, 18, 29, 32, 48, 33, 7, 51, 19, 45, 52]
#
#                            Trials
# ParticipantID StartPointID
# 365           1                90
#               1                88
#               1                25
#               1                80
#               1                71
#
# [5 rows x 35 columns]

# %%
Targets = Integrated.loc[:,['SubjectID','PointingTaskStartingLocations','Trials']]
Targets.head()
print(Targets.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10080 entries, (365, 1) to (9601, 28)
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      10080 non-null  int64
#  1   PointingTaskStartingLocations  10080 non-null  object
#  2   Trials                         10080 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 258.6+ KB
# None

# %%
Final = Targets
#Include trial ID for all trials
Final['TrialID']= np.tile(np.arange(1,337,1), len(Final.SubjectID.unique()))
Final.head()
# Out:
#                             SubjectID PointingTaskStartingLocations Trials  \
# ParticipantID StartPointID
# 365           1                   365                            21     90
#               1                   365                            21     88
#               1                   365                            21     25
#               1                   365                            21     80
#               1                   365                            21     71
#
#                             TrialID
# ParticipantID StartPointID
# 365           1                   1
#               1                   2
#               1                   3
#               1                   4
#               1                   5

# %%
#Include marker for each starting position
SubjectNum = len(df.SubjectID.unique())
#Final['MainID_for_StartingPosition']= np.tile(np.arange(1,29,12),SubjectNum)
Final['ID_for_StartingPosition']= np.tile(np.arange(1,13,1), (SubjectNum*28))
Final.head(16)
# Out:
#                             SubjectID PointingTaskStartingLocations Trials  \
# ParticipantID StartPointID
# 365           1                   365                            21     90
#               1                   365                            21     88
#               1                   365                            21     25
#               1                   365                            21     80
#               1                   365                            21     71
#               1                   365                            21     64
#               1                   365                            21     42
#               1                   365                            21      3
#               1                   365                            21     96
#               1                   365                            21     69
#               1                   365                            21      3
#               1                   365                            21    109
#               2                   365                             9     84
#               2                   365                             9     78
#               2                   365                             9     59
#               2                   365                             9     43
#
#                             TrialID  ID_for_StartingPosition
# ParticipantID StartPointID
# 365           1                   1                        1
#               1                   2                        2
#               1                   3                        3
#               1                   4                        4
#               1                   5                        5
#               1                   6                        6
#               1                   7                        7
#               1                   8                        8
#               1                   9                        9
#               1                  10                       10
#               1                  11                       11
#               1                  12                       12
#               2                  13                        1
#               2                  14                        2
#               2                  15                        3
#               2                  16                        4

# %%
np.tile(np.arange(1,29,1),(SubjectNum*12))
# Out:
# array([ 1,  2,  3, ..., 26, 27, 28])

# %%
FinalIds = Targets.reset_index()
FinalIds.head()
# Out:
#    ParticipantID  StartPointID  SubjectID PointingTaskStartingLocations  \
# 0            365             1        365                            21
# 1            365             1        365                            21
# 2            365             1        365                            21
# 3            365             1        365                            21
# 4            365             1        365                            21
#
#   Trials  TrialID  ID_for_StartingPosition
# 0     90        1                        1
# 1     88        2                        2
# 2     25        3                        3
# 3     80        4                        4
# 4     71        5                        5

# %% [markdown]
# # Reading the participants data from the pointingTask files

# %% [markdown]
# ## Loading performance data

# %%
#Setting a new path for performance data
path = "Final/*.json"

# %%
# create empty dataframe
df = pd.DataFrame()

# read every file name in folder
for filename in glob.glob(path):
    with open(filename, 'r') as file:
        # make json files parsable
        data = "[" + file.read()
        data = data[:len(data)-2] + "]"

        # read data per file
        subjectdf = pd.read_json(data)

        # insert participant id in every line
        subjectdf.insert(0, "SubjectID", [int(filename[6:10])] * subjectdf.shape[0], True)
        df = df.append(subjectdf, ignore_index=True)
df
# Out:
#        SubjectID  TrialNumber  ImageIndexNumber ImageName  TimeOut  \
# 0            365            1                90     46_Sa    False
# 1            365            2                88     45_Sa    False
# 2            365            3                25  13_CmANo    False
# 3            365            4                80     41_Sa    False
# 4            365            5                71   36_SaNo    False
# ...          ...          ...               ...       ...      ...
# 10075       4597          332                39  20_CmANo    False
# 10076       4597          333                 5  03_CmANo    False
# 10077       4597          334                37  19_CmANo    False
# 10078       4597          335                21  11_CmANo    False
# 10079       4597          336                11  06_CmANo    False
#
#                      TimeStampBegin                  TimeStampEnd         RT  \
# 0     2021-11-18 10:22:23.050529792 2021-11-18 10:22:48.876244224  25.825715
# 1     2021-11-18 10:22:49.152516864 2021-11-18 10:23:14.644920320  25.492404
# 2     2021-11-18 10:23:14.911271936 2021-11-18 10:23:33.941789952  19.030518
# 3     2021-11-18 10:23:34.213599744 2021-11-18 10:23:51.752148992  17.538549
# 4     2021-11-18 10:23:52.016517632 2021-11-18 10:23:56.168036096   4.151519
# ...                             ...                           ...        ...
# 10075 2021-10-14 08:21:55.319928320 2021-10-14 08:21:57.349065984   2.029138
# 10076 2021-10-14 08:21:57.620871168 2021-10-14 08:22:17.909244416  20.288373
# 10077 2021-10-14 08:22:18.175598336 2021-10-14 08:22:30.780933888  12.605335
# 10078 2021-10-14 08:22:31.047781888 2021-10-14 08:22:33.049141504   2.001359
# 10079 2021-10-14 08:22:33.320452352 2021-10-14 08:22:37.217523200   3.897071
#
#            Angle  TriggerPressedFreq  ...  \
# 0      15.294643                   2  ...
# 1      14.686119                   2  ...
# 2      25.987650                   2  ...
# 3      20.002567                   2  ...
# 4       9.460410                   2  ...
# ...          ...                 ...  ...
# 10075  33.074654                   2  ...
# 10076  81.377144                   2  ...
# 10077  97.995872                   2  ...
# 10078  36.439667                   2  ...
# 10079  37.501797                   2  ...
#
#                                          PointerPosition  \
# 0      {'x': -114.23698425292969, 'y': -0.51772141456...
# 1      {'x': -114.03169250488281, 'y': -0.58369338512...
# 2      {'x': -114.06156921386719, 'y': -0.51319766044...
# 3      {'x': -113.93421936035156, 'y': -0.54913842678...
# 4      {'x': -114.00621032714844, 'y': -0.54621136188...
# ...                                                  ...
# 10075  {'x': -65.43183898925781, 'y': -1.882768869400...
# 10076  {'x': -65.22300720214844, 'y': -1.953780174255...
# 10077  {'x': -65.23188781738281, 'y': -1.891198873519...
# 10078  {'x': -65.33323669433594, 'y': -1.848253011703...
# 10079  {'x': -65.38850402832031, 'y': -1.871883392333...
#
#                                          PointerRotation  \
# 0      {'x': 352.35052490234375, 'y': 356.79223632812...
# 1      {'x': 359.2352294921875, 'y': 68.2468338012695...
# 2      {'x': 354.56964111328125, 'y': 29.633678436279...
# 3      {'x': 359.14617919921875, 'y': 67.794898986816...
# 4      {'x': 356.89862060546875, 'y': 36.026039123535...
# ...                                                  ...
# 10075  {'x': 0.24061803519725802, 'y': 23.14968490600...
# 10076  {'x': 0.478509813547134, 'y': 115.065765380859...
# 10077  {'x': 0.5685269832611081, 'y': 103.59806060791...
# 10078  {'x': 359.3140563964844, 'y': 62.2343482971191...
# 10079  {'x': 359.4039001464844, 'y': 32.2523460388183...
#
#                                PointerRotationQuaternion  \
# 0      {'x': -0.062231320887804004, 'y': -0.036786127...
# 1      {'x': -0.055458828806877004, 'y': 0.5582441091...
# 2      {'x': -0.07568536698818201, 'y': 0.24823381006...
# 3      {'x': -0.045183580368757005, 'y': 0.5558937191...
# 4      {'x': -0.045329034328460006, 'y': 0.3068593144...
# ...                                                  ...
# 10075  {'x': -0.055440083146095005, 'y': 0.1928470581...
# 10076  {'x': -0.11826512962579701, 'y': 0.83536523580...
# 10077  {'x': -0.23921956121921503, 'y': 0.74854719638...
# 10078  {'x': -0.24285082519054402, 'y': 0.45619300007...
# 10079  {'x': -0.07828190922737101, 'y': 0.26653674244...
#
#                                         PointerDirection  TargetBuildingName  \
# 0      {'x': -0.055458828806877004, 'y': 0.1331123709...     TaskBuilding_35
# 1      {'x': 0.9287064671516411, 'y': 0.0133473798632...     TaskBuilding_33
# 2      {'x': 0.49223372340202304, 'y': 0.094636023044...      TaskBuilding_3
# 3      {'x': 0.9257342219352721, 'y': 0.0149016454815...     TaskBuilding_26
# 4      {'x': 0.587291479110717, 'y': 0.05410270392894...     TaskBuilding_18
# ...                                                  ...                 ...
# 10075  {'x': 0.393131166696548, 'y': -0.0041995644569...  BasketballCourt_58
# 10076  {'x': 0.9057904481887811, 'y': -0.008351475000...      TaskBuilding_2
# 10077  {'x': 0.9719210863113401, 'y': -0.009922504425...     TaskBuilding_34
# 10078  {'x': 0.8847969770431511, 'y': 0.0119718909263...     TaskBuilding_27
# 10079  {'x': 0.5336202383041381, 'y': 0.0104037225246...     TaskBuilding_20
#
#                                   TargetBuildingPosition  \
# 0      {'x': -72.79883575439453, 'y': 0.7274017333984...
# 1      {'x': -7.537855625152588, 'y': -2.005443572998...
# 2      {'x': 132.77926635742188, 'y': -1.083272933959...
# 3      {'x': 87.63272094726562, 'y': -0.7474174499511...
# 4      {'x': 157.62081909179688, 'y': -1.219543457031...
# ...                                                  ...
# 10075  {'x': 104.33999633789062, 'y': -3.069999933242...
# 10076  {'x': 197.39566040039062, 'y': -2.950988769531...
# 10077  {'x': -36.169708251953125, 'y': 0.444427490234...
# 10078  {'x': 60.14825439453125, 'y': -0.7427062988281...
# 10079  {'x': 184.2935333251953, 'y': -2.906982421875,...
#
#                                   TargetBuildingRotation  \
# 0      {'x': 7.450580596923828e-09, 'y': 0.9792929887...
# 1      {'x': 2.9802322387695312e-08, 'y': -0.35620027...
# 2      {'x': 0.0, 'y': 0.9378134012222291, 'z': -1.78...
# 3      {'x': 0.0, 'y': 0.9338998794555661, 'z': -2.08...
# 4      {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
# ...                                                  ...
# 10075  {'x': 0.0, 'y': -0.353580743074417, 'z': 0.0, ...
# 10076  {'x': 1.117587089538574e-08, 'y': 0.9974239468...
# 10077  {'x': -2.9802322387695312e-08, 'y': 0.55909502...
# 10078  {'x': -0.12068373709917, 'y': 0.69673198461532...
# 10079  {'x': 4.470348358154297e-08, 'y': 0.9437062740...
#
#                                    TargetBuildingForward  \
# 0      {'x': 0.396512001752853, 'y': -4.1160959085573...
# 1      {'x': -0.665673911571502, 'y': -8.754194169569...
# 2      {'x': 0.6511048078536981, 'y': -3.353882220835...
# 3      {'x': 0.6678031682968141, 'y': -3.896533939951...
# 4      {'x': 0.783807098865509, 'y': -5.1893408681280...
# ...                                                  ...
# 10075  {'x': -0.661481738090515, 'y': 0.0, 'z': 0.749...
# 10076  {'x': 0.14309366047382302, 'y': -7.15016540198...
# 10077  {'x': 0.927095413208007, 'y': -8.3880216550369...
# 10078  {'x': 0.0, 'y': 0.9999998807907101, 'z': -4.09...
# 10079  {'x': 0.6243268847465511, 'y': -4.795686550096...
#
#       DistanceToParticipant                                  PointedDirections
# 0                197.768723  [{'x': -0.055458828806877004, 'y': 0.133112370...
# 1                132.345505  [{'x': 0.9287064671516411, 'y': 0.013347379863...
# 2                299.172119  [{'x': 0.49223372340202304, 'y': 0.09463602304...
# 3                272.171936  [{'x': 0.9257342219352721, 'y': 0.014901645481...
# 4                380.950958  [{'x': 0.587291479110717, 'y': 0.0541027039289...
# ...                     ...                                                ...
# 10075            204.538574  [{'x': 0.393131166696548, 'y': -0.004199564456...
# 10076            473.514160  [{'x': 0.9057904481887811, 'y': -0.00835147500...
# 10077            297.610809  [{'x': 0.9719210863113401, 'y': -0.00992250442...
# 10078            288.566467  [{'x': 0.8847969770431511, 'y': 0.011971890926...
# 10079            266.462585  [{'x': 0.5336202383041381, 'y': 0.010403722524...
#
# [10080 rows x 28 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ## Extracting the Avatar number from the variable 'ImageName'

# %%
#The avatarID info is included in a string variable, here we extracted just the ID number and place it into a new variable
df['avatarID'] = df['ImageName'].str.extractall('(\d+)').unstack().loc[:,0]

# %%
AvaIDs = []
for idx, row in df.iterrows():
    num = re.findall(r'\d+', row['ImageName'])
    AvaIDs.append(num)
# Flatten the list: Every number was returned as a list of it's own with this we get one unified list
avatarIDsf = [item for sublist in AvaIDs for item in sublist]

# %%
df['AvatarPresence'] = df['ImageName'].str.contains('No')
df.loc[:, 'AvatarPresenceCategory'] = df['AvatarPresence'].replace({True: 'Omitted', False: 'Present'})
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber ImageName  TimeOut  \
# 0        365            1                90     46_Sa    False
# 1        365            2                88     45_Sa    False
# 2        365            3                25  13_CmANo    False
# 3        365            4                80     41_Sa    False
# 4        365            5                71   36_SaNo    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2021-11-18 10:22:23.050529792 2021-11-18 10:22:48.876244224  25.825715
# 1 2021-11-18 10:22:49.152516864 2021-11-18 10:23:14.644920320  25.492404
# 2 2021-11-18 10:23:14.911271936 2021-11-18 10:23:33.941789952  19.030518
# 3 2021-11-18 10:23:34.213599744 2021-11-18 10:23:51.752148992  17.538549
# 4 2021-11-18 10:23:52.016517632 2021-11-18 10:23:56.168036096   4.151519
#
#        Angle  TriggerPressedFreq  ...  \
# 0  15.294643                   2  ...
# 1  14.686119                   2  ...
# 2  25.987650                   2  ...
# 3  20.002567                   2  ...
# 4   9.460410                   2  ...
#
#                                     PointerDirection  TargetBuildingName  \
# 0  {'x': -0.055458828806877004, 'y': 0.1331123709...     TaskBuilding_35
# 1  {'x': 0.9287064671516411, 'y': 0.0133473798632...     TaskBuilding_33
# 2  {'x': 0.49223372340202304, 'y': 0.094636023044...      TaskBuilding_3
# 3  {'x': 0.9257342219352721, 'y': 0.0149016454815...     TaskBuilding_26
# 4  {'x': 0.587291479110717, 'y': 0.05410270392894...     TaskBuilding_18
#
#                               TargetBuildingPosition  \
# 0  {'x': -72.79883575439453, 'y': 0.7274017333984...
# 1  {'x': -7.537855625152588, 'y': -2.005443572998...
# 2  {'x': 132.77926635742188, 'y': -1.083272933959...
# 3  {'x': 87.63272094726562, 'y': -0.7474174499511...
# 4  {'x': 157.62081909179688, 'y': -1.219543457031...
#
#                               TargetBuildingRotation  \
# 0  {'x': 7.450580596923828e-09, 'y': 0.9792929887...
# 1  {'x': 2.9802322387695312e-08, 'y': -0.35620027...
# 2  {'x': 0.0, 'y': 0.9378134012222291, 'z': -1.78...
# 3  {'x': 0.0, 'y': 0.9338998794555661, 'z': -2.08...
# 4  {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.396512001752853, 'y': -4.1160959085573...            197.768723
# 1  {'x': -0.665673911571502, 'y': -8.754194169569...            132.345505
# 2  {'x': 0.6511048078536981, 'y': -3.353882220835...            299.172119
# 3  {'x': 0.6678031682968141, 'y': -3.896533939951...            272.171936
# 4  {'x': 0.783807098865509, 'y': -5.1893408681280...            380.950958
#
#                                    PointedDirections avatarID AvatarPresence  \
# 0  [{'x': -0.055458828806877004, 'y': 0.133112370...       46          False
# 1  [{'x': 0.9287064671516411, 'y': 0.013347379863...       45          False
# 2  [{'x': 0.49223372340202304, 'y': 0.09463602304...       13           True
# 3  [{'x': 0.9257342219352721, 'y': 0.014901645481...       41          False
# 4  [{'x': 0.587291479110717, 'y': 0.0541027039289...       36           True
#
#   AvatarPresenceCategory
# 0                Present
# 1                Present
# 2                Omitted
# 3                Present
# 4                Omitted
#
# [5 rows x 31 columns]

# %%
#Checking that value counts for Avatar presence [Should be 50/50]
df.AvatarPresenceCategory.value_counts()
# Out:
# Omitted    5044
# Present    5036
# Name: AvatarPresenceCategory, dtype: int64

# %%
df['meaningful'] = df['ImageName'].str.contains('CmA')
df.loc[:, 'meaningfulBuilding'] = df['meaningful'].replace({True: 'Meaningful', False: 'Not meaningful'})
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber ImageName  TimeOut  \
# 0        365            1                90     46_Sa    False
# 1        365            2                88     45_Sa    False
# 2        365            3                25  13_CmANo    False
# 3        365            4                80     41_Sa    False
# 4        365            5                71   36_SaNo    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2021-11-18 10:22:23.050529792 2021-11-18 10:22:48.876244224  25.825715
# 1 2021-11-18 10:22:49.152516864 2021-11-18 10:23:14.644920320  25.492404
# 2 2021-11-18 10:23:14.911271936 2021-11-18 10:23:33.941789952  19.030518
# 3 2021-11-18 10:23:34.213599744 2021-11-18 10:23:51.752148992  17.538549
# 4 2021-11-18 10:23:52.016517632 2021-11-18 10:23:56.168036096   4.151519
#
#        Angle  TriggerPressedFreq  ...  \
# 0  15.294643                   2  ...
# 1  14.686119                   2  ...
# 2  25.987650                   2  ...
# 3  20.002567                   2  ...
# 4   9.460410                   2  ...
#
#                               TargetBuildingPosition  \
# 0  {'x': -72.79883575439453, 'y': 0.7274017333984...
# 1  {'x': -7.537855625152588, 'y': -2.005443572998...
# 2  {'x': 132.77926635742188, 'y': -1.083272933959...
# 3  {'x': 87.63272094726562, 'y': -0.7474174499511...
# 4  {'x': 157.62081909179688, 'y': -1.219543457031...
#
#                               TargetBuildingRotation  \
# 0  {'x': 7.450580596923828e-09, 'y': 0.9792929887...
# 1  {'x': 2.9802322387695312e-08, 'y': -0.35620027...
# 2  {'x': 0.0, 'y': 0.9378134012222291, 'z': -1.78...
# 3  {'x': 0.0, 'y': 0.9338998794555661, 'z': -2.08...
# 4  {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.396512001752853, 'y': -4.1160959085573...            197.768723
# 1  {'x': -0.665673911571502, 'y': -8.754194169569...            132.345505
# 2  {'x': 0.6511048078536981, 'y': -3.353882220835...            299.172119
# 3  {'x': 0.6678031682968141, 'y': -3.896533939951...            272.171936
# 4  {'x': 0.783807098865509, 'y': -5.1893408681280...            380.950958
#
#                                    PointedDirections avatarID AvatarPresence  \
# 0  [{'x': -0.055458828806877004, 'y': 0.133112370...       46          False
# 1  [{'x': 0.9287064671516411, 'y': 0.013347379863...       45          False
# 2  [{'x': 0.49223372340202304, 'y': 0.09463602304...       13           True
# 3  [{'x': 0.9257342219352721, 'y': 0.014901645481...       41          False
# 4  [{'x': 0.587291479110717, 'y': 0.0541027039289...       36           True
#
#   AvatarPresenceCategory meaningful meaningfulBuilding
# 0                Present      False     Not meaningful
# 1                Present      False     Not meaningful
# 2                Omitted       True         Meaningful
# 3                Present      False     Not meaningful
# 4                Omitted      False     Not meaningful
#
# [5 rows x 33 columns]

# %%
#Checking that value counts for Action and Standing avatars [Should be 50/50]
df.meaningfulBuilding.value_counts()
# Out:
# Not meaningful    5049
# Meaningful        5031
# Name: meaningfulBuilding, dtype: int64

# %% [markdown]
# ### Unesting variables

# %%
def unnest(dframe):

    """Unnest nested data that is needed from a JSON file by inserting each coordinates
    as a seperate column of the DataFrame.
    This Function is specific for the variable
Parameters
-------------
     dframe: your data frame
returns
----------
    DataFrame

    """

    TargetBuildingDirection = pd.DataFrame.from_records(dframe['TargetBuildingForward'])
    dframe.insert(25, "TargetBuildingDirection_z",TargetBuildingDirection['z'], True)
    dframe.insert(25, "TargetBuildingDirection_y",TargetBuildingDirection['y'], True)
    dframe.insert(25, "TargetBuildingDirection_x",TargetBuildingDirection['x'], True)

    TargetBuildingRotation = pd.DataFrame.from_records(dframe['TargetBuildingRotation'])
    dframe.insert(24, "TargetBuildingRotation_z",TargetBuildingRotation['z'], True)
    dframe.insert(24, "TargetBuildingRotation_y",TargetBuildingRotation['y'], True)
    dframe.insert(24, "TargetBuildingRotation_x",TargetBuildingRotation['x'], True)

    TargetBuildingPosition = pd.DataFrame.from_records(dframe['TargetBuildingPosition'])
    dframe.insert(23, "TargetBuildingPosition_z",TargetBuildingPosition['z'], True)
    dframe.insert(23, "TargetBuildingPosition_y",TargetBuildingPosition['y'], True)
    dframe.insert(23, "TargetBuildingPosition_x",TargetBuildingPosition['x'], True)

    PointerDirection = pd.DataFrame.from_records(dframe['PointerDirection'])
    dframe.insert(21, "PointerDirection_z",PointerDirection['z'], True)
    dframe.insert(21, "PointerDirection_y",PointerDirection['y'], True)
    dframe.insert(21, "PointerDirection_x",PointerDirection['x'], True)

    PointerRotation = pd.DataFrame.from_records(dframe['PointerRotation'])
    dframe.insert(19, "PointerRotation_z", PointerRotation['z'], True)
    dframe.insert(19, "PointerRotation_y", PointerRotation['y'], True)
    dframe.insert(19, "PointerRotation_x", PointerRotation['x'], True)

    PointerPosition = pd.DataFrame.from_records(dframe['PointerPosition'])
    dframe.insert(18, "PointerPosition_z", PointerPosition['z'], True)
    dframe.insert(18, "PointerPosition_y", PointerPosition['y'], True)
    dframe.insert(18, "PointerPosition_x", PointerPosition['x'], True)

    ParticipantRotation = pd.DataFrame.from_records(dframe['ParticipantRotation'])
    dframe.insert(17, "ParticipantRotation_z",ParticipantRotation['z'], True)
    dframe.insert(17, "ParticipantRotation_y", ParticipantRotation['y'], True)
    dframe.insert(17, "ParticipantRotation_x", ParticipantRotation['x'], True)

    ParticipantPosition = pd.DataFrame.from_records(dframe['ParticipantPosition'])
    dframe.insert(16, "ParticipantPosition_z", ParticipantPosition['z'], True)
    dframe.insert(16, "ParticipantPosition_y", ParticipantPosition['y'], True)
    dframe.insert(16, "ParticipantPosition_x", ParticipantPosition['x'], True)

    return dframe

# %%
df = unnest(df)
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber ImageName  TimeOut  \
# 0        365            1                90     46_Sa    False
# 1        365            2                88     45_Sa    False
# 2        365            3                25  13_CmANo    False
# 3        365            4                80     41_Sa    False
# 4        365            5                71   36_SaNo    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2021-11-18 10:22:23.050529792 2021-11-18 10:22:48.876244224  25.825715
# 1 2021-11-18 10:22:49.152516864 2021-11-18 10:23:14.644920320  25.492404
# 2 2021-11-18 10:23:14.911271936 2021-11-18 10:23:33.941789952  19.030518
# 3 2021-11-18 10:23:34.213599744 2021-11-18 10:23:51.752148992  17.538549
# 4 2021-11-18 10:23:52.016517632 2021-11-18 10:23:56.168036096   4.151519
#
#        Angle  TriggerPressedFreq  ...  TargetBuildingDirection_y  \
# 0  15.294643                   2  ...              -4.116096e-07
# 1  14.686119                   2  ...              -8.754194e-08
# 2  25.987650                   2  ...              -3.353882e-07
# 3  20.002567                   2  ...              -3.896534e-07
# 4   9.460410                   2  ...              -5.189341e-08
#
#    TargetBuildingDirection_z  \
# 0                  -0.918030
# 1                   0.746243
# 2                  -0.758988
# 3                  -0.744338
# 4                   0.621004
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.396512001752853, 'y': -4.1160959085573...            197.768723
# 1  {'x': -0.665673911571502, 'y': -8.754194169569...            132.345505
# 2  {'x': 0.6511048078536981, 'y': -3.353882220835...            299.172119
# 3  {'x': 0.6678031682968141, 'y': -3.896533939951...            272.171936
# 4  {'x': 0.783807098865509, 'y': -5.1893408681280...            380.950958
#
#                                    PointedDirections avatarID  AvatarPresence  \
# 0  [{'x': -0.055458828806877004, 'y': 0.133112370...       46           False
# 1  [{'x': 0.9287064671516411, 'y': 0.013347379863...       45           False
# 2  [{'x': 0.49223372340202304, 'y': 0.09463602304...       13            True
# 3  [{'x': 0.9257342219352721, 'y': 0.014901645481...       41           False
# 4  [{'x': 0.587291479110717, 'y': 0.0541027039289...       36            True
#
#    AvatarPresenceCategory  meaningful meaningfulBuilding
# 0                 Present       False     Not meaningful
# 1                 Present       False     Not meaningful
# 2                 Omitted        True         Meaningful
# 3                 Present       False     Not meaningful
# 4                 Omitted       False     Not meaningful
#
# [5 rows x 57 columns]

# %%
df.to_csv('PointingTask_exp1.csv')

# %%
df.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle', 'TriggerPressedFreq',
#        'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
#        'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
#        'PhotoReleasedTimeStamps', 'ParticipantPosition_x',
#        'ParticipantPosition_y', 'ParticipantPosition_z', 'ParticipantPosition',
#        'ParticipantRotation_x', 'ParticipantRotation_y',
#        'ParticipantRotation_z', 'ParticipantRotation', 'PointerPosition_x',
#        'PointerPosition_y', 'PointerPosition_z', 'PointerPosition',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding'],
#       dtype='object')

# %%
df.TrialNumber.describe()
# Out:
# count    10080.000000
# mean       168.500000
# std         96.999227
# min          1.000000
# 25%         84.750000
# 50%        168.500000
# 75%        252.250000
# max        336.000000
# Name: TrialNumber, dtype: float64

# %%
PointingTask = pd.read_csv('PointingTask_exp1.csv')

# %%
### Merging the two data frames (Data + Ids)

# %%
AnglesMerged = df.merge(FinalIds, how='right',
                                      left_on=['SubjectID', 'TrialNumber'],
                                      right_on=['SubjectID', 'TrialID'])
FinalIds.head()
# Out:
#    ParticipantID  StartPointID  SubjectID PointingTaskStartingLocations  \
# 0            365             1        365                            21
# 1            365             1        365                            21
# 2            365             1        365                            21
# 3            365             1        365                            21
# 4            365             1        365                            21
#
#   Trials  TrialID  ID_for_StartingPosition
# 0     90        1                        1
# 1     88        2                        2
# 2     25        3                        3
# 3     80        4                        4
# 4     71        5                        5

# %%
AnglesMerged.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle', 'TriggerPressedFreq',
#        'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
#        'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
#        'PhotoReleasedTimeStamps', 'ParticipantPosition_x',
#        'ParticipantPosition_y', 'ParticipantPosition_z', 'ParticipantPosition',
#        'ParticipantRotation_x', 'ParticipantRotation_y',
#        'ParticipantRotation_z', 'ParticipantRotation', 'PointerPosition_x',
#        'PointerPosition_y', 'PointerPosition_z', 'PointerPosition',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding', 'ParticipantID', 'StartPointID',
#        'PointingTaskStartingLocations', 'Trials', 'TrialID',
#        'ID_for_StartingPosition'],
#       dtype='object')

# %%
AnglesMerged[['TrialNumber', 'StartPointID']].head(300)
# Out:
#      TrialNumber  StartPointID
# 0              1             1
# 1              2             1
# 2              3             1
# 3              4             1
# 4              5             1
# ..           ...           ...
# 295          296            25
# 296          297            25
# 297          298            25
# 298          299            25
# 299          300            25
#
# [300 rows x 2 columns]

# %%
# Dropping unnecessary columns
AnglesMerged = AnglesMerged.drop(['TriggerPressedFreq',
                   'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
                   'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
                   'PhotoReleasedTimeStamps','ParticipantPosition', 'PointerPosition'], axis=1)

# %%
# Creating trial time duration
AnglesMerged['TimeStampEnd'] = pd.to_datetime(AnglesMerged['TimeStampEnd'])
AnglesMerged['TimeStampBegin'] = pd.to_datetime(AnglesMerged['TimeStampBegin'])
AnglesMerged['TimeDelta'] = AnglesMerged['TimeStampEnd'] - AnglesMerged['TimeStampBegin']

# %% [markdown]
# Checking if the columns `Trials` and `ImageIndexNumber` coincide, in theory both of them hold the buildings reference number

# %%
c = AnglesMerged
c['Equals'] = np.where((c['Trials'] == c['ImageIndexNumber']), 1, 0)
c['Equals2'] = np.where((c['TrialNumber'] == c['TrialID']), 1, 0)

# %%
d = c[c['Equals'] == 0 ]
d.SubjectID.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: SubjectID, dtype: float64

# %%
AnglesMerged.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle',
#        'ParticipantPosition_x', 'ParticipantPosition_y',
#        'ParticipantPosition_z', 'ParticipantRotation_x',
#        'ParticipantRotation_y', 'ParticipantRotation_z', 'ParticipantRotation',
#        'PointerPosition_x', 'PointerPosition_y', 'PointerPosition_z',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding', 'ParticipantID', 'StartPointID',
#        'PointingTaskStartingLocations', 'Trials', 'TrialID',
#        'ID_for_StartingPosition', 'TimeDelta', 'Equals', 'Equals2'],
#       dtype='object')

# %%
final = AnglesMerged[['SubjectID', 'ParticipantPosition_x', 'ParticipantPosition_z', 'PointerPosition_x','PointerPosition_z', 'PointerDirection_x', 'PointerDirection_z', 'PointerDirection_y',  'TargetBuildingPosition_x', 'TargetBuildingPosition_z','DistanceToParticipant','avatarID','AvatarPresence', 'AvatarPresenceCategory', 'meaningful','meaningfulBuilding','StartPointID','PointingTaskStartingLocations', 'Trials', 'TrialNumber', 'StartPointID' ,'ID_for_StartingPosition','ImageIndexNumber','ImageName','TimeDelta','RT', 'TimeOut', 'TimeStampBegin', 'TimeStampEnd','Angle' ]]
final.head()
# Out:
#    SubjectID  ParticipantPosition_x  ParticipantPosition_z  PointerPosition_x  \
# 0        365            -114.329147            -139.997375        -114.236984
# 1        365            -114.264938            -139.996460        -114.031693
# 2        365            -114.299942            -139.961884        -114.061569
# 3        365            -114.295120            -139.949188        -113.934219
# 4        365            -114.277084            -140.014740        -114.006210
#
#    PointerPosition_z  PointerDirection_x  PointerDirection_z  \
# 0        -139.696228           -0.055459            0.989548
# 1        -139.985962            0.928706            0.370576
# 2        -139.765411            0.492234            0.865303
# 3        -139.899109            0.925734            0.377881
# 4        -139.814026            0.587291            0.807565
#
#    PointerDirection_y  TargetBuildingPosition_x  TargetBuildingPosition_z  \
# 0            0.133112                -72.798836                 53.811722
# 1            0.013347                 -7.537856                -61.359150
# 2            0.094636                132.779266                 29.115131
# 3            0.014902                 87.632721                 42.919762
# 4            0.054103                157.620819                127.239502
#
#    ...  StartPointID ID_for_StartingPosition  ImageIndexNumber ImageName  \
# 0  ...             1                       1                90     46_Sa
# 1  ...             1                       2                88     45_Sa
# 2  ...             1                       3                25  13_CmANo
# 3  ...             1                       4                80     41_Sa
# 4  ...             1                       5                71   36_SaNo
#
#                   TimeDelta         RT  TimeOut                TimeStampBegin  \
# 0 0 days 00:00:25.825714432  25.825715    False 2021-11-18 10:22:23.050529792
# 1 0 days 00:00:25.492403456  25.492404    False 2021-11-18 10:22:49.152516864
# 2 0 days 00:00:19.030518016  19.030518    False 2021-11-18 10:23:14.911271936
# 3 0 days 00:00:17.538549248  17.538549    False 2021-11-18 10:23:34.213599744
# 4 0 days 00:00:04.151518464   4.151519    False 2021-11-18 10:23:52.016517632
#
#                    TimeStampEnd      Angle
# 0 2021-11-18 10:22:48.876244224  15.294643
# 1 2021-11-18 10:23:14.644920320  14.686119
# 2 2021-11-18 10:23:33.941789952  25.987650
# 3 2021-11-18 10:23:51.752148992  20.002567
# 4 2021-11-18 10:23:56.168036096   9.460410
#
# [5 rows x 30 columns]

# %%
final[['avatarID', 'ImageName']]
# Out:
#       avatarID ImageName
# 0           46     46_Sa
# 1           45     45_Sa
# 2           13  13_CmANo
# 3           41     41_Sa
# 4           36   36_SaNo
# ...        ...       ...
# 10075       45   45_SaNo
# 10076       34   34_SaNo
# 10077       31   31_SaNo
# 10078       30   30_SaNo
# 10079       39   39_SaNo
#
# [10080 rows x 2 columns]

# %%
PointingTask = final.to_csv('Results/PointingTask_exp1.csv')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10080 entries, 0 to 10079
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      10080 non-null  int64
#  1   ParticipantPosition_x          10080 non-null  float64
#  2   ParticipantPosition_z          10080 non-null  float64
#  3   PointerPosition_x              10080 non-null  float64
#  4   PointerPosition_z              10080 non-null  float64
#  5   PointerDirection_x             10080 non-null  float64
#  6   PointerDirection_z             10080 non-null  float64
#  7   PointerDirection_y             10080 non-null  float64
#  8   TargetBuildingPosition_x       10080 non-null  float64
#  9   TargetBuildingPosition_z       10080 non-null  float64
#  10  DistanceToParticipant          10080 non-null  float64
#  11  avatarID                       10080 non-null  object
#  12  AvatarPresence                 10080 non-null  bool
#  13  AvatarPresenceCategory         10080 non-null  object
#  14  meaningful                     10080 non-null  bool
#  15  meaningfulBuilding             10080 non-null  object
#  16  StartPointID                   10080 non-null  int64
#  17  PointingTaskStartingLocations  10080 non-null  object
#  18  Trials                         10080 non-null  object
#  19  TrialNumber                    10080 non-null  int64
#  20  StartPointID                   10080 non-null  int64
#  21  ID_for_StartingPosition        10080 non-null  int64
#  22  ImageIndexNumber               10080 non-null  int64
#  23  ImageName                      10080 non-null  object
#  24  TimeDelta                      10080 non-null  timedelta64[ns]
#  25  RT                             10080 non-null  float64
#  26  TimeOut                        10080 non-null  bool
#  27  TimeStampBegin                 10080 non-null  datetime64[ns]
#  28  TimeStampEnd                   10080 non-null  datetime64[ns]
#  29  Angle                          10080 non-null  float64
# dtypes: bool(3), datetime64[ns](2), float64(12), int64(6), object(6), timedelta64[ns](1)
# memory usage: 2.2+ MB
