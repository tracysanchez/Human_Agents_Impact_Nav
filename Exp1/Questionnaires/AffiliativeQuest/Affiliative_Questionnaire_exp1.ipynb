# %% [markdown]
# ## Affiliative Questionnaire

# %% [markdown]
# ## Import packages

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.anova import *
import pingouin as pg

# %% [markdown]
# ## Function creation
#
# 1. reverseScoring: Reserse scores likert scales. It requires three arguments:
#     - **df** = your data frame,
#     - **high** = 1 + highest score available
#     - **cols** = the columns you want reversed in list form

# %%
def reverseScoring(df, high, cols):
    '''Reverse scores on given columns
Parameters
-------------
     df: your data frame,
     high: 1 + highest score available
     cols: the columns you want reversed in list form
Returns
------------
     dataFrame '''
    
    df[cols] = 1 + high - df[cols]
    return df

# %% [markdown]
# 2. indexNans: Gets the row index of Nans cointained in a dataFrame
#     - **df**= Your data Frame

# %%
def indexNans(df):
    '''Get row index of all Nans in a data frame
Parameters
----------
    df:  Data frame
Returns
-------
    List
'''
    booleanMaskNaNs = df.isna() #Dataframe with boolen of NaNs
    rowsWithNaNs = df[(booleanMaskNaNs == 1).any(axis=1)] # Keeps only rows with NaNs
    index = rowsWithNaNs.index # Gets index of rows with NaNs
    return list(index)

# %% [markdown]
# 3.dataImputation: Fills in Nan and changes them for the average score of the subject on the scale:
#     - **DF** = Data frame for imputation

# %%
def Imputation(DF=None):
    '''Replace NaN values with subject average
    Parameters
----------
    df:  Data frame
Returns
-------
    Data frame'''
    index = indexNans(DF)
    for row in DF.iterrows():
        for element in index: 
            DF.loc[element] = DF.loc[element].fillna(round(DF.iloc[element,2:6].mean()))   
    return DF

# %%
os.chdir("/Volumes/TwoTeras/0_Experiment_1/Questionnaires/")

# %% [markdown]
# ## Preprocessing

# %%
# Data set loading

df_file = "AffiliativeQuest_exp1.csv"
df = pd.read_csv(df_file, sep= ';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Timestamp                                               29 non-null     object
#  1   ID                                                      29 non-null     int64
#  2   1. I prefer to work in group instead of by myself ​     29 non-null     int64
#  3   2. I spend a lot of time talking to others              28 non-null     float64
#  4   3. I like to study with groups rather than by myself​   29 non-null     int64
#  5   4. I try to work alone ​                                29 non-null     int64
#  6   5. I prefer to work on my own and let others do theirs  29 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.7+ KB

# %%
#Renaming the column names 
column_names = ['timeStamp', 'ID', 'item1', 'item2', 'item3', 'item4', 'item5']
df.columns = column_names
df.head()
# Out:
#              timeStamp    ID  item1  item2  item3  item4  item5
# 0       11.12.21 16:36  8469      3    6.0      2      5      3
# 1  11/15/2021 15:06:20  7264      1    NaN      1      6      6
# 2  11/17/2021 13:38:04  3572      5    4.0      3      4      4
# 3  11/18/2021 12:15:48   365      6    6.0      4      3      3
# 4  11/30/2021 11:33:24  6642      5    5.0      3      5      3

# %%
#Recodifying the negatively phrased items 
reverseScoring(df,7,['item4','item5'])
# Out:
#               timeStamp    ID  item1  item2  item3  item4  item5
# 0        11.12.21 16:36  8469      3    6.0      2      3      5
# 1   11/15/2021 15:06:20  7264      1    NaN      1      2      2
# 2   11/17/2021 13:38:04  3572      5    4.0      3      4      4
# 3   11/18/2021 12:15:48   365      6    6.0      4      5      5
# 4   11/30/2021 11:33:24  6642      5    5.0      3      3      5
# 5        12.03.21 17:28  5741      2    5.0      3      2      2
# 6        12.10.21 12:32  7842      5    5.0      2      2      3
# 7   12/15/2021 11:16:55  4176      2    5.0      3      5      2
# 8   12/22/2021 16:53:24  9472      5    5.0      4      4      5
# 9    1/18/2022 12:54:26  4623      2    2.0      2      3      2
# 10   1/19/2022 11:33:27  9502      5    3.0      1      1      2
# 11   1/20/2022 16:58:51  7093      3    6.0      3      3      3
# 12   2/28/2022 10:35:05  2258      5    7.0      4      2      7
# 13   3/16/2022 14:21:12  1754      2    1.0      2      3      4
# 14   3/21/2022 12:42:12  5238      6    6.0      6      4      3
# 15   3/23/2022 15:42:37  8695      5    7.0      5      4      3
# 16   4/20/2022 20:46:47  3976      2    4.0      2      2      2
# 17   4/21/2022 12:37:20  5531      5    6.0      5      6      6
# 18       05.04.22 15:07  7412      4    5.0      2      3      3
# 19       05.06.22 09:59  4796      7    4.0      6      6      6
# 20   5/13/2022 15:03:35  3246      3    3.0      1      5      3
# 21   5/18/2022 10:09:38  9601      3    4.0      3      3      3
# 22   5/30/2022 11:41:52   479      6    7.0      7      7      7
# 23       06.01.22 14:52  8007      3    3.0      3      3      2
# 24       06.03.22 09:33  8673      3    7.0      5      4      3
# 25    6/16/2022 9:55:07  9586      2    2.0      2      1      2
# 26   6/16/2022 13:40:53  2693      5    5.0      2      3      4
# 27   6/20/2022 11:20:41  3310      4    7.0      5      4      5
# 28       07.04.22 11:24  4917      7    5.0      6      6      7

# %%
df1 = Imputation(df)
df1.head()
# Out:
#              timeStamp    ID  item1  item2  item3  item4  item5
# 0       11.12.21 16:36  8469      3    6.0      2      3      5
# 1  11/15/2021 15:06:20  7264      1    1.0      1      2      2
# 2  11/17/2021 13:38:04  3572      5    4.0      3      4      4
# 3  11/18/2021 12:15:48   365      6    6.0      4      5      5
# 4  11/30/2021 11:33:24  6642      5    5.0      3      3      5

# %%
# Calculating the average for all context items 
df1['AffiliativeQ_average'] = df1[['item1', 'item2', 'item3','item4','item5']].mean(axis=1)
df1.head()
# Out:
#              timeStamp    ID  item1  item2  item3  item4  item5  \
# 0       11.12.21 16:36  8469      3    6.0      2      3      5
# 1  11/15/2021 15:06:20  7264      1    1.0      1      2      2
# 2  11/17/2021 13:38:04  3572      5    4.0      3      4      4
# 3  11/18/2021 12:15:48   365      6    6.0      4      5      5
# 4  11/30/2021 11:33:24  6642      5    5.0      3      3      5
#
#    AffiliativeQ_average
# 0                   3.8
# 1                   1.4
# 2                   4.0
# 3                   5.2
# 4                   4.2

# %% [markdown]
# ## Write to CSV

# %%
df1.to_csv('Results/AffilliativeTend_exp1.csv')

# %%
# From a wide format to a long format 
Long = pd.melt(df1, id_vars=['ID'], value_vars=['item1', 'item2', 'item3', 'item4', 'item5', 'AffiliativeQ_average'], var_name='item', value_name='score')
Long.head()
# Out:
#      ID   item  score
# 0  8469  item1    3.0
# 1  7264  item1    1.0
# 2  3572  item1    5.0
# 3   365  item1    6.0
# 4  6642  item1    5.0

# %%
Affiliative = df1[['item1', 'item2', 'item3', 'item4', 'item5']]
pg.cronbach_alpha(data=Affiliative, ci=.99)
# Out:
# (0.8764977202841693, array([0.749, 0.948]))

# %% [markdown]
# ## Data Visualization

# %%
sns.set_palette('colorblind')
dy='item'; dx='score'; data=Long
fig, ax = plt.subplots(figsize=(15,5))
sns.boxplot(data= data, x=dy, y=dx, ax=ax)
sns.swarmplot(data= data, x=dy, y=dx, ax=ax)
plt.show()

# %%
data.describe()
# Out:
#                 ID       score
# count   174.000000  174.000000
# mean   5687.344828    3.875862
# std    2756.986219    1.651411
# min     365.000000    1.000000
# 25%    3572.000000    2.800000
# 50%    5531.000000    4.000000
# 75%    8007.000000    5.000000
# max    9601.000000    7.000000

# %%
fig, ax = plt.subplots(figsize=(15,5))
sns.violinplot(data= Long, x=dy, y=dx, ax=ax)
sns.swarmplot(data= Long, x=dy, y=dx,  ax=ax, linewidth=1)

plt.show()
# Out:
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.1, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
