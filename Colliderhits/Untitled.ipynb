# %%
import pandas as pd

# %%
path = "/Volumes/SSD/6258_PointingTask_Randomization_1666084297.70049.json"
with open(path, 'r') as file:
        # make json files parsable
        data = "[" + file.read()
        data = data[:len(data)-1] + "]"

        # read data per file
        subjectdf = pd.read_json(data)

        # insert participant id in every line
        subjectdf.insert(0, "SubjectID", [int(path[13:17])] * subjectdf.shape[0], True)

# %%
subjectdf.head()
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       6258           6258  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                        PointingTaskStartingLocations  \
# 0  [4, 25, 27, 13, 26, 6, 11, 23, 21, 19, 24, 10,...
#
#                PointingTaskTargets_1           PointingTaskTargets_2  \
# 0  [28, 43, 99, 99, 107, 22, 92, 41]  [9, 85, 27, 32, 25, 31, 14, 2]
#
#               PointingTaskTargets_3  ...             PointingTaskTargets_19  \
# 0  [54, 93, 10, 36, 34, 54, 34, 28]  ...  [77, 24, 75, 107, 50, 64, 23, 36]
#
#             PointingTaskTargets_20             PointingTaskTargets_21  \
# 0  [44, 56, 89, 6, 97, 37, 97, 85]  [100, 13, 13, 87, 38, 54, 46, 62]
#
#               PointingTaskTargets_22           PointingTaskTargets_23  \
# 0  [104, 71, 8, 104, 22, 25, 52, 54]  [27, 73, 48, 0, 93, 89, 44, 58]
#
#             PointingTaskTargets_24             PointingTaskTargets_25  \
# 0  [67, 77, 0, 24, 52, 56, 55, 13]  [19, 101, 18, 46, 31, 23, 89, 12]
#
#             PointingTaskTargets_26            PointingTaskTargets_27  \
# 0  [2, 90, 55, 31, 13, 66, 30, 63]  [69, 76, 85, 80, 83, 64, 70, 71]
#
#              PointingTaskTargets_28
# 0  [81, 76, 65, 60, 75, 77, 77, 63]
#
# [1 rows x 35 columns]

# %%
StartingPoints = pd.DataFrame(subjectdf.explode('PointingTaskStartingLocations'))
StartingPoints.head()
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       6258           6258  [PointingTask]  English
# 0       6258           6258  [PointingTask]  English
# 0       6258           6258  [PointingTask]  English
# 0       6258           6258  [PointingTask]  English
# 0       6258           6258  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#   PointingTaskStartingLocations              PointingTaskTargets_1  \
# 0                             4  [28, 43, 99, 99, 107, 22, 92, 41]
# 0                            25  [28, 43, 99, 99, 107, 22, 92, 41]
# 0                            27  [28, 43, 99, 99, 107, 22, 92, 41]
# 0                            13  [28, 43, 99, 99, 107, 22, 92, 41]
# 0                            26  [28, 43, 99, 99, 107, 22, 92, 41]
#
#             PointingTaskTargets_2             PointingTaskTargets_3  ...  \
# 0  [9, 85, 27, 32, 25, 31, 14, 2]  [54, 93, 10, 36, 34, 54, 34, 28]  ...
# 0  [9, 85, 27, 32, 25, 31, 14, 2]  [54, 93, 10, 36, 34, 54, 34, 28]  ...
# 0  [9, 85, 27, 32, 25, 31, 14, 2]  [54, 93, 10, 36, 34, 54, 34, 28]  ...
# 0  [9, 85, 27, 32, 25, 31, 14, 2]  [54, 93, 10, 36, 34, 54, 34, 28]  ...
# 0  [9, 85, 27, 32, 25, 31, 14, 2]  [54, 93, 10, 36, 34, 54, 34, 28]  ...
#
#               PointingTaskTargets_19           PointingTaskTargets_20  \
# 0  [77, 24, 75, 107, 50, 64, 23, 36]  [44, 56, 89, 6, 97, 37, 97, 85]
# 0  [77, 24, 75, 107, 50, 64, 23, 36]  [44, 56, 89, 6, 97, 37, 97, 85]
# 0  [77, 24, 75, 107, 50, 64, 23, 36]  [44, 56, 89, 6, 97, 37, 97, 85]
# 0  [77, 24, 75, 107, 50, 64, 23, 36]  [44, 56, 89, 6, 97, 37, 97, 85]
# 0  [77, 24, 75, 107, 50, 64, 23, 36]  [44, 56, 89, 6, 97, 37, 97, 85]
#
#               PointingTaskTargets_21             PointingTaskTargets_22  \
# 0  [100, 13, 13, 87, 38, 54, 46, 62]  [104, 71, 8, 104, 22, 25, 52, 54]
# 0  [100, 13, 13, 87, 38, 54, 46, 62]  [104, 71, 8, 104, 22, 25, 52, 54]
# 0  [100, 13, 13, 87, 38, 54, 46, 62]  [104, 71, 8, 104, 22, 25, 52, 54]
# 0  [100, 13, 13, 87, 38, 54, 46, 62]  [104, 71, 8, 104, 22, 25, 52, 54]
# 0  [100, 13, 13, 87, 38, 54, 46, 62]  [104, 71, 8, 104, 22, 25, 52, 54]
#
#             PointingTaskTargets_23           PointingTaskTargets_24  \
# 0  [27, 73, 48, 0, 93, 89, 44, 58]  [67, 77, 0, 24, 52, 56, 55, 13]
# 0  [27, 73, 48, 0, 93, 89, 44, 58]  [67, 77, 0, 24, 52, 56, 55, 13]
# 0  [27, 73, 48, 0, 93, 89, 44, 58]  [67, 77, 0, 24, 52, 56, 55, 13]
# 0  [27, 73, 48, 0, 93, 89, 44, 58]  [67, 77, 0, 24, 52, 56, 55, 13]
# 0  [27, 73, 48, 0, 93, 89, 44, 58]  [67, 77, 0, 24, 52, 56, 55, 13]
#
#               PointingTaskTargets_25           PointingTaskTargets_26  \
# 0  [19, 101, 18, 46, 31, 23, 89, 12]  [2, 90, 55, 31, 13, 66, 30, 63]
# 0  [19, 101, 18, 46, 31, 23, 89, 12]  [2, 90, 55, 31, 13, 66, 30, 63]
# 0  [19, 101, 18, 46, 31, 23, 89, 12]  [2, 90, 55, 31, 13, 66, 30, 63]
# 0  [19, 101, 18, 46, 31, 23, 89, 12]  [2, 90, 55, 31, 13, 66, 30, 63]
# 0  [19, 101, 18, 46, 31, 23, 89, 12]  [2, 90, 55, 31, 13, 66, 30, 63]
#
#              PointingTaskTargets_27            PointingTaskTargets_28
# 0  [69, 76, 85, 80, 83, 64, 70, 71]  [81, 76, 65, 60, 75, 77, 77, 63]
# 0  [69, 76, 85, 80, 83, 64, 70, 71]  [81, 76, 65, 60, 75, 77, 77, 63]
# 0  [69, 76, 85, 80, 83, 64, 70, 71]  [81, 76, 65, 60, 75, 77, 77, 63]
# 0  [69, 76, 85, 80, 83, 64, 70, 71]  [81, 76, 65, 60, 75, 77, 77, 63]
# 0  [69, 76, 85, 80, 83, 64, 70, 71]  [81, 76, 65, 60, 75, 77, 77, 63]
#
# [5 rows x 35 columns]

# %%
StartingPointsnorm = pd.json_normalize(subjectdf["InitialOrientation"]).add_prefix("InitialOrientation_")
StartingPointsnorm.head()
# Out:
#    InitialOrientation_x  InitialOrientation_y  InitialOrientation_z  \
# 0              0.000819             -0.906321             -0.001439
#
#    InitialOrientation_w
# 0             -0.422586

# %%
# %timeit -r 4 -n 1000 StartingPoints = pd.DataFrame(subjectdf.explode('PointingTaskStartingLocations'))
# %timeit -r 4 -n 1000 StartingPointsnorm = pd.json_normalize(subjectdf["InitialOrientation"])
# Out:
# 3.12 ms ± 70.9 µs per loop (mean ± std. dev. of 4 runs, 1000 loops each)
# 520 µs ± 12.8 µs per loop (mean ± std. dev. of 4 runs, 1000 loops each)

# %%
subjectdf["PointingTaskRandomised"][0]
# Out:
# [{'Block': 1,
#   'LocationNumber': 1,
#   'StartingPositionRandom': 4,
#   'TargetLocationsRandom': [28, 43, 99, 99, 107, 22, 92, 41]},
#  {'Block': 1,
#   'LocationNumber': 2,
#   'StartingPositionRandom': 25,
#   'TargetLocationsRandom': [9, 85, 27, 32, 25, 31, 14, 2]},
#  {'Block': 1,
#   'LocationNumber': 3,
#   'StartingPositionRandom': 27,
#   'TargetLocationsRandom': [54, 93, 10, 36, 34, 54, 34, 28]},
#  {'Block': 1,
#   'LocationNumber': 4,
#   'StartingPositionRandom': 13,
#   'TargetLocationsRandom': [73, 25, 40, 71, 91, 93, 83, 73]},
#  {'Block': 1,
#   'LocationNumber': 5,
#   'StartingPositionRandom': 26,
#   'TargetLocationsRandom': [53, 101, 11, 62, 24, 34, 43, 15]},
#  {'Block': 1,
#   'LocationNumber': 6,
#   'StartingPositionRandom': 6,
#   'TargetLocationsRandom': [66, 101, 67, 104, 100, 44, 74, 12]},
#  {'Block': 1,
#   'LocationNumber': 7,
#   'StartingPositionRandom': 11,
#   'TargetLocationsRandom': [59, 34, 34, 42, 100, 9, 59, 44]},
#  {'Block': 1,
#   'LocationNumber': 8,
#   'StartingPositionRandom': 23,
#   'TargetLocationsRandom': [72, 105, 19, 15, 80, 13, 47, 51]},
#  {'Block': 1,
#   'LocationNumber': 9,
#   'StartingPositionRandom': 21,
#   'TargetLocationsRandom': [54, 69, 72, 13, 42, 87, 69, 88]},
#  {'Block': 1,
#   'LocationNumber': 10,
#   'StartingPositionRandom': 19,
#   'TargetLocationsRandom': [104, 23, 80, 50, 42, 40, 28, 63]},
#  {'Block': 1,
#   'LocationNumber': 11,
#   'StartingPositionRandom': 24,
#   'TargetLocationsRandom': [28, 12, 57, 58, 40, 84, 44, 41]},
#  {'Block': 1,
#   'LocationNumber': 12,
#   'StartingPositionRandom': 10,
#   'TargetLocationsRandom': [79, 101, 30, 15, 28, 47, 52, 53]},
#  {'Block': 1,
#   'LocationNumber': 13,
#   'StartingPositionRandom': 8,
#   'TargetLocationsRandom': [16, 50, 30, 84, 61, 81, 83, 76]},
#  {'Block': 1,
#   'LocationNumber': 14,
#   'StartingPositionRandom': 1,
#   'TargetLocationsRandom': [58, 49, 76, 41, 9, 57, 30, 64]},
#  {'Block': 1,
#   'LocationNumber': 15,
#   'StartingPositionRandom': 17,
#   'TargetLocationsRandom': [102, 64, 51, 1, 101, 104, 13, 97]},
#  {'Block': 1,
#   'LocationNumber': 16,
#   'StartingPositionRandom': 3,
#   'TargetLocationsRandom': [28, 84, 75, 98, 39, 73, 76, 88]},
#  {'Block': 1,
#   'LocationNumber': 17,
#   'StartingPositionRandom': 9,
#   'TargetLocationsRandom': [28, 108, 82, 103, 56, 1, 58, 41]},
#  {'Block': 1,
#   'LocationNumber': 18,
#   'StartingPositionRandom': 2,
#   'TargetLocationsRandom': [93, 111, 102, 7, 2, 31, 21, 70]},
#  {'Block': 1,
#   'LocationNumber': 19,
#   'StartingPositionRandom': 20,
#   'TargetLocationsRandom': [77, 24, 75, 107, 50, 64, 23, 36]},
#  {'Block': 1,
#   'LocationNumber': 20,
#   'StartingPositionRandom': 5,
#   'TargetLocationsRandom': [44, 56, 89, 6, 97, 37, 97, 85]},
#  {'Block': 1,
#   'LocationNumber': 21,
#   'StartingPositionRandom': 7,
#   'TargetLocationsRandom': [100, 13, 13, 87, 38, 54, 46, 62]},
#  {'Block': 1,
#   'LocationNumber': 22,
#   'StartingPositionRandom': 15,
#   'TargetLocationsRandom': [104, 71, 8, 104, 22, 25, 52, 54]},
#  {'Block': 1,
#   'LocationNumber': 23,
#   'StartingPositionRandom': 18,
#   'TargetLocationsRandom': [27, 73, 48, 0, 93, 89, 44, 58]},
#  {'Block': 1,
#   'LocationNumber': 24,
#   'StartingPositionRandom': 14,
#   'TargetLocationsRandom': [67, 77, 0, 24, 52, 56, 55, 13]},
#  {'Block': 1,
#   'LocationNumber': 25,
#   'StartingPositionRandom': 22,
#   'TargetLocationsRandom': [19, 101, 18, 46, 31, 23, 89, 12]},
#  {'Block': 1,
#   'LocationNumber': 26,
#   'StartingPositionRandom': 0,
#   'TargetLocationsRandom': [2, 90, 55, 31, 13, 66, 30, 63]},
#  {'Block': 1,
#   'LocationNumber': 27,
#   'StartingPositionRandom': 12,
#   'TargetLocationsRandom': [69, 76, 85, 80, 83, 64, 70, 71]},
#  {'Block': 1,
#   'LocationNumber': 28,
#   'StartingPositionRandom': 16,
#   'TargetLocationsRandom': [81, 76, 65, 60, 75, 77, 77, 63]}]

# %%
normalized = pd.json_normalize(subjectdf["PointingTaskRandomised"][0])
normalized.head()
# Out:
#    Block  LocationNumber  StartingPositionRandom  \
# 0      1               1                       4
# 1      1               2                      25
# 2      1               3                      27
# 3      1               4                      13
# 4      1               5                      26
#
#                TargetLocationsRandom
# 0  [28, 43, 99, 99, 107, 22, 92, 41]
# 1     [9, 85, 27, 32, 25, 31, 14, 2]
# 2   [54, 93, 10, 36, 34, 54, 34, 28]
# 3   [73, 25, 40, 71, 91, 93, 83, 73]
# 4  [53, 101, 11, 62, 24, 34, 43, 15]

# %%
Final = pd.DataFrame(normalized.explode('TargetLocationsRandom'))
Final.head()
# Out:
#    Block  LocationNumber  StartingPositionRandom TargetLocationsRandom
# 0      1               1                       4                    28
# 0      1               1                       4                    43
# 0      1               1                       4                    99
# 0      1               1                       4                    99
# 0      1               1                       4                   107

# %%
pd.json_normalize(subjectdf.PointingTaskStartingLocations")
# Out:
#   File "<ipython-input-10-3246c7ab22f1>", line 1
#     pd.json_normalize(subjectdf.PointingTaskStartingLocations")
#                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
Dataset = pd.DataFrame()

# %%
# %%timeit -r 4 -n 1000
StartingPointsnorm = pd.json_normalize(subjectdf["InitialOrientation"]).add_suffix('_InitialOrientation')
StartingPointsnorm.head()
