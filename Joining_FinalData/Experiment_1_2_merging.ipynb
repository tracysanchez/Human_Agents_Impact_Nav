# %% [markdown]
# # Joining experiment one and two

# %%
import pandas as pd 
import numpy as np

# %%
Exp_1 = pd.read_csv("/Volumes/TwoTeras/2_DataSets_Experiments_1_2/humanA_Behavioural.csv")
Exp_2 = pd.read_csv("/Volumes/TwoTeras/2_DataSets_Experiments_1_2/humanA_Behavioural_Building_withoutSuf.csv")

# %%
Exp_1.head()
# Out:
#    Unnamed: 0     ID  Alter   Global  Overview  Cardinal  \
# 0           0  365.0    37.0     5.6  6.285714       2.5
# 1           1  365.0    37.0     5.6  6.285714       2.5
# 2           2  365.0    37.0     5.6  6.285714       2.5
# 3           3  365.0    37.0     5.6  6.285714       2.5
# 4           4  365.0    37.0     5.6  6.285714       2.5
#
#    AffiliativeQ_average  item3  ContextQ_average  remember_action_likert  ...  \
# 0                   5.2    2.0               3.5                2.714286  ...
# 1                   5.2    2.0               3.5                2.714286  ...
# 2                   5.2    2.0               3.5                2.714286  ...
# 3                   5.2    2.0               3.5                2.714286  ...
# 4                   5.2    2.0               3.5                2.714286  ...
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0             197.768723                           21.0          1.0
# ...

# %%
Exp_1["Experiment"] = 1
Exp_2["Experiment"] = 2

# %%
Exp_2.head(30)
# Out:
#     Unnamed: 0    ID  Alter   Global  Overview  Cardinal  \
# 0            0  8629    23.0     4.3  5.714286       2.0
# 1            1  8629    23.0     4.3  5.714286       2.0
# 2            2  8629    23.0     4.3  5.714286       2.0
# 3            3  8629    23.0     4.3  5.714286       2.0
# 4            4  8629    23.0     4.3  5.714286       2.0
# 5            5  8629    23.0     4.3  5.714286       2.0
# 6            6  8629    23.0     4.3  5.714286       2.0
# 7            7  8629    23.0     4.3  5.714286       2.0
# 8            8  8629    23.0     4.3  5.714286       2.0
# 9            9  8629    23.0     4.3  5.714286       2.0
# 10          10  8629    23.0     4.3  5.714286       2.0
# 11          11  8629    23.0     4.3  5.714286       2.0
# 12          12  8629    23.0     4.3  5.714286       2.0
# 13          13  8629    23.0     4.3  5.714286       2.0
# 14          14  8629    23.0     4.3  5.714286       2.0
# ...

# %%
Exp_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4259 entries, 0 to 4258
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     4259 non-null   int64
#  1   ID                             4259 non-null   int64
#  2   Alter                          4258 non-null   float64
#  3   Global                         4258 non-null   float64
#  4   Overview                       4258 non-null   float64
#  5   Cardinal                       4258 non-null   float64
#  6   AffiliativeQ_average           3808 non-null   float64
#  7   item3                          3808 non-null   float64
#  8   ContextQ_average               3808 non-null   float64
#  9   remember_action_likert         4029 non-null   float64
#  10  remember_standing_likert       4029 non-null   float64
#  11  attractive_action_likert       4029 non-null   float64
# ...

# %%
Exp_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10049 entries, 0 to 10048
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10049 non-null  int64
#  1   ID                             10049 non-null  float64
#  2   Alter                          9718 non-null   float64
#  3   Global                         9718 non-null   float64
#  4   Overview                       9718 non-null   float64
#  5   Cardinal                       9718 non-null   float64
#  6   AffiliativeQ_average           9382 non-null   float64
#  7   item3                          9382 non-null   float64
#  8   ContextQ_average               9382 non-null   float64
#  9   remember_action_likert         9713 non-null   float64
#  10  remember_standing_likert       9713 non-null   float64
#  11  attractive_action_likert       9713 non-null   float64
# ...

# %%
Exp_2.rename(columns={"BuildingCategory": "meaningfulBuilding"}, inplace=True)

# %%
result = pd.concat([Exp_1, Exp_2], axis=0)

# %%
result.tail()
# Out:
#       Unnamed: 0      ID  Alter   Global  Overview  Cardinal  \
# 4254        4254  1268.0    22.0     4.9  4.571429       1.0
# 4255        4255  7823.0    22.0     4.7  3.000000       3.0
# 4256        4256  4875.0    26.0     4.5  3.833333       4.0
# 4257        4257  1574.0    23.0     5.8  2.857143       3.0
# 4258        4258  4508.0     NaN     NaN       NaN       NaN
#
#       AffiliativeQ_average  item3  ContextQ_average  remember_action_likert  \
# 4254                   3.4    3.0               5.0                     NaN
# 4255                   NaN    NaN               NaN                     NaN
# 4256                   NaN    NaN               NaN                     NaN
# 4257                   4.2    4.0               6.0                     NaN
# 4258                   4.8    3.0               2.0                     NaN
#
#       ...  PointingTaskStartingLocations  TrialNumber  StartPointID  \
# 4254  ...                            NaN          NaN           NaN
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14308 entries, 0 to 4258
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     14308 non-null  int64
#  1   ID                             14308 non-null  float64
#  2   Alter                          13976 non-null  float64
#  3   Global                         13976 non-null  float64
#  4   Overview                       13976 non-null  float64
#  5   Cardinal                       13976 non-null  float64
#  6   AffiliativeQ_average           13190 non-null  float64
#  7   item3                          13190 non-null  float64
#  8   ContextQ_average               13190 non-null  float64
#  9   remember_action_likert         13742 non-null  float64
#  10  remember_standing_likert       13742 non-null  float64
#  11  attractive_action_likert       13742 non-null  float64
# ...

# %%
result
# Out:
#       Unnamed: 0      ID  Alter   Global  Overview  Cardinal  \
# 0              0   365.0    37.0     5.6  6.285714       2.5
# 1              1   365.0    37.0     5.6  6.285714       2.5
# 2              2   365.0    37.0     5.6  6.285714       2.5
# 3              3   365.0    37.0     5.6  6.285714       2.5
# 4              4   365.0    37.0     5.6  6.285714       2.5
# ...          ...     ...     ...     ...       ...       ...
# 4254        4254  1268.0    22.0     4.9  4.571429       1.0
# 4255        4255  7823.0    22.0     4.7  3.000000       3.0
# 4256        4256  4875.0    26.0     4.5  3.833333       4.0
# 4257        4257  1574.0    23.0     5.8  2.857143       3.0
# 4258        4258  4508.0     NaN     NaN       NaN       NaN
#
#       AffiliativeQ_average  item3  ContextQ_average  remember_action_likert  \
# 0                      5.2    2.0               3.5                2.714286
# 1                      5.2    2.0               3.5                2.714286
# ...

# %%
result.tail()
# Out:
#       Unnamed: 0      ID  Alter   Global  Overview  Cardinal  \
# 4254        4254  1268.0    22.0     4.9  4.571429       1.0
# 4255        4255  7823.0    22.0     4.7  3.000000       3.0
# 4256        4256  4875.0    26.0     4.5  3.833333       4.0
# 4257        4257  1574.0    23.0     5.8  2.857143       3.0
# 4258        4258  4508.0     NaN     NaN       NaN       NaN
#
#       AffiliativeQ_average  item3  ContextQ_average  remember_action_likert  \
# 4254                   3.4    3.0               5.0                     NaN
# 4255                   NaN    NaN               NaN                     NaN
# 4256                   NaN    NaN               NaN                     NaN
# 4257                   4.2    4.0               6.0                     NaN
# 4258                   4.8    3.0               2.0                     NaN
#
#       ...  PointingTaskStartingLocations  TrialNumber  StartPointID  \
# 4254  ...                            NaN          NaN           NaN
# ...

# %%
result["Agent_Action_level"] = np.where(np.isnan(result["avatarID"]), np.nan, np.where(result["avatarID"] > 28, "Passive", "Active"))

# %%
result[["avatarID","Agent_Action_level"]].head(50)
# Out:
#     avatarID Agent_Action_level
# 0       46.0            Passive
# 1       46.0            Passive
# 2       46.0            Passive
# 3       46.0            Passive
# 4       46.0            Passive
# 5       46.0            Passive
# 6       46.0            Passive
# 7       46.0            Passive
# 8       46.0            Passive
# 9       46.0            Passive
# 10      45.0            Passive
# 11      45.0            Passive
# 12      45.0            Passive
# 13      45.0            Passive
# 14      45.0            Passive
# 15      13.0             Active
# 16      13.0             Active
# 17      13.0             Active
# 18      13.0             Active
# 19      13.0             Active
# 20      13.0             Active
# 21      41.0            Passive
# 22      41.0            Passive
# 23      41.0            Passive
# 24      41.0            Passive
# 25      41.0            Passive
# 26      41.0            Passive
# 27      36.0            Passive
# ...

# %%
Buildings_tags = pd.read_csv("/Volumes/SSD/Experiments_1_2/humanA_Behavioural_Building.csv")
Buildings_tags.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Buildings_tags = pd.read_csv("/Volumes/SSD/Experiments_1_2/humanA_Behavioural_Building.csv")
#       2 Buildings_tags.columns
#
# ...

# %%
Buildings_tags.head()

# %%
Buildings_tags["Agent_Action_level"] = np.where(np.isnan(Buildings_tags["avatarID_Building"]), np.nan, np.where(Buildings_tags["avatarID_Building"] > 28, "Passive", "Active"))

# %%
Buildings_tags.to_csv("/Volumes/SSD/Experiments_1_2/humanA_Behavioural_Building.csv")

# %%
result.to_csv("/Volumes/SSD/Experiments_1_2/Experiments.csv")

# %%
experiment_1 = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/Data_Sets/BehavioralData_Fixations_Wide.csv")
experiment_1.rename({"meaningfulBuilding":"BuildingCategory"}, axis=1, inplace=True)
experiment_1 = pd.read_csv("/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/Data_Sets/BehavioralData_Fixations_Wide.csv")

# %%
len(experiment_1.SubjectID.unique())
# Out:
# 30

# %%
experiment_1.columns

# %%
experiment_1["Experiment"] = 1
experiment_2["Experiment"] = 2

frames = [experiment_1, experiment_2]
result = pd.concat(frames)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16538 entries, 0 to 6489
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0.1                   16538 non-null  int64
#  1   Unnamed: 0                     16538 non-null  int64
#  2   SubjectID                      16538 non-null  int64
#  3   AbsolutError                   16538 non-null  float64
#  4   SignedAngle-+180               16538 non-null  float64
#  5   IQR                            16538 non-null  float64
#  6   RT                             16538 non-null  float64
#  7   DistanceToParticipant          16538 non-null  float64
#  8   PointingTaskStartingLocations  16538 non-null  int64
#  9   TrialNumber                    16538 non-null  int64
#  10  StartPointID                   16538 non-null  int64
#  11  ID_for_StartingPosition        16538 non-null  int64
# ...

# %%
result.to_csv("/Volumes/TwoTeras/2_DataSets_Experiments_1_2/BehavioralData_Fixations_Wide.csv")
