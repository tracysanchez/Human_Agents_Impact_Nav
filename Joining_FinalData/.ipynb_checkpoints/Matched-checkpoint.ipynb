# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Load the datasets
eyetracking_data = pd.read_csv("D:\MasterThesis\Experiment_1\Complete_Data\Complete_Data_AngularV.csv")
pointing_data = pd.read_csv("D:\MasterThesis\Experiment_1\PointingTask\PointingTask_Integrated_exp1.csv")

# %%
# Load your dataframes and filter for Subject 365
eyetracking_data_365 = eyetracking_data[eyetracking_data['SubjectID'] == 365]
pointing_data_365 = pointing_data[pointing_data['SubjectID'] == 365]

# Convert Unix timestamps to datetime format
eyetracking_data_365['timeStampDataPointStart'] = pd.to_datetime(eyetracking_data_365['timeStampDataPointStart'], unit='s')
eyetracking_data_365['timeStampDataPointEnd'] = pd.to_datetime(eyetracking_data_365['timeStampDataPointEnd'], unit='s')
pointing_data_365['TimeStampBegin'] = pd.to_datetime(pointing_data_365['TimeStampBegin'])
pointing_data_365['TimeStampEnd'] = pd.to_datetime(pointing_data_365['TimeStampEnd'])

aligned_data = []

# Set the reference timestamps based on eyetracking data
reference_start = eyetracking_data_365['timeStampDataPointStart'].min()
reference_end = eyetracking_data_365['timeStampDataPointEnd'].max()
reference_diff = (reference_end - reference_start).total_seconds()

for index, pointing_row in pointing_data_365.iterrows():
    subject_id = pointing_row['SubjectID']
    trial_number = pointing_row['TrialNumber']
    pointing_start = pointing_row['TimeStampBegin']
    pointing_end = pointing_row['TimeStampEnd']
    pointing_location = pointing_row['PointingTaskStartingLocations']
    
    # Calculate the relative duration within the pointing experiment
    pointing_duration = (pointing_end - pointing_start).total_seconds()
    pointing_duration_total = (pointing_data_365['TimeStampEnd'].max() - pointing_data_365['TimeStampBegin'].min()).total_seconds()
    if pointing_duration_total == 0:
        relative_duration = 0
    else:
        relative_duration = (pointing_start - pointing_data_365['TimeStampBegin'].min()).total_seconds() / pointing_duration_total
        relative_duration = max(0, min(relative_duration, 1))  # Clamp between 0 and 1
    
    # Calculate the time offset based on the reference
    time_offset = relative_duration * reference_diff
    
    # Calculate the corresponding eyetracking timestamps
    eyetracking_start = reference_start + pd.Timedelta(seconds=time_offset)
    eyetracking_end = eyetracking_start + pd.Timedelta(seconds=pointing_duration)
    
    # Filter relevant columns from eyetracking_data
    eyetracking_data_subset = eyetracking_data_365[(eyetracking_data_365['SubjectID'] == subject_id) &
                                                    (eyetracking_data_365['timeStampDataPointStart'] >= eyetracking_start) &
                                                    (eyetracking_data_365['timeStampDataPointEnd'] <= eyetracking_end)]
    
    # Add pointing trial info to eyetracking_data_subset
    eyetracking_data_subset['TrialNumber'] = trial_number
    eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
    
    # Append to the aligned_data list
    aligned_data.append(eyetracking_data_subset)

# Concatenate the aligned dataframes
aligned_data_df = pd.concat(aligned_data, ignore_index=True)

# Print the results
print(aligned_data_df)
# Out:
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_365['timeStampDataPointStart'] = pd.to_datetime(eyetracking_data_365['timeStampDataPointStart'], unit='s')
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_365['timeStampDataPointEnd'] = pd.to_datetime(eyetracking_data_365['timeStampDataPointEnd'], unit='s')
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pointing_data_365['TimeStampBegin'] = pd.to_datetime(pointing_data_365['TimeStampBegin'])
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pointing_data_365['TimeStampEnd'] = pd.to_datetime(pointing_data_365['TimeStampEnd'])
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['TrialNumber'] = trial_number
# C:\Users\Jule\AppData\Local\Temp\ipykernel_55588\1904888995.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eyetracking_data_subset['PointingTaskStartingLocations'] = pointing_location
#         Unnamed: 0  index  SubjectID  Eyetracking  \
# 0                0      0        365            1
# 1                1      1        365            1
# 2                2      2        365            1
# 3                3      3        365            1
# 4                4      4        365            1
# ...            ...    ...        ...          ...
# 111806       15943  15943        365            4
# 111807       15944  15944        365            4
# 111808       15945  15945        365            4
# 111809       15946  15946        365            4
# 111810       15947  15947        365            4
#
#              timeStampDataPointStart         timeStampDataPointEnd  \
# 0      2021-11-18 10:22:22.621986304 2021-11-18 10:22:22.624962048
# 1      2021-11-18 10:22:22.633890560 2021-11-18 10:22:22.636866304
# 2      2021-11-18 10:22:22.650754560 2021-11-18 10:22:22.653731072
# 3      2021-11-18 10:22:23.113523200 2021-11-18 10:22:23.116993792
# 4      2021-11-18 10:22:23.125426944 2021-11-18 10:22:23.128401408
# ...                              ...                           ...
# 111806 2021-11-18 11:04:40.447853568 2021-11-18 11:04:40.451325184
# 111807 2021-11-18 11:04:40.461245440 2021-11-18 11:04:40.464221184
# 111808 2021-11-18 11:04:40.473149952 2021-11-18 11:04:40.476125184
# 111809 2021-11-18 11:04:40.486045440 2021-11-18 11:04:40.488795648
# 111810 2021-11-18 11:04:40.499436800 2021-11-18 11:04:40.502413056
#
#         timeStampGetVerboseData  combinedGazeValidityBitmask  \
# 0                  1.637231e+09                            0
# 1                  1.637231e+09                            0
# 2                  1.637231e+09                            3
# 3                  1.637231e+09                            3
# 4                  1.637231e+09                            3
# ...                         ...                          ...
# 111806             1.637233e+09                            3
# 111807             1.637233e+09                            3
# 111808             1.637233e+09                            3
# 111809             1.637233e+09                            3
# 111810             1.637233e+09                            3
#
#                                   rayCastHitsCombinedEyes  \
# 0       [{'hitPointOnObject': {'x': -116.4806289672851...
# 1       [{'hitPointOnObject': {'x': -116.4808349609375...
# 2       [{'hitPointOnObject': {'x': 63.72035217285156,...
# 3       [{'hitPointOnObject': {'x': 23.45851707458496,...
# 4       [{'hitPointOnObject': {'x': 6.599761009216309,...
# ...                                                   ...
# 111806  [{'hitPointOnObject': {'x': 16.223018646240234...
# 111807  [{'hitPointOnObject': {'x': 16.17633056640625,...
# 111808  [{'hitPointOnObject': {'x': 16.15665054321289,...
# 111809  [{'hitPointOnObject': {'x': 16.149036407470703...
# 111810  [{'hitPointOnObject': {'x': 14.261116981506348...
#
#         eyePositionCombinedWorld.x  ...      isFix  corrected_vel  events  \
# 0                      -114.327370  ...        NaN            NaN     NaN
# 1                      -114.327370  ...   0.000000       0.000000     2.0
# 2                      -114.327370  ...   0.000000       0.000000     NaN
# 3                      -114.294662  ...   0.106728       0.106728     NaN
# 4                      -114.294388  ...   4.581290       4.581290     NaN
# ...                            ...  ...        ...            ...     ...
# 111806                  103.401474  ...   9.418235       9.418235     NaN
# 111807                  103.401695  ...  10.072397      10.072397     NaN
# 111808                  103.401695  ...   6.284784       6.284784     NaN
# 111809                  103.401695  ...   0.600902       0.600902     NaN
# 111810                  103.400871  ...   0.559074       0.559074     NaN
#
#           length    distance    avg_dist             names  \
# 0            NaN         NaN         NaN    pavement_K.002
# 1       0.513359  143.589519  143.571742    pavement_K.002
# 2       0.513359  143.589519  143.571742    pavement_K.002
# 3       0.513359  143.560421  143.571742    pavement_K.002
# 4       0.513359  143.560125  143.571742    pavement_K.002
# ...          ...         ...         ...               ...
# 111806  2.469583   87.297119   87.287404  CollisionObject1
# 111807  2.469583   87.297337   87.287404  CollisionObject1
# 111808  2.469583   87.297334   87.287404  CollisionObject1
# 111809  2.469583   87.297333   87.287404  CollisionObject1
# 111810  2.469583   87.296508   87.287404  CollisionObject1
#
#         Collider_CategoricalN  TrialNumber  PointingTaskStartingLocations
# 0                  Background            1                             21
# 1                  Background            1                             21
# 2                  Background            1                             21
# 3                  Background            1                             21
# 4                  Background            1                             21
# ...                       ...          ...                            ...
# 111806             Background          266                             11
# 111807             Background          266                             11
# 111808             Background          266                             11
# 111809             Background          266                             11
# 111810             Background          266                             11
#
# [111811 rows x 72 columns]

# %%
aligned_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111811 entries, 0 to 111810
# Data columns (total 72 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     111811 non-null  int64
#  1   index                          111811 non-null  int64
#  2   SubjectID                      111811 non-null  int64
#  3   Eyetracking                    111811 non-null  int64
#  4   timeStampDataPointStart        111811 non-null  datetime64[ns]
#  5   timeStampDataPointEnd          111811 non-null  datetime64[ns]
#  6   timeStampGetVerboseData        111811 non-null  float64
#  7   combinedGazeValidityBitmask    111811 non-null  int64
#  8   rayCastHitsCombinedEyes        111811 non-null  object
#  9   eyePositionCombinedWorld.x     111811 non-null  float64
#  10  eyePositionCombinedWorld.y     107876 non-null  float64
#  11  eyePositionCombinedWorld.z     107876 non-null  float64
#  12  eyeDirectionCombinedWorld.x    111811 non-null  float64
#  13  eyeDirectionCombinedWorld.y    111811 non-null  float64
#  14  eyeDirectionCombinedWorld.z    111811 non-null  float64
#  15  eyeDirectionCombinedLocal.x    111811 non-null  float64
#  16  eyeDirectionCombinedLocal.y    111811 non-null  float64
#  17  eyeDirectionCombinedLocal.z    111811 non-null  float64
#  18  hmdPosition.x                  111811 non-null  float64
#  19  hmdPosition.y                  111811 non-null  float64
#  20  hmdPosition.z                  111811 non-null  float64
#  21  hmdDirectionForward.x          111811 non-null  float64
#  22  hmdDirectionForward.y          111811 non-null  float64
#  23  hmdDirectionForward.z          111811 non-null  float64
#  24  hmdDirectionRight.x            111811 non-null  float64
#  25  hmdDirectionRight.y            111811 non-null  float64
#  26  hmdDirectionRight.z            111811 non-null  float64
#  27  hmdRotation.x                  111811 non-null  float64
#  28  hmdRotation.y                  111811 non-null  float64
#  29  hmdRotation.z                  111811 non-null  float64
#  30  hmdDirectionUp.x               111811 non-null  float64
#  31  hmdDirectionUp.y               111811 non-null  float64
#  32  hmdDirectionUp.z               111811 non-null  float64
#  33  playerBodyPosition.x           111811 non-null  float64
#  34  playerBodyPosition.y           111811 non-null  float64
#  35  playerBodyPosition.z           111811 non-null  float64
#  36  bodyTrackerPosition.x          111811 non-null  float64
#  37  bodyTrackerPosition.y          111811 non-null  float64
#  38  bodyTrackerPosition.z          111811 non-null  float64
#  39  bodyTrackerRotation.x          111811 non-null  float64
#  40  bodyTrackerRotation.y          111811 non-null  float64
#  41  bodyTrackerRotation.z          111811 non-null  float64
#  42  hitObjectColliderName          111811 non-null  object
#  43  hitColliderType                111811 non-null  object
#  44  hitObjectColliderBoundsCenter  111811 non-null  object
#  45  ordinalOfHit                   111811 non-null  float64
#  46  hitPointOnObject_x             107876 non-null  float64
#  47  hitPointOnObject_y             107876 non-null  float64
#  48  hitPointOnObject_z             107876 non-null  float64
#  49  Eucledian_distance             105404 non-null  float64
#  50  Collider_Categorical           111811 non-null  object
#  51  Face_Hits                      111811 non-null  object
#  52  Time_Shift                     111811 non-null  float64
#  53  Continuous_Time                111811 non-null  float64
#  54  Bitmask_flag                   111811 non-null  object
#  55  Interpolated_collider          111811 non-null  object
#  56  Collider_shift                 111811 non-null  bool
#  57  counter                        111811 non-null  float64
#  58  Time_of_Gaze                   0 non-null       float64
#  59  Gaze                           111811 non-null  object
#  60  combined_vel                   107280 non-null  float64
#  61  thresh                         111811 non-null  float64
#  62  isFix                          68230 non-null   float64
#  63  corrected_vel                  91259 non-null   float64
#  64  events                         21009 non-null   float64
#  65  length                         111810 non-null  float64
#  66  distance                       107258 non-null  float64
#  67  avg_dist                       111152 non-null  float64
#  68  names                          111811 non-null  object
#  69  Collider_CategoricalN          111811 non-null  object
#  70  TrialNumber                    111811 non-null  int64
#  71  PointingTaskStartingLocations  111811 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(51), int64(7), object(11)
# memory usage: 60.7+ MB

# %%
# Define the file path
csv_file_path = r'D:\MasterThesis\Experiment_1\Matching\aligned_data.csv'

# Save the dataframe to CSV
aligned_data_df.to_csv(csv_file_path, index=False)

print(f"Dataframe saved as {csv_file_path}")
# Out:
# Dataframe saved as D:\MasterThesis\Experiment_1\Matching\aligned_data.csv
