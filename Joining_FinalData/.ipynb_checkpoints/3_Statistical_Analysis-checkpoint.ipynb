# %%
# Define probability distribution for the response variable for the linear (LM) and logistic (GLM) model
family_LM = sm.families.Gaussian()
family_GLM = sm.families.Binomial()

# %% [markdown]
# ## Order effects

# %%
#Plotting KDE for first independent variable
ax = sns.kdeplot(x='AbsolutError', data= HumanAf, shade='fill', palette='Crest', alpha=.5, linewidth=0,)
ax.set_title("Absolut Errror distribution")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
#Plotting KDE for second independent variable
ax = sns.kdeplot(x='RT', data= HumanAf, shade='fill', palette='Crest', alpha=.5, linewidth=0,)
ax.set_title("Response time distribution")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Response time predicted by trial order in each starting location
formula = 'np.log(RT) ~ C(ID_for_StartingPosition, Treatment(reference=12))'

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
#                                 Mixed Linear Model Regression Results
# ======================================================================================================
# Model:                            MixedLM                Dependent Variable:                np.log(RT)
# No. Observations:                 9381                   Method:                            REML
# No. Groups:                       28                     Scale:                             0.3309
# Min. group size:                  329                    Log-Likelihood:                    -8208.7384
# Max. group size:                  336                    Converged:                         No
# Mean group size:                  335.0
# ------------------------------------------------------------------------------------------------------
#                                                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                                                    1.718    0.050 34.046 0.000  1.619  1.817
# C(ID_for_StartingPosition, Treatment(reference=12))[T.1.0]   1.016    0.029 34.844 0.000  0.959  1.073
# C(ID_for_StartingPosition, Treatment(reference=12))[T.2.0]   0.184    0.029  6.337 0.000  0.127  0.241
# C(ID_for_StartingPosition, Treatment(reference=12))[T.3.0]   0.103    0.029  3.530 0.000  0.046  0.160
# C(ID_for_StartingPosition, Treatment(reference=12))[T.4.0]   0.062    0.029  2.141 0.032  0.005  0.119
# C(ID_for_StartingPosition, Treatment(reference=12))[T.5.0]   0.086    0.029  2.975 0.003  0.030  0.143
# C(ID_for_StartingPosition, Treatment(reference=12))[T.6.0]   0.050    0.029  1.726 0.084 -0.007  0.107
# C(ID_for_StartingPosition, Treatment(reference=12))[T.7.0]   0.022    0.029  0.747 0.455 -0.035  0.079
# C(ID_for_StartingPosition, Treatment(reference=12))[T.8.0]   0.006    0.029  0.203 0.839 -0.051  0.063
# C(ID_for_StartingPosition, Treatment(reference=12))[T.9.0]   0.040    0.029  1.372 0.170 -0.017  0.097
# C(ID_for_StartingPosition, Treatment(reference=12))[T.10.0]  0.004    0.029  0.154 0.878 -0.053  0.061
# C(ID_for_StartingPosition, Treatment(reference=12))[T.11.0] -0.000    0.029 -0.010 0.992 -0.057  0.057
# Group Var                                                    0.059    0.023
# ======================================================================================================
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 16.239516
#   warnings.warn(msg, ConvergenceWarning)

# %%
#Plotting residual to check for a normal distribution
sns.kdeplot(model_LM.resid, shade='fill', palette='Crest', alpha=.5, linewidth=0)
ax.set_title("KDE Plot of Model Residuals (Blue) and Normal Distribution (Black)")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 17.200000000000003, 'Residuals')

# %% [markdown]
# ### CONCLUSION
# __________________
# Subjects are **significantly** slower on the first three trials in each pointing position.

# %%
# Response time predicted by trial order in each starting location
formula = 'np.log(AbsolutError) ~ C(ID_for_StartingPosition, Treatment(reference=12))'

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                                 Mixed Linear Model Regression Results
# ======================================================================================================
# Model:                        MixedLM             Dependent Variable:             np.log(AbsolutError)
# No. Observations:             9381                Method:                         REML
# No. Groups:                   28                  Scale:                          1.7225
# Min. group size:              329                 Log-Likelihood:                 -15931.9351
# Max. group size:              336                 Converged:                      Yes
# Mean group size:              335.0
# ------------------------------------------------------------------------------------------------------
#                                                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                                                    3.263    0.099 32.884 0.000  3.069  3.458
# C(ID_for_StartingPosition, Treatment(reference=12))[T.1.0]   0.069    0.067  1.033 0.302 -0.062  0.199
# C(ID_for_StartingPosition, Treatment(reference=12))[T.2.0]   0.020    0.066  0.305 0.760 -0.110  0.150
# C(ID_for_StartingPosition, Treatment(reference=12))[T.3.0]   0.035    0.066  0.525 0.599 -0.095  0.165
# C(ID_for_StartingPosition, Treatment(reference=12))[T.4.0]   0.038    0.066  0.572 0.567 -0.092  0.168
# C(ID_for_StartingPosition, Treatment(reference=12))[T.5.0]  -0.041    0.066 -0.618 0.537 -0.171  0.089
# C(ID_for_StartingPosition, Treatment(reference=12))[T.6.0]  -0.019    0.066 -0.290 0.772 -0.149  0.111
# C(ID_for_StartingPosition, Treatment(reference=12))[T.7.0]  -0.087    0.066 -1.306 0.191 -0.217  0.043
# C(ID_for_StartingPosition, Treatment(reference=12))[T.8.0]  -0.037    0.066 -0.564 0.573 -0.167  0.093
# C(ID_for_StartingPosition, Treatment(reference=12))[T.9.0]  -0.025    0.066 -0.370 0.712 -0.155  0.106
# C(ID_for_StartingPosition, Treatment(reference=12))[T.10.0] -0.014    0.066 -0.218 0.828 -0.144  0.116
# C(ID_for_StartingPosition, Treatment(reference=12))[T.11.0]  0.005    0.066  0.072 0.942 -0.125  0.135
# Group Var                                                    0.214    0.046
# ======================================================================================================

# %% [markdown]
# ### Result
# __________________
# Subjects do not significantly differ in their precision across time spent at pointing position.

# %%
#Plotting residual to check for a normal distribution
sns.kdeplot(model_LM.resid, shade='fill', palette='Crest', alpha=.5, linewidth=0)
ax.set_title("KDE Plot of Model Residuals (Blue) and Normal Distribution (Black)")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 17.200000000000003, 'Residuals')

# %%
# Response time predicted by trial order at the overall test
formula = 'np.log(AbsolutError) ~ C(StartPointID, Treatment(reference=14))'

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                            Mixed Linear Model Regression Results
# ===========================================================================================
# Model:                     MixedLM         Dependent Variable:         np.log(AbsolutError)
# No. Observations:          9381            Method:                     REML
# No. Groups:                28              Scale:                      1.7179
# Min. group size:           329             Log-Likelihood:             -15933.9895
# Max. group size:           336             Converged:                  Yes
# Mean group size:           335.0
# -------------------------------------------------------------------------------------------
#                                                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------------------
# Intercept                                         3.236    0.113 28.640 0.000  3.015  3.457
# C(StartPointID, Treatment(reference=14))[T.1.0]   0.256    0.102  2.510 0.012  0.056  0.456
# C(StartPointID, Treatment(reference=14))[T.2.0]  -0.040    0.101 -0.399 0.690 -0.239  0.158
# C(StartPointID, Treatment(reference=14))[T.3.0]  -0.001    0.101 -0.005 0.996 -0.199  0.198
# C(StartPointID, Treatment(reference=14))[T.4.0]   0.124    0.101  1.228 0.219 -0.074  0.323
# C(StartPointID, Treatment(reference=14))[T.5.0]  -0.021    0.101 -0.203 0.839 -0.219  0.178
# C(StartPointID, Treatment(reference=14))[T.6.0]   0.019    0.101  0.188 0.851 -0.179  0.217
# C(StartPointID, Treatment(reference=14))[T.7.0]   0.036    0.101  0.358 0.720 -0.162  0.234
# C(StartPointID, Treatment(reference=14))[T.8.0]   0.142    0.101  1.403 0.161 -0.056  0.340
# C(StartPointID, Treatment(reference=14))[T.9.0]  -0.129    0.101 -1.276 0.202 -0.327  0.069
# C(StartPointID, Treatment(reference=14))[T.10.0] -0.018    0.101 -0.176 0.861 -0.216  0.181
# C(StartPointID, Treatment(reference=14))[T.11.0]  0.017    0.101  0.166 0.869 -0.181  0.215
# C(StartPointID, Treatment(reference=14))[T.12.0] -0.075    0.101 -0.741 0.459 -0.273  0.123
# C(StartPointID, Treatment(reference=14))[T.13.0] -0.065    0.101 -0.641 0.521 -0.263  0.133
# C(StartPointID, Treatment(reference=14))[T.15.0]  0.077    0.101  0.765 0.444 -0.121  0.276
# C(StartPointID, Treatment(reference=14))[T.16.0] -0.033    0.101 -0.327 0.744 -0.231  0.165
# C(StartPointID, Treatment(reference=14))[T.17.0]  0.207    0.101  2.045 0.041  0.009  0.405
# C(StartPointID, Treatment(reference=14))[T.18.0] -0.023    0.101 -0.228 0.820 -0.221  0.175
# C(StartPointID, Treatment(reference=14))[T.19.0] -0.047    0.101 -0.459 0.646 -0.245  0.152
# C(StartPointID, Treatment(reference=14))[T.20.0] -0.043    0.101 -0.427 0.669 -0.242  0.155
# C(StartPointID, Treatment(reference=14))[T.21.0] -0.010    0.101 -0.094 0.925 -0.208  0.189
# C(StartPointID, Treatment(reference=14))[T.22.0] -0.069    0.101 -0.686 0.493 -0.268  0.129
# C(StartPointID, Treatment(reference=14))[T.23.0]  0.252    0.101  2.488 0.013  0.053  0.450
# C(StartPointID, Treatment(reference=14))[T.24.0]  0.090    0.101  0.889 0.374 -0.108  0.288
# C(StartPointID, Treatment(reference=14))[T.25.0]  0.007    0.101  0.074 0.941 -0.191  0.206
# C(StartPointID, Treatment(reference=14))[T.26.0] -0.054    0.101 -0.529 0.597 -0.252  0.145
# C(StartPointID, Treatment(reference=14))[T.27.0] -0.024    0.101 -0.235 0.814 -0.222  0.175
# C(StartPointID, Treatment(reference=14))[T.28.0]  0.058    0.101  0.576 0.565 -0.140  0.256
# Group Var                                         0.214    0.046
# ===========================================================================================

# %% [markdown]
# ### Result
# __________________
# Subjects are in average 1.5 seconds slower during  the first 10 trials

# %%
# Response time predicted by trial order for the overall test
formula = 'RT ~ C(StartPointID, Treatment(reference=27))'

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                           Mixed Linear Model Regression Results
# ==========================================================================================
# Model:                       MixedLM            Dependent Variable:            RT
# No. Observations:            9381               Method:                        REML
# No. Groups:                  28                 Scale:                         25.2444
# Min. group size:             329                Log-Likelihood:                -28504.6779
# Max. group size:             336                Converged:                     Yes
# Mean group size:             335.0
# ------------------------------------------------------------------------------------------
#                                                  Coef. Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------
# Intercept                                        6.089    0.461 13.195 0.000  5.184  6.993
# C(StartPointID, Treatment(reference=27))[T.1.0]  6.625    0.391 16.934 0.000  5.858  7.392
# C(StartPointID, Treatment(reference=27))[T.2.0]  5.030    0.388 12.956 0.000  4.269  5.791
# C(StartPointID, Treatment(reference=27))[T.3.0]  4.578    0.389 11.774 0.000  3.816  5.340
# C(StartPointID, Treatment(reference=27))[T.4.0]  4.379    0.388 11.281 0.000  3.619  5.140
# C(StartPointID, Treatment(reference=27))[T.5.0]  3.942    0.388 10.155 0.000  3.182  4.703
# C(StartPointID, Treatment(reference=27))[T.6.0]  2.959    0.388  7.621 0.000  2.198  3.719
# C(StartPointID, Treatment(reference=27))[T.7.0]  2.607    0.388  6.721 0.000  1.847  3.368
# C(StartPointID, Treatment(reference=27))[T.8.0]  2.359    0.388  6.080 0.000  1.598  3.119
# C(StartPointID, Treatment(reference=27))[T.9.0]  2.422    0.388  6.242 0.000  1.661  3.182
# C(StartPointID, Treatment(reference=27))[T.10.0] 3.074    0.388  7.919 0.000  2.313  3.835
# C(StartPointID, Treatment(reference=27))[T.11.0] 1.737    0.388  4.477 0.000  0.976  2.497
# C(StartPointID, Treatment(reference=27))[T.12.0] 1.243    0.388  3.205 0.001  0.483  2.004
# C(StartPointID, Treatment(reference=27))[T.13.0] 1.067    0.388  2.751 0.006  0.307  1.828
# C(StartPointID, Treatment(reference=27))[T.14.0] 0.613    0.388  1.581 0.114 -0.147  1.373
# C(StartPointID, Treatment(reference=27))[T.15.0] 1.112    0.388  2.867 0.004  0.352  1.873
# C(StartPointID, Treatment(reference=27))[T.16.0] 0.813    0.388  2.095 0.036  0.052  1.573
# C(StartPointID, Treatment(reference=27))[T.17.0] 0.831    0.388  2.143 0.032  0.071  1.592
# C(StartPointID, Treatment(reference=27))[T.18.0] 0.827    0.388  2.132 0.033  0.067  1.587
# C(StartPointID, Treatment(reference=27))[T.19.0] 1.677    0.389  4.317 0.000  0.916  2.439
# C(StartPointID, Treatment(reference=27))[T.20.0] 1.758    0.388  4.529 0.000  0.998  2.519
# C(StartPointID, Treatment(reference=27))[T.21.0] 0.835    0.388  2.150 0.032  0.074  1.596
# C(StartPointID, Treatment(reference=27))[T.22.0] 0.629    0.388  1.620 0.105 -0.132  1.390
# C(StartPointID, Treatment(reference=27))[T.23.0] 0.645    0.388  1.663 0.096 -0.115  1.406
# C(StartPointID, Treatment(reference=27))[T.24.0] 0.829    0.388  2.137 0.033  0.069  1.589
# C(StartPointID, Treatment(reference=27))[T.25.0] 0.689    0.388  1.777 0.076 -0.071  1.450
# C(StartPointID, Treatment(reference=27))[T.26.0] 0.359    0.388  0.925 0.355 -0.402  1.120
# C(StartPointID, Treatment(reference=27))[T.28.0] 0.176    0.388  0.453 0.651 -0.585  0.936
# Group Var                                        3.852    0.213
# ==========================================================================================

# %% [markdown]
# ### Result
# __________________
# Subjects accuracy does not increase throughout the task

# %% [markdown]
# ### CONCLUSION
# __________________
# Subjects accuracy does not improve through the task, but their responsable does. This could be evidence of a learning effect of the testing format that does not enhance their performance. Their knwoledge is stable throughout.

# %% [markdown]
# ## The two factor interaction: Meaningfulness*Presence

# %%
# Absolute predicted by Avatar Presence + Avatar Category
formula = "np.log(AbsolutError) ~ C(Context, Treatment(reference=False)) + C(AvatarPresenceCategory) + C(Context, Treatment(reference=False))*C(AvatarPresenceCategory)"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                                             Mixed Linear Model Regression Results
# ==============================================================================================================================
# Model:                                MixedLM                     Dependent Variable:                     np.log(AbsolutError)
# No. Observations:                     9381                        Method:                                 REML
# No. Groups:                           28                          Scale:                                  1.7197
# Min. group size:                      329                         Log-Likelihood:                         -15913.5130
# Max. group size:                      336                         Converged:                              Yes
# Mean group size:                      335.0
# ------------------------------------------------------------------------------------------------------------------------------
#                                                                                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                            3.280    0.091 35.865 0.000  3.100  3.459
# C(Context, Treatment(reference=False))[T.True]                                      -0.090    0.038 -2.354 0.019 -0.165 -0.015
# C(AvatarPresenceCategory)[T.Present]                                                 0.054    0.038  1.420 0.155 -0.021  0.129
# C(Context, Treatment(reference=False))[T.True]:C(AvatarPresenceCategory)[T.Present] -0.013    0.054 -0.243 0.808 -0.120  0.093
# Group Var                                                                            0.214    0.046
# ==============================================================================================================================

# %%
HumanAf[["ID", "avatarID", "PointingTaskStartingLocations", "StartPointID"]] = HumanAf[["ID", "avatarID", "PointingTaskStartingLocations", "StartPointID"]].astype(int)
HumanAf[["ID", "avatarID", "PointingTaskStartingLocations", "StartPointID"]] = HumanAf[["ID", "avatarID", "PointingTaskStartingLocations", "StartPointID"]].values.astype(str)

# %%
HumanAf["ID_StartPointID"] =str(HumanAf['ID']) + "_" + str(HumanAf['StartPointID'])

# %%
# Absolute predicted by Avatar Presence + Avatar Category
formula = "np.log(AbsolutError) ~  C(Context, Treatment(reference=False)) + C(AvatarPresenceCategory)  + C(AvatarPresenceCategory)*C(Context, Treatment(reference=False))"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID_StartPointID']).fit()
print(model_LM.summary())
# Out:
#                                               Mixed Linear Model Regression Results
# =================================================================================================================================
# Model:                                 MixedLM                      Dependent Variable:                      np.log(AbsolutError)
# No. Observations:                      9381                         Method:                                  REML
# No. Groups:                            1                            Scale:                                   1.9260
# Min. group size:                       9381                         Log-Likelihood:                          -16394.0763
# Max. group size:                       9381                         Converged:                               Yes
# Mean group size:                       9381.0
# ---------------------------------------------------------------------------------------------------------------------------------
#                                                                                     Coef.    Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                            3.264       1.388  2.351 0.019  0.543  5.984
# C(Context, Treatment(reference=False))[T.True]                                      -0.059       0.041 -1.445 0.148 -0.138  0.021
# C(AvatarPresenceCategory)[T.Present]                                                 0.086       0.040  2.122 0.034  0.007  0.165
# C(AvatarPresenceCategory)[T.Present]:C(Context, Treatment(reference=False))[T.True] -0.077       0.057 -1.340 0.180 -0.189  0.036
# Group Var                                                                            1.926 9244532.270
# =================================================================================================================================

# %%
HumanAf["ID_PointingTaskStartingLocations"] = HumanAf.loc[:,"ID"] + "_" + HumanAf.loc[:,"PointingTaskStartingLocations"]

# %%
HumanAf["ID_PointingTaskStartingLocations"].head()
# Out:
# 0    365_21
# 1    365_16
# 2    365_13
# 3    365_13
# 4     365_8
# Name: ID_PointingTaskStartingLocations, dtype: object

# %%
# Whithout global landmarks
HumanAfnoL = HumanAf[(HumanAf.avatarID != 27) | (HumanAf.avatarID != 28) | (HumanAf.avatarID != 55)| (HumanAf.avatarID != 56)]

# %%
# Absolute predicted by Avatar Presence + Avatar Category
formula = "np.log(AbsolutError) ~ C(Context, Treatment(reference=False)) + C(AvatarPresenceCategory) + C(Context, Treatment(reference=False)):C(AvatarPresenceCategory)"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID_PointingTaskStartingLocations']).fit()
print(model_LM.summary())
# Out:
#                                             Mixed Linear Model Regression Results
# ==============================================================================================================================
# Model:                                MixedLM                     Dependent Variable:                     np.log(AbsolutError)
# No. Observations:                     9381                        Method:                                 REML
# No. Groups:                           784                         Scale:                                  1.6275
# Min. group size:                      9                           Log-Likelihood:                         -16059.4527
# Max. group size:                      12                          Converged:                              Yes
# Mean group size:                      12.0
# ------------------------------------------------------------------------------------------------------------------------------
#                                                                                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                            3.271    0.033 98.753 0.000  3.206  3.336
# C(Context, Treatment(reference=False))[T.True]                                      -0.066    0.038 -1.703 0.089 -0.141  0.010
# C(AvatarPresenceCategory)[T.Present]                                                 0.069    0.038  1.802 0.071 -0.006  0.144
# C(Context, Treatment(reference=False))[T.True]:C(AvatarPresenceCategory)[T.Present] -0.058    0.054 -1.062 0.288 -0.165  0.049
# Group Var                                                                            0.299    0.018
# ==============================================================================================================================

# %%
from statsmodels.stats.anova import AnovaRM
print(AnovaRM(data=HumanAfnoL, depvar='RT', subject='ID', within=['Context', 'AvatarPresenceCategory'], aggregate_func = 'mean').fit())
# Out:
#                            Anova
# ============================================================
#                                F Value Num DF  Den DF Pr > F
# ------------------------------------------------------------
# Context                         0.2085 1.0000 27.0000 0.6516
# AvatarPresenceCategory          1.3191 1.0000 27.0000 0.2608
# Context:AvatarPresenceCategory  1.9845 1.0000 27.0000 0.1703
# ============================================================

# %%
#Plotting residual to check for a normal distribution
sns.kdeplot(model_LM.resid, shade='fill', palette='Crest', alpha=.5, linewidth=0)
ax.set_title("KDE Plot of Model Residuals (Blue) and Normal Distribution (Black)")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 17.200000000000003, 'Residuals')

# %%
# Response time predicted by Avatar Presence
formula = "np.log(RT) ~ C(Context, Treatment(reference=False)) + C(AvatarPresenceCategory) + C(Context, Treatment(reference=False))*C(AvatarPresenceCategory)"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
#                                             Mixed Linear Model Regression Results
# ==============================================================================================================================
# Model:                                    MixedLM                        Dependent Variable:                        np.log(RT)
# No. Observations:                         9381                           Method:                                    REML
# No. Groups:                               28                             Scale:                                     0.4033
# Min. group size:                          329                            Log-Likelihood:                            -9120.0793
# Max. group size:                          336                            Converged:                                 No
# Mean group size:                          335.0
# ------------------------------------------------------------------------------------------------------------------------------
#                                                                                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                            1.840    0.055 33.406 0.000  1.732  1.947
# C(Context, Treatment(reference=False))[T.True]                                       0.044    0.019  2.364 0.018  0.008  0.080
# C(AvatarPresenceCategory)[T.Present]                                                -0.011    0.019 -0.606 0.545 -0.048  0.025
# C(Context, Treatment(reference=False))[T.True]:C(AvatarPresenceCategory)[T.Present] -0.031    0.026 -1.189 0.235 -0.083  0.020
# Group Var                                                                            0.080    0.037
# ==============================================================================================================================
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 3.796513
#   warnings.warn(msg, ConvergenceWarning)

# %%
HumanAf.groupby('Context')['AbsolutError'].median()
# Out:
# Context
# False    37.237238
# True     31.087897
# Name: AbsolutError, dtype: float64

# %%
HumanAf.groupby(['Context'])['RT'].std()
# Out:
# Context
# False    5.711605
# True     5.525178
# Name: RT, dtype: float64

# %%
# Absolut error predicted by location
formula = "np.log(AbsolutError) ~ C(avatarID)"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:            MixedLM Dependent Variable: np.log(AbsolutError)
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              1.6336
# Min. group size:  329     Log-Likelihood:     -15714.4183
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# -------------------------------------------------------------------
#                     Coef.   Std.Err.    z     P>|z|  [0.025  0.975]
# -------------------------------------------------------------------
# Intercept            2.992     0.129  23.206  0.000   2.739   3.244
# C(avatarID)[T.10]    0.584     0.140   4.185  0.000   0.310   0.857
# C(avatarID)[T.11]   -0.109     0.139  -0.782  0.434  -0.382   0.164
# C(avatarID)[T.12]    0.658     0.136   4.836  0.000   0.391   0.924
# C(avatarID)[T.13]    0.360     0.137   2.632  0.008   0.092   0.629
# C(avatarID)[T.14]    0.594     0.135   4.414  0.000   0.330   0.858
# C(avatarID)[T.15]    0.107     0.136   0.785  0.432  -0.160   0.374
# C(avatarID)[T.16]    0.240     0.130   1.847  0.065  -0.015   0.495
# C(avatarID)[T.17]    0.123     0.138   0.892  0.373  -0.147   0.393
# C(avatarID)[T.18]    0.451     0.143   3.156  0.002   0.171   0.731
# C(avatarID)[T.19]    0.287     0.139   2.070  0.038   0.015   0.560
# C(avatarID)[T.2]     0.406     0.140   2.906  0.004   0.132   0.679
# C(avatarID)[T.20]   -0.113     0.141  -0.805  0.421  -0.389   0.163
# C(avatarID)[T.21]   -0.238     0.134  -1.779  0.075  -0.499   0.024
# C(avatarID)[T.22]    0.266     0.135   1.964  0.050   0.001   0.531
# C(avatarID)[T.23]    0.306     0.135   2.266  0.023   0.041   0.571
# C(avatarID)[T.24]    0.858     0.142   6.038  0.000   0.579   1.136
# C(avatarID)[T.25]   -0.044     0.141  -0.313  0.754  -0.321   0.232
# C(avatarID)[T.26]    0.493     0.138   3.572  0.000   0.222   0.763
# C(avatarID)[T.27]   -0.047     0.133  -0.352  0.725  -0.307   0.213
# C(avatarID)[T.28]   -0.064     0.138  -0.465  0.642  -0.334   0.206
# C(avatarID)[T.29]    0.293     0.137   2.143  0.032   0.025   0.560
# C(avatarID)[T.3]     0.124     0.139   0.888  0.375  -0.149   0.396
# C(avatarID)[T.30]    0.047     0.144   0.327  0.744  -0.235   0.329
# C(avatarID)[T.31]    0.593     0.136   4.344  0.000   0.325   0.860
# C(avatarID)[T.32]    0.336     0.142   2.370  0.018   0.058   0.614
# C(avatarID)[T.33]    0.446     0.132   3.375  0.001   0.187   0.705
# C(avatarID)[T.34]    0.463     0.137   3.389  0.001   0.195   0.730
# C(avatarID)[T.35]    0.503     0.135   3.716  0.000   0.238   0.769
# C(avatarID)[T.36]    0.521     0.142   3.671  0.000   0.243   0.800
# C(avatarID)[T.37]    0.195     0.137   1.428  0.153  -0.073   0.463
# C(avatarID)[T.38]    0.502     0.137   3.658  0.000   0.233   0.771
# C(avatarID)[T.39]    0.534     0.138   3.861  0.000   0.263   0.805
# C(avatarID)[T.4]     0.151     0.137   1.099  0.272  -0.118   0.420
# C(avatarID)[T.40]    0.592     0.139   4.270  0.000   0.320   0.864
# C(avatarID)[T.41]    0.539     0.133   4.067  0.000   0.279   0.799
# C(avatarID)[T.42]    0.393     0.140   2.815  0.005   0.119   0.667
# C(avatarID)[T.43]    0.189     0.137   1.379  0.168  -0.080   0.457
# C(avatarID)[T.44]    0.293     0.142   2.067  0.039   0.015   0.571
# C(avatarID)[T.45]    0.417     0.137   3.050  0.002   0.149   0.685
# C(avatarID)[T.46]   -0.030     0.136  -0.219  0.827  -0.297   0.237
# C(avatarID)[T.47]    0.441     0.137   3.215  0.001   0.172   0.709
# C(avatarID)[T.48]   -0.068     0.135  -0.503  0.615  -0.333   0.197
# C(avatarID)[T.49]    0.361     0.143   2.518  0.012   0.080   0.642
# C(avatarID)[T.5]    -0.042     0.137  -0.309  0.757  -0.312   0.227
# C(avatarID)[T.50]    0.603     0.136   4.440  0.000   0.337   0.870
# C(avatarID)[T.51]    0.384     0.134   2.861  0.004   0.121   0.648
# C(avatarID)[T.52]    0.018     0.133   0.134  0.893  -0.242   0.278
# C(avatarID)[T.53]    0.569     0.136   4.197  0.000   0.303   0.835
# C(avatarID)[T.54]    0.748     0.134   5.563  0.000   0.485   1.012
# C(avatarID)[T.55]   -1.055     0.140  -7.547  0.000  -1.329  -0.781
# C(avatarID)[T.56]   -0.155     0.136  -1.134  0.257  -0.422   0.113
# C(avatarID)[T.6]     0.356     0.139   2.559  0.010   0.083   0.629
# C(avatarID)[T.7]     0.569     0.134   4.233  0.000   0.305   0.832
# C(avatarID)[T.8]    -0.073     0.139  -0.525  0.600  -0.345   0.199
# C(avatarID)[T.9]    -0.027     0.143  -0.190  0.850  -0.307   0.253
# Group Var            0.212     0.046
# ==================================================================

# %% [markdown]
# ## FRS questionnaire analysis

# %%
# Absolut error predicted by FRS
formula = "np.log(RT) ~ Global + Overview + Cardinal"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#          Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: np.log(RT)
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              0.4037
# Min. group size:  329     Log-Likelihood:     -9120.1481
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# --------------------------------------------------------
#               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------
# Intercept      1.986    0.247  8.057 0.000  1.503  2.469
# Global         0.039    0.059  0.662 0.508 -0.076  0.154
# Overview      -0.073    0.040 -1.841 0.066 -0.151  0.005
# Cardinal      -0.009    0.052 -0.167 0.868 -0.110  0.093
# Group Var      0.073    0.034
# ========================================================

# %%
# Absolut error predicted by FRS
formula = "AbsolutError ~ Global + Overview + Cardinal"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#           Mixed Linear Model Regression Results
# ==========================================================
# Model:            MixedLM Dependent Variable: AbsolutError
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              1808.6960
# Min. group size:  329     Log-Likelihood:     -48533.5394
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# -----------------------------------------------------------
#             Coef.   Std.Err.    z     P>|z|  [0.025  0.975]
# -----------------------------------------------------------
# Intercept   68.484    13.211   5.184  0.000  42.592  94.376
# Global      -3.443     3.152  -1.092  0.275  -9.621   2.735
# Overview     0.784     2.129   0.368  0.713  -3.389   4.957
# Cardinal    -3.328     2.772  -1.201  0.230  -8.761   2.104
# Group Var  207.599     1.448
# ==========================================================

# %%
#Plotting residual to check for a normal distribution
ax = sns.kdeplot(model_LM.resid, shade='fill', palette='Crest', alpha=.5, linewidth=0)
ax.set_title("KDE Plot of Model Residuals for  log transform of absolut error")
ax.set_xlabel("Residuals")
# Out:
# Text(0.5, 0, 'Residuals')

# %%
# Response Time predicted by FRS
formula = "np.log(RT) ~ Global + Overview + Cardinal"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#          Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: np.log(RT)
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              0.4037
# Min. group size:  329     Log-Likelihood:     -9120.1481
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# --------------------------------------------------------
#               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------
# Intercept      1.986    0.247  8.057 0.000  1.503  2.469
# Global         0.039    0.059  0.662 0.508 -0.076  0.154
# Overview      -0.073    0.040 -1.841 0.066 -0.151  0.005
# Cardinal      -0.009    0.052 -0.167 0.868 -0.110  0.093
# Group Var      0.073    0.034
# ========================================================

# %% [markdown]
# ## Avatar questionnaire analysis

# %%
# Response time predicted by Avatar Presence

# %%
# Isolating the avatar Quest variables for correlation
HumanAavatarQ = HumanAf[['remember_action_likert', 'remember_standing_likert', 'attractive_action_likert', 'attractive_standing_likert', 'realistic_action_likert', 'realistic_standing_likert' ]]

# %%
sns.set(rc={"figure.figsize":(18, 8)})
sns.set(font_scale = 1.3)
from matplotlib import cm
initial_cmap = cm.get_cmap('YlGnBu')
reversed_cmap=initial_cmap.reversed()

fig, ax = plt.subplots(nrows=1,ncols=2)

#Calculates pearsons r matrix
corrMatrix = HumanAavatarQ.corr()
#Creates a mask that eliminates the 1s
mask = np.triu(np.ones_like(corrMatrix, dtype=bool))
#Calculates spearmans s
cor, pval = stats.spearmanr(corrMatrix.T)
#Heatmap plotting
sns.heatmap(cor, annot=True, cmap="YlGnBu", mask=mask, ax=ax[0]).set(title="Spearman's rank correlation coefficients(ρ)")
sns.heatmap(pval, annot=True, cmap=reversed_cmap, mask=mask, ax=ax[1]).set(title="Probability values for Spearman's rank correlation")
#sns.heatmap(corrMatrix, annot=True, cmap="YlGnBu", mask=mask,ax=[2])

for ax in ax.ravel():
    ax.set_xticklabels(['Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful'], rotation=80);
    ax.set_yticklabels(['Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful'], rotation=360);
plt.tight_layout()
plt.show()

# %%
stats.spearmanr(HumanAavatarQ.remember_standing_likert, HumanAavatarQ.remember_action_likert)
# Out:
# SpearmanrResult(correlation=0.6121283746824386, pvalue=0.0)

# %%
HumanAavatarQ.head()
# Out:
#    remember_action_likert  remember_standing_likert  attractive_action_likert  \
# 0                2.714286                  1.107143                  2.214286
# 1                2.714286                  1.107143                  2.214286
# 2                2.714286                  1.107143                  2.214286
# 3                2.714286                  1.107143                  2.214286
# 4                2.714286                  1.107143                  2.214286
#
#    attractive_standing_likert  realistic_action_likert  \
# 0                    1.178571                 3.392857
# 1                    1.178571                 3.392857
# 2                    1.178571                 3.392857
# 3                    1.178571                 3.392857
# 4                    1.178571                 3.392857
#
#    realistic_standing_likert
# 0                   1.964286
# 1                   1.964286
# 2                   1.964286
# 3                   1.964286
# 4                   1.964286

# %% [markdown]
# ## Calculating a factorial analysis on the questionnaire

# %%
AvatarQuest= pd.read_csv('/Users/tracysanchezpacheco/Documents/Resources/AvatarQuestcsv.csv')
AvatarQuest.drop('Unnamed: 0', axis=1, inplace=True)
AvatarQuest.head()
# Out:
#      ID  Atractive 1  Atractive 2  Atractive 3  Atractive 4  Atractive 5  \
# 0   365            1            3            2            2            3
# 1   479            1            1            1            1            1
# 2  1754            3            4            4            3            5
# 3  2258            2            2            2            2            2
# 4  2693            1            4            2            1            1
#
#    Atractive 6  Atractive 7  Atractive 8  Atractive 9  ...  Remember 47  \
# 0            4            2            2            5  ...            1
# 1            1            1            1            1  ...            1
# 2            4            3            3            4  ...            1
# 3            3            2            2            2  ...            2
# 4            2            1            1            3  ...            1
#
#    Remember 48  Remember 49  Remember 50  Remember 51  Remember 52  \
# 0            1            1            1            1            1
# 1            3            1            5            3            2
# 2            2            1            1            1            1
# 3            2            2            1            1            2
# 4            1            1            1            1            1
#
#    Remember 53  Remember 54  Remember 55  Remember 56
# 0            1            1            1            1
# 1            2            1            3            3
# 2            1            1            1            1
# 3            1            1            2            3
# 4            1            1            1            1
#
# [5 rows x 169 columns]

# %%
b = list(range(1,57))
Attractive= AvatarQuest.iloc[: , b].copy()
Attractive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 56 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Atractive 1   29 non-null     int64
#  1   Atractive 2   29 non-null     int64
#  2   Atractive 3   29 non-null     int64
#  3   Atractive 4   29 non-null     int64
#  4   Atractive 5   29 non-null     int64
#  5   Atractive 6   29 non-null     int64
#  6   Atractive 7   29 non-null     int64
#  7   Atractive 8   29 non-null     int64
#  8   Atractive 9   29 non-null     int64
#  9   Atractive 10  29 non-null     int64
#  10  Atractive 11  29 non-null     int64
#  11  Atractive 12  29 non-null     int64
#  12  Atractive 13  29 non-null     int64
#  13  Atractive 14  29 non-null     int64
#  14  Atractive 15  29 non-null     int64
#  15  Atractive 16  29 non-null     int64
#  16  Atractive 17  29 non-null     int64
#  17  Atractive 18  29 non-null     int64
#  18  Atractive 19  29 non-null     int64
#  19  Atractive 20  29 non-null     int64
#  20  Atractive 21  29 non-null     int64
#  21  Atractive 22  29 non-null     int64
#  22  Atractive 23  29 non-null     int64
#  23  Atractive 24  29 non-null     int64
#  24  Atractive 25  29 non-null     int64
#  25  Atractive 26  29 non-null     int64
#  26  Atractive 27  29 non-null     int64
#  27  Atractive 28  29 non-null     int64
#  28  Atractive 29  29 non-null     int64
#  29  Atractive 30  29 non-null     int64
#  30  Atractive 31  29 non-null     int64
#  31  Atractive 32  29 non-null     int64
#  32  Atractive 33  29 non-null     int64
#  33  Atractive 34  29 non-null     int64
#  34  Atractive 35  29 non-null     int64
#  35  Atractive 36  29 non-null     int64
#  36  Atractive 37  29 non-null     int64
#  37  Atractive 38  29 non-null     int64
#  38  Atractive 39  29 non-null     int64
#  39  Atractive 40  29 non-null     int64
#  40  Atractive 41  29 non-null     int64
#  41  Atractive 42  29 non-null     int64
#  42  Atractive 43  29 non-null     int64
#  43  Atractive 44  29 non-null     int64
#  44  Atractive 45  29 non-null     int64
#  45  Atractive 46  29 non-null     int64
#  46  Atractive 47  29 non-null     int64
#  47  Atractive 48  29 non-null     int64
#  48  Atractive 49  29 non-null     int64
#  49  Atractive 50  29 non-null     int64
#  50  Atractive 51  29 non-null     int64
#  51  Atractive 52  29 non-null     int64
#  52  Atractive 53  29 non-null     int64
#  53  Atractive 54  29 non-null     int64
#  54  Atractive 55  29 non-null     int64
#  55  Atractive 56  29 non-null     int64
# dtypes: int64(56)
# memory usage: 12.8 KB

# %%
sns.set(rc={"figure.figsize":(36, 36)})
sns.set(font_scale = 1.3)
from matplotlib import cm
initial_cmap = cm.get_cmap('YlGnBu')
reversed_cmap=initial_cmap.reversed()

fig, ax = plt.subplots(nrows=2,ncols=1)

#Calculates pearsons r matrix
corrMatrix = Attractive.corr()
#Creates a mask that eliminates the 1s
mask = np.triu(np.ones_like(corrMatrix, dtype=bool))
#Calculates spearmans s
cor, pval = stats.spearmanr(corrMatrix.T)
#Heatmap plotting
sns.heatmap(cor, annot=True, cmap="YlGnBu", mask=mask, ax=ax[0]).set(title="Spearman's rank correlation coefficients(ρ)")
sns.heatmap(pval, annot=True, cmap=reversed_cmap, mask=mask, ax=ax[1]).set(title="Probability values for Spearman's rank correlation")
#sns.heatmap(corrMatrix, annot=True, cmap="YlGnBu", mask=mask,ax=[2])
plt.tight_layout()
plt.show()

# %%
corrMatrix.T
# Out:
#               Atractive 1  Atractive 2  Atractive 3  Atractive 4  Atractive 5  \
# Atractive 25      0.644928      0.360435      0.308864
# Atractive 26      0.611043      0.257765      0.363453
# Atractive 27      0.451087      0.477541      0.112220
# Atractive 28      0.458785      0.379193      0.399683
# Atractive 29      0.560262      0.531308      0.442970
# Atractive 30      0.170962      0.279070      0.265719
# Atractive 31      0.419765      0.515606      0.448478
# Atractive 32      0.554484      0.510194      0.413447
# Atractive 33      0.235074      0.472456      0.035501
# Atractive 34      0.336680      0.122495      0.695206
# Atractive 35      0.575422      0.509073      0.489563
# Atractive 36      0.772847      0.523678      0.496631
# Atractive 37      0.366508      0.420752      0.249377
# Atractive 38      0.680332      0.543344      0.407777
# Atractive 39      0.309117      0.462050      0.359268
# Atractive 40      0.687691      0.646765      0.484198
# Atractive 41      0.600298      0.468327      0.533595
# Atractive 42      0.605862      0.588350      0.383997
# Atractive 43      0.513149      0.395288      0.479257
# Atractive 44      0.615563      0.594399      0.477003
# Atractive 45      0.554717      0.623641      0.313799
# Atractive 46      0.508502      0.435299      0.429093
# Atractive 47      0.642867      0.556722      0.644865
# Atractive 48      0.374110      0.362992      0.244963
# Atractive 49      0.452000      0.213334      0.464569
# Atractive 50      0.589610      0.369506      0.527181
# Atractive 51      0.281434      0.461401      0.352015
# Atractive 52      0.887849      0.743223      0.448764
# Atractive 53      0.177350      0.281718      0.141753
# Atractive 54      1.000000      0.692376      0.490683
# Atractive 55      0.692376      1.000000      0.461481
# Atractive 56      0.490683      0.461481      1.000000
#
# [56 rows x 56 columns]

# %%
from sklearn.datasets import load_iris
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

#Droppin Nas
HumanAavatarQ.dropna(inplace=True);

#Adecuacy test

#Barlets sphericity: A significative p value indicates the date is different from an identity matrix
chi_square_value,p_value= calculate_bartlett_sphericity(HumanAavatarQ)
print(chi_square_value,p_value)

# Kaiser-Meyer-Olkin (KMO): Estimates the proportion of variance among all observed variables, less than 0.6 is inadequate
kmo_all,kmo_model=calculate_kmo(HumanAavatarQ)
print(kmo_model)
#Create factor analysis object and perform analysis
fa= FactorAnalyzer(rotation='varimax')
fa.fit(HumanAavatarQ)

loadings = fa.loadings_

# Get the eigenvector
ev, v = fa.get_eigenvalues()

xvals = range(1, HumanAavatarQ.shape[1]+1)
plt.scatter(xvals, ev)
plt.plot(xvals, ev)
plt.title('Scree Plot')
plt.xlabel('Factor')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()
# Out:
# <ipython-input-39-5d2b43fc8427>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HumanAavatarQ.dropna(inplace=True);
# 33576.98490489833 0.0
# 0.37922299072097404

# %%
# Response time predicted by Avatar Presence
formula = "np.log(RT) ~ remember_action_likert + remember_standing_likert  + attractive_action_likert + attractive_standing_likert + realistic_action_likert + realistic_standing_likert"

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                 MixedLM     Dependent Variable:     np.log(RT)
# No. Observations:      9381        Method:                 REML
# No. Groups:            28          Scale:                  0.4037
# Min. group size:       329         Log-Likelihood:         -9119.2885
# Max. group size:       336         Converged:              Yes
# Mean group size:       335.0
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.530    0.495  3.092 0.002  0.560  2.500
# remember_action_likert      0.075    0.120  0.627 0.531 -0.160  0.311
# remember_standing_likert   -0.236    0.176 -1.341 0.180 -0.580  0.109
# attractive_action_likert    0.341    0.221  1.541 0.123 -0.092  0.774
# attractive_standing_likert -0.274    0.238 -1.150 0.250 -0.742  0.193
# realistic_action_likert    -0.281    0.207 -1.358 0.174 -0.686  0.124
# realistic_standing_likert   0.411    0.205  2.006 0.045  0.009  0.812
# Group Var                   0.076    0.037
# =====================================================================

# %%
import random
number = random.randint(1000,9999)
print(number)
# Out:
# 8768

# %%
# Response time predicted by Avatar Presence
formula = "np.log(AbsolutError) ~ ContextQ_average "

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:            MixedLM Dependent Variable: np.log(AbsolutError)
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              1.7221
# Min. group size:  329     Log-Likelihood:     -15915.5917
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# -------------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z|  [0.025  0.975]
# -------------------------------------------------------------------
# Intercept             3.042     0.317  9.586  0.000   2.420   3.664
# ContextQ_average      0.045     0.064  0.711  0.477  -0.080   0.171
# Group Var             0.218     0.047
# ==================================================================

# %%
# Response time predicted by Avatar Presence
formula = "remember_action_likert ~ AffiliativeQ_average "

# Define and fit a linear regression model
model_LM = smf.mixedlm(formula = formula, data = HumanAf, groups=HumanAf['ID']).fit()
print(model_LM.summary())
# Out:
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:            MixedLM Dependent Variable: remember_action_likert
# No. Observations: 9381    Method:             REML
# No. Groups:       28      Scale:              0.0000
# Min. group size:  329     Log-Likelihood:     128252.3034
# Max. group size:  336     Converged:          Yes
# Mean group size:  335.0
# ---------------------------------------------------------------------
#                       Coef.  Std.Err.     z     P>|z|  [0.025  0.975]
# ---------------------------------------------------------------------
# Intercept             2.053     0.019  106.647  0.000   2.015   2.090
# AffiliativeQ_average  0.222     0.005   47.862  0.000   0.213   0.231
# Group Var             0.001    57.503
# ====================================================================
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
HumanAaffili = HumanAf[['AffiliativeQ_average', 'remember_action_likert', 'remember_standing_likert', 'attractive_action_likert', 'attractive_standing_likert', 'realistic_action_likert', 'realistic_standing_likert','ContextQ_average' ]]
corrMatrix = HumanAaffili.corr()

fig, ax = plt.subplots(figsize=(8,6))
mask = np.triu(np.ones_like(corrMatrix, dtype=bool))
sns.heatmap(corrMatrix, annot=True, cmap="YlGnBu", ax=ax, mask=mask)

ax.set_xticklabels(['Affiliative Scale', 'Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful', 'ContextQ_average']);
ax.set_yticklabels(['Affiliative Scale', 'Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful', 'ContextQ_average']);

# %%
sns.regplot('remember_action_likert', 'AffiliativeQ_average', data= HumanAaffili )
# Out:
# /Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='remember_action_likert', ylabel='AffiliativeQ_average'>

# %%
sns.regplot('realistic_standing_likert', 'AffiliativeQ_average', data= HumanAaffili )
# Out:
# <AxesSubplot: xlabel='realistic_standing_likert', ylabel='AffiliativeQ_average'>

# %%
import scipy.stats
r, p = scipy.stats.pearsonr(HumanAf.AffiliativeQ_average, HumanAf.realistic_standing_likert)
p
# Out:
# 9.30462593653344e-110

# %%
sns.set(rc={"figure.figsize":(18, 8)})
sns.set(font_scale = 1.3)
from matplotlib import cm

fig, ax = plt.subplots(1,2)

cor, pval = stats.spearmanr(corrMatrix.T)
sns.heatmap(cor, annot=True, cmap="YlGnBu", mask=mask, ax=ax[0]).set(title="Spearman's rank correlation coefficients(ρ)")
initial_cmap = cm.get_cmap('YlGnBu')
reversed_cmap=initial_cmap.reversed()
sns.heatmap(pval, annot=True, cmap=reversed_cmap, mask=mask, ax=ax[1]).set(title="Probability values for Spearman's rank correlation")

for ax in ax.ravel():
    ax.set_xticklabels(['Affiliative Scale', 'Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful', 'ContextQ_average'], rotation=60);
    ax.set_yticklabels(['Affiliative Scale', 'Remember Meaningful', 'Remember not meaningful', 'Attractive Meaningful', 'Attractive not meaningful', 'Realistic Meaningful', 'Realistic not meaningful', 'ContextQ_average'], rotation=360);
plt.tight_layout()
plt.show()

# %%
HumanAf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9381 entries, 0 to 9717
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        9381 non-null   int64
#  1   ID                                9381 non-null   object
#  2   Alter                             9381 non-null   float64
#  3   Global                            9381 non-null   float64
#  4   Overview                          9381 non-null   float64
#  5   Cardinal                          9381 non-null   float64
#  6   AffiliativeQ_average              9381 non-null   float64
#  7   item3                             9381 non-null   float64
#  8   ContextQ_average                  9381 non-null   float64
#  9   remember_action_likert            9381 non-null   float64
#  10  remember_standing_likert          9381 non-null   float64
#  11  attractive_action_likert          9381 non-null   float64
#  12  attractive_standing_likert        9381 non-null   float64
#  13  realistic_action_likert           9381 non-null   float64
#  14  realistic_standing_likert         9381 non-null   float64
#  15  AbsolutError                      9381 non-null   float64
#  16  SignedAngle-+180                  9381 non-null   float64
#  17  IQR                               9381 non-null   float64
#  18  RT                                9381 non-null   float64
#  19  DistanceToParticipant             9381 non-null   float64
#  20  PointingTaskStartingLocations     9381 non-null   object
#  21  TrialNumber                       9381 non-null   float64
#  22  StartPointID                      9381 non-null   object
#  23  ID_for_StartingPosition           9381 non-null   float64
#  24  avatarID                          9381 non-null   object
#  25  AvatarPresenceCategory            9381 non-null   object
#  26  Context                           9381 non-null   object
#  27  meaningfulBuilding                9381 non-null   object
#  28  ImageName                         9381 non-null   object
#  29  ID_StartPointID                   9381 non-null   object
#  30  ID_PointingTaskStartingLocations  9381 non-null   object
# dtypes: float64(20), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
# library & dataset
import matplotlib.pyplot as plt
import seaborn as sns

# with regression
sns.pairplot(HumanAaffili, kind="reg")
plt.show()
