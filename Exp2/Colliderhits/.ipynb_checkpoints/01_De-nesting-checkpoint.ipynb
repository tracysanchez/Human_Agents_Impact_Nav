# %%
# Added cell to set Working Directory to your location
import os
import ast
import glob
import numpy as np
import pandas as pd
import json
import time

# %%
path = "/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller" 

# csv files in the path
files = glob.glob(path + "/*.csv")

for filename in files:
    temp_one_part = pd.read_csv(filename)
    # Drop unnecessary variables
    temp_one_part.drop(["0"],axis=1, inplace=True)
    # Format index column
    temp_one_part.rename(columns = {'Unnamed: 0':'index'}, inplace=True)
    temp_one_part.dropna(subset=['hitPointOnObject'], inplace=True)
    # Given the way our the files have been constructed up to now, the contents of "hitPointOnObject" are not longer read as dictionary.
    # So we go row by row turn them into string and then properly format them into dictionaries to be able to explote that data on the subsequent step.
    temp_one_part["hitPointOnObject"] = [ast.literal_eval(str(row_value)) for row_value in temp_one_part["hitPointOnObject"]]
    # Turn the dictionary values into columns
    temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
    temp_one_part.drop(["hitPointOnObject"], axis=1, inplace= True)
    temp_one_part.to_csv("/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/02_Individuals_Colliders/" + str(filename[-8:len(filename)]))
    print(str(filename) + " Done")
# Out:
# /Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/0365.csv Done
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#   File "pandas/_libs/lib.pyx", line 2467, in pandas._libs.lib.map_infer
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 318, in __init__
#     data, index = self._init_dict(data, index, dtype)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 411, in _init_dict
#     s = create_series_with_explicit_dtype(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py", line 666, in create_series_with_explicit_dtype
#     return Series(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 281, in __init__
#     index = ensure_index(index)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 5917, in ensure_index
#     return Index(index_like)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 391, in __new__
#     return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 360, in __new__
#     return cls(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 259, in __new__
#     dtype = pandas_dtype(dtype)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py", line 1769, in pandas_dtype
#     def pandas_dtype(dtype) -> DtypeObj:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-f8d4071b1c7e>", line 17, in <module>
#     temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 721, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#   File "pandas/_libs/lib.pyx", line 2467, in pandas._libs.lib.map_infer
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 318, in __init__
#     data, index = self._init_dict(data, index, dtype)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 411, in _init_dict
#     s = create_series_with_explicit_dtype(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py", line 666, in create_series_with_explicit_dtype
#     return Series(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 281, in __init__
#     index = ensure_index(index)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 5917, in ensure_index
#     return Index(index_like)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 391, in __new__
#     return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 360, in __new__
#     return cls(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 259, in __new__
#     dtype = pandas_dtype(dtype)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py", line 1769, in pandas_dtype
#     def pandas_dtype(dtype) -> DtypeObj:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-f8d4071b1c7e>", line 17, in <module>
#     temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/posixpath.py", line 392, in realpath
#     return abspath(path)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/posixpath.py", line 375, in abspath
#     if not isabs(path):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/posixpath.py", line 64, in isabs
#     return s.startswith(sep)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     317             elif is_dict_like(data):
# --> 318                 data, index = self._init_dict(data, index, dtype)
#     319                 dtype = None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _init_dict(self, data, index, dtype)
#     410         # TODO: passing np.float64 to not break anything yet. See GH-17261
# --> 411         s = create_series_with_explicit_dtype(
#     412             values, index=keys, dtype=dtype, dtype_if_empty=np.float64
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in create_series_with_explicit_dtype(data, index, dtype, name, copy, fastpath, dtype_if_empty)
#     665         dtype = dtype_if_empty
# --> 666     return Series(
#     667         data=data, index=index, dtype=dtype, name=name, copy=copy, fastpath=fastpath
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     280             if index is not None:
# --> 281                 index = ensure_index(index)
#     282
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5916
# -> 5917     return Index(index_like)
#    5918
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     390             subarr = com.asarray_tuplesafe(data, dtype=object)
# --> 391             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     392
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     359                 if new_dtype is not None:
# --> 360                     return cls(
#     361                         new_data, dtype=new_dtype, copy=False, name=name, **kwargs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     258         if dtype is not None:
# --> 259             dtype = pandas_dtype(dtype)
#     260         if "tz" in kwargs:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    1768
# -> 1769 def pandas_dtype(dtype) -> DtypeObj:
#    1770     """
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-f8d4071b1c7e> in <module>
#      16     # Turn the dictionary values into columns
# ---> 17     temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
#      18     temp_one_part.drop(["hitPointOnObject"], axis=1, inplace= True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3356                         asy = compare(code)
# -> 3357                     if (await self.run_code(code, result,  async_=asy)):
#    3358                         return True
#
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3163                     interactivity = 'async'
#    3164
# -> 3165                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3166                        interactivity=interactivity, compiler=compiler, result=result)
#    3167
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3374             if result:
#    3375                 result.error_before_exec = sys.exc_info()[1]
# -> 3376             self.showtraceback()
#    3377             return True
#    3378
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
temp_one_part.head()
