# %%
import pandas as pd
import glob

# %%
path = "/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/05_Debbies_gaze" 

  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    One_participant = pd.read_csv(filename)
    One_participant = One_participant.loc[:, ~One_participant.columns.str.contains('^Unnamed')]
    print(filename[-10:-4])
    content.append(One_participant)

# converting content to data frame
data_frame = pd.concat(content)
# Out:
# 1031_1
# 1031_2
# 1031_3
# 1031_4
# 1031_5
# 1268_1
# 1268_2
# 1268_3
# 1268_4
# 1268_5
# 1574_1
# 1574_2
# 1574_3
# 1574_4
# 1574_5
# 1843_1
# 1843_2
# 1843_3
# 1843_4
# 1843_5
# 2069_1
# 2069_2
# 2069_3
# 2069_4
# 2069_5
# 3193_1
# 3193_2
# 3193_3
# 3193_4
# 3193_5
# 3540_1
# 3540_2
# 3540_3
# 3540_4
# 3540_5
# 4580_1
# 4580_2
# 4580_3
# 4580_4
# 4580_5
# 4598_1
# 4598_2
# 4598_3
# 4598_4
# 4598_5
# 4847_1
# 4847_2
# 4847_3
# 4847_4
# 4847_5
# 4875_1
# 4875_2
# 4875_3
# 4875_4
# 4875_5
# 5161_1
# 5161_2
# 5161_3
# 5161_4
# 5161_5
# 5189_1
# 5189_2
# 5189_3
# 5189_4
# 5189_5
# 5743_1
# 5743_2
# 5743_3
# 5743_4
# 5743_5
# 5766_1
# 5766_2
# 5766_3
# 5766_4
# 5766_5
# 5851_1
# 5851_2
# 5851_3
# 5851_4
# 5851_5
# 5972_1
# 5972_2
# 5972_3
# 5972_4
# 5972_5
# 6406_1
# 6406_2
# 6406_3
# 6406_4
# 6406_5
# 7081_1
# 7081_2
# 7081_3
# 7081_4
# 7081_5
# 7393_1
# 7393_2
# 7393_3
# 7393_4
# 7393_5
# 7823_1
# 7823_2
# 7823_3
# 7823_4
# 7823_5
# 7935_1
# 7935_2
# 7935_3
# 7935_4
# 7935_5
# 8629_1
# ...

# %%
data_frame.to_csv("/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/Data_Sets/Complete_Data_AngularV.cvs")
