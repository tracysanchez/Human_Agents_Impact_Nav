# %% [markdown]
# # Extracting information from the randomization file

# %%
import os
import re
import glob
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Added cell to set Working Directory to your location
#os.chdir('/Volumes/SSD/Pointing_Task')
os.chdir('/Volumes/TwoTeras/1_Experiment_2/Pointing_Task/Randomization/Building')
os.getcwd()
# Out:
# '/Volumes/TwoTeras/1_Experiment_2/Pointing_Task/Randomization/Building'

# %% [markdown]
# ## Importing the individual randomization files per participant

# %%
# specify data folder
# with wildcard for every file with a certain name
#path = "Randomizations/*.json"
path = "*.json"

# %%
## Extracting all subject IDs from the data folder
subIDs = []
for sub in glob.glob(path):
    if sub[0].isdigit():
        subIDs.append(int(sub[0:4]))
    #if sub[15].isdigit():
    #    subIDs.append(int(sub[15:19]))
    else:
        pass
subIDs = np.unique(subIDs)
print(subIDs)
# Out:
# [1031 1142 1234 1268 1574 1843 2069 3193 3540 4580 4598 4847 4875 5161
#  5189 5191 5743 5766 5851 5972 6266 6406 7081 7393 7823 7935 8629 9297
#  9627]

# %%
# create empty dataframe
df = pd.DataFrame()

# read every file name in folder
for filename in glob.glob(path):
    if "PointingTask" in filename:
        with open(filename, 'r') as file:
            # make json files parsable
            data = "[" + file.read()
            data = data[:len(data)-1] + "]"

            # read data per file
            subjectdf = pd.read_json(data)

            # insert participant id in every line
            #subjectdf.insert(0, "SubjectID", [int(filename[15:19])] * subjectdf.shape[0], True)
            subjectdf.insert(0, "SubjectID", [int(filename[0:4])] * subjectdf.shape[0], True)
            df = df.append(subjectdf, ignore_index=True)
df.head(8)
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       5743           5743  [PointingTask]  English
# 1       4598           4598  [PointingTask]  Deutsch
# 2       2069           2069  [PointingTask]  English
# 3       7393           7393  [PointingTask]  English
# 4       5851           5851  [PointingTask]  English
# 5       3193           3193  [PointingTask]  English
# 6       6406           6406  [PointingTask]  English
# 7       7081           7081  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 1  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 2  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 3  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 4  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 5  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 6  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 7  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 1  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 2  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 3  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 4  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 5  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 6  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 7  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                        PointingTaskStartingLocations  \
# 0  [3, 22, 27, 17, 5, 25, 16, 6, 14, 2, 1, 21, 9,...
# 1  [24, 14, 22, 17, 1, 0, 12, 2, 15, 6, 10, 13, 2...
# 2  [1, 5, 2, 11, 17, 15, 25, 4, 18, 9, 6, 8, 7, 2...
# 3  [26, 23, 14, 16, 25, 10, 7, 17, 21, 4, 24, 27,...
# 4  [8, 10, 23, 0, 21, 25, 16, 9, 7, 15, 24, 18, 1...
# 5  [6, 20, 26, 22, 14, 1, 27, 8, 24, 7, 10, 18, 4...
# 6  [7, 18, 25, 5, 26, 15, 16, 8, 4, 27, 13, 12, 2...
# 7  [14, 3, 1, 16, 4, 18, 5, 25, 23, 2, 6, 21, 19,...
#
#                 PointingTaskTargets_1              PointingTaskTargets_2  \
# 0     [6, 76, 48, 44, 8, 91, 18, 104]   [83, 60, 15, 32, 11, 10, 31, 33]
# 1    [66, 52, 58, 19, 30, 69, 70, 65]   [109, 86, 99, 88, 26, 91, 7, 25]
# 2  [71, 45, 104, 102, 27, 55, 48, 70]  [23, 42, 111, 100, 29, 87, 4, 89]
# 3  [47, 102, 57, 104, 23, 15, 62, 55]   [35, 15, 62, 10, 49, 88, 38, 39]
# 4     [89, 58, 88, 49, 79, 5, 3, 107]    [64, 33, 13, 95, 9, 23, 97, 12]
# 5   [103, 107, 63, 13, 31, 4, 19, 25]  [82, 89, 31, 14, 66, 96, 20, 108]
# 6     [4, 52, 96, 60, 25, 45, 22, 73]  [37, 10, 25, 105, 87, 87, 54, 25]
# 7     [54, 78, 3, 22, 54, 1, 40, 102]     [26, 5, 82, 37, 0, 81, 94, 61]
#
#                 PointingTaskTargets_3  ...  \
# 0     [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 1    [11, 80, 60, 54, 66, 23, 85, 38]  ...
# 2    [89, 36, 28, 58, 21, 35, 54, 89]  ...
# 3  [66, 31, 103, 27, 33, 111, 15, 89]  ...
# 4       [62, 65, 2, 1, 111, 16, 0, 4]  ...
# 5   [30, 105, 95, 78, 38, 7, 45, 101]  ...
# 6   [57, 26, 89, 67, 103, 85, 74, 13]  ...
# 7  [108, 17, 67, 90, 73, 11, 107, 75]  ...
#
#                PointingTaskTargets_19              PointingTaskTargets_20  \
# 0    [31, 39, 71, 67, 76, 97, 15, 10]   [36, 110, 99, 60, 93, 97, 73, 79]
# 1   [105, 26, 17, 7, 23, 107, 68, 29]     [45, 7, 11, 68, 11, 91, 90, 50]
# 2     [95, 94, 95, 82, 47, 90, 35, 0]   [27, 26, 74, 69, 41, 37, 101, 26]
# 3     [1, 76, 51, 75, 31, 23, 26, 79]   [60, 44, 32, 38, 22, 64, 102, 27]
# 4      [52, 17, 88, 75, 34, 27, 1, 1]  [50, 53, 69, 105, 48, 56, 38, 111]
# 5     [74, 37, 21, 62, 5, 19, 11, 92]     [88, 0, 79, 108, 27, 5, 62, 27]
# 6  [35, 82, 16, 103, 105, 29, 35, 71]  [45, 75, 21, 106, 105, 44, 20, 93]
# 7   [100, 1, 38, 61, 68, 17, 109, 91]   [111, 93, 65, 50, 18, 77, 54, 81]
#
#                 PointingTaskTargets_21              PointingTaskTargets_22  \
# 0  [48, 75, 21, 71, 111, 30, 100, 107]     [88, 73, 88, 2, 99, 31, 93, 56]
# 1   [104, 98, 107, 92, 111, 93, 92, 5]    [5, 29, 107, 34, 81, 52, 18, 32]
# 2      [0, 77, 20, 36, 16, 60, 27, 67]    [23, 71, 99, 40, 36, 93, 33, 22]
# 3     [17, 94, 103, 91, 96, 64, 5, 33]    [19, 16, 56, 67, 102, 30, 6, 71]
# 4    [23, 73, 68, 47, 101, 42, 67, 70]     [78, 70, 80, 41, 0, 33, 32, 79]
# 5    [7, 31, 90, 94, 92, 108, 111, 23]       [50, 6, 8, 81, 48, 47, 3, 94]
# 6     [44, 70, 95, 87, 51, 55, 99, 67]   [55, 89, 73, 40, 102, 33, 98, 79]
# 7    [9, 105, 77, 51, 19, 10, 105, 46]  [105, 18, 60, 41, 103, 57, 56, 35]
#
#               PointingTaskTargets_23             PointingTaskTargets_24  \
# 0   [90, 106, 4, 93, 16, 87, 67, 85]   [34, 30, 47, 80, 14, 11, 22, 86]
# 1  [107, 53, 76, 30, 8, 110, 92, 54]     [32, 62, 23, 34, 5, 4, 60, 46]
# 2   [34, 21, 22, 89, 92, 82, 90, 26]  [110, 31, 78, 19, 81, 41, 68, 57]
# 3     [1, 42, 62, 69, 54, 84, 60, 4]   [63, 92, 78, 44, 70, 71, 59, 46]
# 4   [39, 53, 51, 26, 79, 71, 14, 68]   [46, 83, 5, 11, 49, 110, 10, 41]
# 5    [15, 22, 5, 97, 86, 1, 47, 109]   [19, 52, 66, 28, 76, 52, 58, 18]
# 6  [88, 68, 77, 67, 54, 20, 95, 100]     [38, 82, 46, 8, 26, 93, 8, 59]
# 7   [8, 19, 100, 55, 21, 50, 51, 56]     [38, 20, 79, 88, 2, 2, 51, 49]
#
#               PointingTaskTargets_25              PointingTaskTargets_26  \
# 0   [78, 60, 63, 107, 58, 44, 61, 0]       [75, 91, 3, 9, 12, 23, 4, 16]
# 1    [101, 76, 105, 2, 9, 24, 8, 12]     [46, 12, 2, 0, 33, 59, 101, 90]
# 2  [24, 108, 13, 17, 32, 64, 79, 34]    [68, 14, 23, 19, 48, 72, 103, 6]
# 3   [62, 12, 32, 109, 60, 7, 48, 71]    [17, 55, 14, 78, 70, 88, 30, 37]
# 4    [3, 55, 92, 46, 86, 62, 86, 21]     [4, 67, 98, 77, 33, 71, 49, 20]
# 5     [11, 27, 21, 4, 3, 14, 68, 78]  [37, 109, 12, 110, 11, 41, 43, 41]
# 6    [81, 6, 61, 64, 60, 16, 68, 80]     [11, 18, 79, 64, 24, 81, 8, 73]
# 7    [49, 10, 28, 91, 76, 87, 1, 90]    [7, 103, 68, 49, 68, 68, 54, 36]
#
#                PointingTaskTargets_27                PointingTaskTargets_28
# 0     [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 1    [72, 14, 60, 42, 106, 6, 53, 59]  [49, 57, 111, 95, 108, 107, 99, 111]
# 2    [16, 79, 15, 79, 82, 77, 59, 71]      [59, 77, 63, 63, 63, 73, 65, 77]
# 3     [73, 37, 91, 2, 33, 45, 33, 28]         [4, 10, 17, 13, 29, 3, 6, 10]
# 4    [36, 99, 85, 62, 72, 98, 88, 78]      [84, 86, 80, 82, 62, 70, 58, 68]
# 5   [109, 96, 92, 5, 111, 77, 74, 83]      [72, 66, 72, 62, 76, 58, 82, 60]
# 6     [65, 21, 66, 17, 24, 76, 78, 1]       [83, 75, 65, 14, 23, 83, 2, 20]
# 7  [42, 110, 20, 102, 78, 28, 76, 70]      [72, 72, 62, 56, 74, 70, 70, 74]
#
# [8 rows x 35 columns]

# %%
df.tail(10)
# Out:
#     SubjectID  ParticipantID       TaskOrder Language  \
# 19       1268           1268  [PointingTask]  English
# 20       1574           1574  [PointingTask]  English
# 21       1843           1843  [PointingTask]  English
# 22       3540           3540  [PointingTask]  English
# 23       4875           4875  [PointingTask]  English
# 24       7823           7823  [PointingTask]  English
# 25       1142           1142  [PointingTask]  English
# 26       1234           1234  [PointingTask]  English
# 27       6266           6266  [PointingTask]  English
# 28       5191           5191  [PointingTask]  English
#
#                                    InitialOrientation  \
# 19  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 20  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 21  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 22  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 23  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 24  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 25  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 26  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 27  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 28  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                PointingTaskRandomised  \
# 19  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 20  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 21  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 22  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 23  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 24  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 25  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 26  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 27  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 28  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                         PointingTaskStartingLocations  \
# 19  [11, 13, 17, 27, 6, 2, 26, 8, 16, 5, 12, 3, 15...
# 20  [20, 26, 5, 15, 2, 11, 22, 3, 16, 25, 17, 23, ...
# 21  [16, 27, 7, 12, 4, 15, 3, 17, 19, 2, 20, 25, 8...
# 22  [13, 3, 11, 18, 16, 24, 10, 21, 22, 5, 6, 4, 7...
# 23  [10, 20, 7, 4, 3, 27, 8, 23, 18, 22, 24, 12, 2...
# 24  [14, 13, 25, 5, 12, 22, 24, 9, 17, 23, 21, 8, ...
# 25  [25, 4, 11, 18, 19, 26, 14, 10, 16, 24, 13, 9,...
# 26  [22, 26, 12, 7, 8, 24, 18, 27, 4, 9, 21, 17, 1...
# 27  [1, 5, 0, 21, 8, 17, 7, 9, 14, 4, 22, 26, 2, 1...
# 28  [2, 19, 9, 7, 22, 13, 21, 6, 27, 16, 24, 14, 1...
#
#                  PointingTaskTargets_1               PointingTaskTargets_2  \
# 19   [59, 64, 62, 24, 12, 26, 106, 72]     [66, 10, 47, 38, 45, 6, 33, 91]
# 20    [37, 60, 23, 53, 27, 11, 22, 28]     [8, 89, 42, 82, 98, 52, 35, 56]
# 21     [95, 55, 71, 47, 26, 4, 22, 11]    [52, 99, 57, 18, 11, 99, 37, 41]
# 22    [17, 33, 83, 37, 56, 44, 49, 23]    [3, 32, 82, 66, 21, 25, 94, 108]
# 23    [19, 30, 21, 19, 83, 0, 61, 107]     [58, 43, 56, 36, 7, 74, 98, 76]
# 24     [89, 78, 88, 95, 1, 89, 16, 12]    [57, 51, 5, 99, 111, 91, 75, 81]
# 25    [38, 12, 87, 67, 13, 60, 67, 91]    [25, 86, 11, 55, 44, 20, 22, 50]
# 26   [5, 106, 14, 64, 94, 104, 28, 58]    [47, 76, 49, 56, 29, 105, 56, 1]
# 27  [92, 29, 103, 104, 75, 26, 20, 89]  [85, 80, 31, 89, 111, 111, 67, 51]
# 28     [88, 69, 51, 69, 107, 7, 17, 8]   [14, 83, 93, 92, 107, 94, 68, 18]
#
#                  PointingTaskTargets_3  ...  \
# 19    [105, 2, 1, 105, 61, 24, 29, 81]  ...
# 20    [29, 84, 6, 89, 104, 70, 22, 17]  ...
# 21      [41, 6, 67, 17, 46, 8, 93, 54]  ...
# 22   [24, 59, 25, 56, 46, 107, 87, 90]  ...
# 23    [38, 85, 68, 94, 45, 58, 65, 91]  ...
# 24    [49, 67, 85, 28, 99, 32, 70, 29]  ...
# 25  [27, 23, 18, 108, 96, 27, 102, 41]  ...
# 26   [12, 79, 109, 74, 27, 48, 12, 91]  ...
# 27   [32, 110, 21, 96, 37, 50, 10, 49]  ...
# 28  [103, 2, 65, 100, 83, 111, 95, 62]  ...
#
#                 PointingTaskTargets_19               PointingTaskTargets_20  \
# 19   [70, 73, 106, 3, 102, 45, 20, 45]     [89, 83, 60, 55, 89, 86, 17, 89]
# 20    [64, 94, 40, 43, 97, 60, 54, 83]  [25, 83, 103, 71, 100, 22, 37, 109]
# 21   [18, 59, 88, 22, 60, 48, 105, 26]      [16, 33, 68, 8, 17, 90, 98, 88]
# 22  [93, 109, 82, 93, 33, 12, 17, 101]      [54, 33, 94, 85, 57, 3, 40, 68]
# 23   [68, 91, 106, 82, 15, 60, 85, 74]       [83, 3, 32, 11, 5, 48, 65, 34]
# 24      [84, 86, 0, 20, 27, 26, 40, 3]     [82, 78, 88, 58, 57, 24, 25, 62]
# 25    [62, 32, 90, 11, 84, 27, 89, 22]    [78, 52, 89, 29, 62, 105, 28, 30]
# 26    [4, 77, 102, 88, 43, 61, 89, 30]      [42, 76, 94, 4, 89, 82, 70, 34]
# 27     [61, 89, 90, 60, 8, 48, 51, 40]      [50, 30, 17, 12, 39, 88, 8, 71]
# 28     [85, 29, 73, 42, 92, 10, 20, 3]  [15, 51, 44, 103, 96, 51, 108, 103]
#
#                PointingTaskTargets_21              PointingTaskTargets_22  \
# 19    [43, 58, 51, 94, 35, 13, 80, 6]  [102, 50, 91, 75, 56, 111, 85, 79]
# 20       [43, 52, 8, 52, 6, 0, 36, 3]   [23, 104, 82, 20, 56, 40, 80, 51]
# 21  [59, 29, 51, 12, 75, 102, 26, 45]   [66, 10, 101, 74, 84, 13, 35, 88]
# 22    [78, 1, 91, 22, 87, 33, 28, 82]   [91, 12, 61, 86, 57, 86, 82, 104]
# 23   [32, 92, 32, 89, 67, 60, 61, 90]     [14, 66, 26, 54, 12, 74, 37, 1]
# 24   [91, 51, 62, 57, 76, 74, 42, 47]   [62, 85, 105, 49, 25, 79, 74, 45]
# 25    [53, 10, 4, 12, 94, 9, 106, 35]       [8, 9, 60, 85, 7, 74, 77, 38]
# 26    [36, 79, 27, 94, 6, 37, 39, 45]    [33, 61, 43, 71, 17, 72, 93, 75]
# 27   [55, 5, 67, 85, 63, 13, 47, 108]    [51, 68, 61, 28, 68, 78, 31, 32]
# 28  [67, 17, 111, 29, 96, 14, 26, 46]     [84, 42, 79, 46, 60, 14, 5, 69]
#
#                  PointingTaskTargets_23               PointingTaskTargets_24  \
# 19        [46, 9, 3, 66, 28, 3, 64, 16]       [80, 9, 12, 84, 1, 55, 16, 44]
# 20       [46, 40, 95, 10, 8, 21, 6, 46]      [56, 23, 51, 12, 93, 9, 12, 27]
# 21     [25, 83, 97, 42, 69, 4, 48, 104]      [70, 42, 67, 51, 73, 43, 5, 63]
# 22       [9, 95, 49, 4, 73, 29, 99, 45]     [50, 98, 13, 79, 78, 34, 73, 58]
# 23     [79, 68, 95, 109, 0, 11, 30, 90]  [45, 14, 105, 102, 58, 105, 28, 61]
# 24  [79, 71, 103, 54, 107, 35, 80, 109]      [88, 9, 85, 65, 90, 20, 86, 83]
# 25    [48, 88, 22, 78, 100, 99, 47, 69]      [54, 63, 49, 37, 54, 65, 0, 40]
# 26     [85, 81, 29, 109, 83, 80, 65, 3]     [110, 15, 17, 92, 5, 96, 64, 98]
# 27       [5, 73, 76, 44, 4, 73, 36, 94]  [100, 55, 54, 66, 56, 100, 25, 104]
# 28  [57, 88, 109, 106, 109, 53, 65, 50]       [3, 88, 25, 58, 39, 9, 48, 51]
#
#                PointingTaskTargets_25                 PointingTaskTargets_26  \
# 19     [6, 33, 22, 9, 83, 47, 40, 56]     [104, 99, 13, 51, 66, 56, 100, 90]
# 20   [83, 64, 57, 68, 83, 63, 81, 93]     [99, 88, 96, 102, 95, 70, 104, 68]
# 21  [51, 54, 31, 6, 95, 97, 107, 100]  [105, 63, 104, 101, 60, 70, 105, 105]
# 22     [79, 29, 6, 76, 64, 62, 5, 79]           [8, 3, 64, 63, 5, 83, 61, 4]
# 23    [19, 39, 18, 80, 39, 8, 31, 45]    [104, 105, 59, 20, 71, 40, 106, 10]
# 24      [7, 74, 27, 92, 4, 56, 4, 10]       [44, 64, 69, 53, 32, 103, 90, 2]
# 25   [81, 17, 77, 29, 40, 24, 98, 52]          [37, 54, 2, 74, 79, 3, 15, 3]
# 26    [92, 5, 28, 84, 55, 16, 40, 63]        [42, 10, 111, 46, 70, 25, 4, 1]
# 27    [79, 68, 41, 98, 48, 41, 93, 8]         [51, 99, 22, 83, 83, 7, 7, 82]
# 28   [87, 18, 101, 92, 103, 3, 70, 3]        [26, 70, 49, 42, 86, 54, 0, 46]
#
#                  PointingTaskTargets_27             PointingTaskTargets_28
# 19    [109, 93, 8, 79, 83, 63, 39, 106]   [34, 47, 34, 46, 40, 49, 55, 55]
# 20  [66, 88, 84, 99, 106, 75, 105, 101]   [73, 91, 69, 69, 73, 70, 63, 68]
# 21     [78, 71, 82, 75, 77, 81, 79, 64]   [71, 60, 61, 58, 70, 73, 78, 75]
# 22       [20, 3, 75, 3, 74, 82, 75, 80]   [58, 66, 61, 81, 67, 81, 64, 76]
# 23     [38, 91, 81, 36, 32, 81, 2, 111]  [21, 45, 71, 31, 73, 109, 19, 33]
# 24      [3, 43, 32, 55, 42, 52, 10, 26]     [36, 50, 10, 22, 18, 0, 10, 4]
# 25     [86, 50, 93, 85, 83, 62, 66, 74]     [70, 72, 69, 9, 19, 4, 81, 63]
# 26      [41, 3, 0, 41, 37, 65, 110, 73]     [8, 58, 48, 8, 64, 70, 76, 10]
# 27        [11, 0, 80, 24, 17, 2, 4, 66]   [69, 65, 13, 10, 73, 79, 17, 23]
# 28      [86, 46, 7, 53, 2, 105, 13, 60]    [26, 8, 100, 80, 38, 16, 8, 28]
#
# [10 rows x 35 columns]

# %% [markdown]
# ## Detangling starting positions
#
# `.explote('VariableName')` is a method that transforms each element of a list-like
# **in this case the list of start locations contained on** to a row, replicating index values

# %%
StartingPoints = pd.DataFrame(df.explode('PointingTaskStartingLocations', ignore_index=True))
StartingPoints.head(29)
# Out:
#     SubjectID  ParticipantID       TaskOrder Language  \
# 0        5743           5743  [PointingTask]  English
# 1        5743           5743  [PointingTask]  English
# 2        5743           5743  [PointingTask]  English
# 3        5743           5743  [PointingTask]  English
# 4        5743           5743  [PointingTask]  English
# 5        5743           5743  [PointingTask]  English
# 6        5743           5743  [PointingTask]  English
# 7        5743           5743  [PointingTask]  English
# 8        5743           5743  [PointingTask]  English
# 9        5743           5743  [PointingTask]  English
# 10       5743           5743  [PointingTask]  English
# 11       5743           5743  [PointingTask]  English
# 12       5743           5743  [PointingTask]  English
# 13       5743           5743  [PointingTask]  English
# 14       5743           5743  [PointingTask]  English
# 15       5743           5743  [PointingTask]  English
# 16       5743           5743  [PointingTask]  English
# 17       5743           5743  [PointingTask]  English
# 18       5743           5743  [PointingTask]  English
# 19       5743           5743  [PointingTask]  English
# 20       5743           5743  [PointingTask]  English
# 21       5743           5743  [PointingTask]  English
# 22       5743           5743  [PointingTask]  English
# 23       5743           5743  [PointingTask]  English
# 24       5743           5743  [PointingTask]  English
# 25       5743           5743  [PointingTask]  English
# 26       5743           5743  [PointingTask]  English
# 27       5743           5743  [PointingTask]  English
# 28       4598           4598  [PointingTask]  Deutsch
#
#                                    InitialOrientation  \
# 0   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 1   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 2   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 3   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 4   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 5   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 6   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 7   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 8   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 9   {'x': 0.0008186895865940001, 'y': -0.906321287...
# 10  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 11  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 12  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 13  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 14  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 15  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 16  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 17  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 18  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 19  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 20  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 21  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 22  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 23  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 24  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 25  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 26  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 27  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 28  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                PointingTaskRandomised  \
# 0   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 1   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 2   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 3   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 4   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 5   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 6   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 7   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 8   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 9   [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 10  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 11  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 12  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 13  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 14  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 15  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 16  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 17  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 18  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 19  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 20  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 21  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 22  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 23  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 24  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 25  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 26  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 27  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 28  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#    PointingTaskStartingLocations             PointingTaskTargets_1  \
# 0                              3   [6, 76, 48, 44, 8, 91, 18, 104]
# 1                             22   [6, 76, 48, 44, 8, 91, 18, 104]
# 2                             27   [6, 76, 48, 44, 8, 91, 18, 104]
# 3                             17   [6, 76, 48, 44, 8, 91, 18, 104]
# 4                              5   [6, 76, 48, 44, 8, 91, 18, 104]
# 5                             25   [6, 76, 48, 44, 8, 91, 18, 104]
# 6                             16   [6, 76, 48, 44, 8, 91, 18, 104]
# 7                              6   [6, 76, 48, 44, 8, 91, 18, 104]
# 8                             14   [6, 76, 48, 44, 8, 91, 18, 104]
# 9                              2   [6, 76, 48, 44, 8, 91, 18, 104]
# 10                             1   [6, 76, 48, 44, 8, 91, 18, 104]
# 11                            21   [6, 76, 48, 44, 8, 91, 18, 104]
# 12                             9   [6, 76, 48, 44, 8, 91, 18, 104]
# 13                            15   [6, 76, 48, 44, 8, 91, 18, 104]
# 14                            13   [6, 76, 48, 44, 8, 91, 18, 104]
# 15                            23   [6, 76, 48, 44, 8, 91, 18, 104]
# 16                            18   [6, 76, 48, 44, 8, 91, 18, 104]
# 17                            24   [6, 76, 48, 44, 8, 91, 18, 104]
# 18                            20   [6, 76, 48, 44, 8, 91, 18, 104]
# 19                            26   [6, 76, 48, 44, 8, 91, 18, 104]
# 20                             8   [6, 76, 48, 44, 8, 91, 18, 104]
# 21                             0   [6, 76, 48, 44, 8, 91, 18, 104]
# 22                             4   [6, 76, 48, 44, 8, 91, 18, 104]
# 23                            19   [6, 76, 48, 44, 8, 91, 18, 104]
# 24                             7   [6, 76, 48, 44, 8, 91, 18, 104]
# 25                            10   [6, 76, 48, 44, 8, 91, 18, 104]
# 26                            12   [6, 76, 48, 44, 8, 91, 18, 104]
# 27                            11   [6, 76, 48, 44, 8, 91, 18, 104]
# 28                            24  [66, 52, 58, 19, 30, 69, 70, 65]
#
#                PointingTaskTargets_2             PointingTaskTargets_3  ...  \
# 0   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 1   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 2   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 3   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 4   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 5   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 6   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 7   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 8   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 9   [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 10  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 11  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 12  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 13  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 14  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 15  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 16  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 17  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 18  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 19  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 20  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 21  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 22  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 23  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 24  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 25  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 26  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 27  [83, 60, 15, 32, 11, 10, 31, 33]   [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 28  [109, 86, 99, 88, 26, 91, 7, 25]  [11, 80, 60, 54, 66, 23, 85, 38]  ...
#
#                PointingTaskTargets_19             PointingTaskTargets_20  \
# 0    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 1    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 2    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 3    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 4    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 5    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 6    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 7    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 8    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 9    [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 10   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 11   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 12   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 13   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 14   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 15   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 16   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 17   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 18   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 19   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 20   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 21   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 22   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 23   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 24   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 25   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 26   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 27   [31, 39, 71, 67, 76, 97, 15, 10]  [36, 110, 99, 60, 93, 97, 73, 79]
# 28  [105, 26, 17, 7, 23, 107, 68, 29]    [45, 7, 11, 68, 11, 91, 90, 50]
#
#                  PointingTaskTargets_21            PointingTaskTargets_22  \
# 0   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 1   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 2   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 3   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 4   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 5   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 6   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 7   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 8   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 9   [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 10  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 11  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 12  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 13  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 14  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 15  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 16  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 17  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 18  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 19  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 20  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 21  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 22  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 23  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 24  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 25  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 26  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 27  [48, 75, 21, 71, 111, 30, 100, 107]   [88, 73, 88, 2, 99, 31, 93, 56]
# 28   [104, 98, 107, 92, 111, 93, 92, 5]  [5, 29, 107, 34, 81, 52, 18, 32]
#
#                PointingTaskTargets_23            PointingTaskTargets_24  \
# 0    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 1    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 2    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 3    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 4    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 5    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 6    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 7    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 8    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 9    [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 10   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 11   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 12   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 13   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 14   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 15   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 16   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 17   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 18   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 19   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 20   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 21   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 22   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 23   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 24   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 25   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 26   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 27   [90, 106, 4, 93, 16, 87, 67, 85]  [34, 30, 47, 80, 14, 11, 22, 86]
# 28  [107, 53, 76, 30, 8, 110, 92, 54]    [32, 62, 23, 34, 5, 4, 60, 46]
#
#               PointingTaskTargets_25           PointingTaskTargets_26  \
# 0   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 1   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 2   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 3   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 4   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 5   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 6   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 7   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 8   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 9   [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 10  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 11  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 12  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 13  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 14  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 15  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 16  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 17  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 18  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 19  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 20  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 21  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 22  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 23  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 24  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 25  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 26  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 27  [78, 60, 63, 107, 58, 44, 61, 0]    [75, 91, 3, 9, 12, 23, 4, 16]
# 28   [101, 76, 105, 2, 9, 24, 8, 12]  [46, 12, 2, 0, 33, 59, 101, 90]
#
#               PointingTaskTargets_27                PointingTaskTargets_28
# 0    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 1    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 2    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 3    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 4    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 5    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 6    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 7    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 8    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 9    [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 10   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 11   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 12   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 13   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 14   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 15   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 16   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 17   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 18   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 19   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 20   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 21   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 22   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 23   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 24   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 25   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 26   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 27   [82, 98, 92, 91, 62, 73, 7, 48]      [36, 81, 95, 19, 93, 50, 45, 41]
# 28  [72, 14, 60, 42, 106, 6, 53, 59]  [49, 57, 111, 95, 108, 107, 99, 111]
#
# [29 rows x 35 columns]

# %%
StartingPoints.shape
# Out:
# (812, 35)

# %%
StartingPoints = pd.DataFrame(df.explode('PointingTaskStartingLocations'))

# %% [markdown]
# ### Creating StartingPoint ID
#
# We have 28 starting locations, `np.arange(1,29,1)` creates a list starting at 1 and stopping at 28 in 1 unit incrementals and repeats that for the lenght of participants in the data base `len(StartingPoints.ParticipantID.unique()`.

# %%
StartingPoints['StartPointID']= np.tile(np.arange(1,29,1), len(StartingPoints.ParticipantID.unique()))
StartingPoints.head()
# Out:
#    SubjectID  ParticipantID       TaskOrder Language  \
# 0       5743           5743  [PointingTask]  English
# 0       5743           5743  [PointingTask]  English
# 0       5743           5743  [PointingTask]  English
# 0       5743           5743  [PointingTask]  English
# 0       5743           5743  [PointingTask]  English
#
#                                   InitialOrientation  \
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
# 0  {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                               PointingTaskRandomised  \
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
# 0  [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#   PointingTaskStartingLocations            PointingTaskTargets_1  \
# 0                             3  [6, 76, 48, 44, 8, 91, 18, 104]
# 0                            22  [6, 76, 48, 44, 8, 91, 18, 104]
# 0                            27  [6, 76, 48, 44, 8, 91, 18, 104]
# 0                            17  [6, 76, 48, 44, 8, 91, 18, 104]
# 0                             5  [6, 76, 48, 44, 8, 91, 18, 104]
#
#               PointingTaskTargets_2            PointingTaskTargets_3  ...  \
# 0  [83, 60, 15, 32, 11, 10, 31, 33]  [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 0  [83, 60, 15, 32, 11, 10, 31, 33]  [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 0  [83, 60, 15, 32, 11, 10, 31, 33]  [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 0  [83, 60, 15, 32, 11, 10, 31, 33]  [92, 11, 101, 10, 59, 2, 80, 6]  ...
# 0  [83, 60, 15, 32, 11, 10, 31, 33]  [92, 11, 101, 10, 59, 2, 80, 6]  ...
#
#               PointingTaskTargets_20               PointingTaskTargets_21  \
# 0  [36, 110, 99, 60, 93, 97, 73, 79]  [48, 75, 21, 71, 111, 30, 100, 107]
# 0  [36, 110, 99, 60, 93, 97, 73, 79]  [48, 75, 21, 71, 111, 30, 100, 107]
# 0  [36, 110, 99, 60, 93, 97, 73, 79]  [48, 75, 21, 71, 111, 30, 100, 107]
# 0  [36, 110, 99, 60, 93, 97, 73, 79]  [48, 75, 21, 71, 111, 30, 100, 107]
# 0  [36, 110, 99, 60, 93, 97, 73, 79]  [48, 75, 21, 71, 111, 30, 100, 107]
#
#             PointingTaskTargets_22            PointingTaskTargets_23  \
# 0  [88, 73, 88, 2, 99, 31, 93, 56]  [90, 106, 4, 93, 16, 87, 67, 85]
# 0  [88, 73, 88, 2, 99, 31, 93, 56]  [90, 106, 4, 93, 16, 87, 67, 85]
# 0  [88, 73, 88, 2, 99, 31, 93, 56]  [90, 106, 4, 93, 16, 87, 67, 85]
# 0  [88, 73, 88, 2, 99, 31, 93, 56]  [90, 106, 4, 93, 16, 87, 67, 85]
# 0  [88, 73, 88, 2, 99, 31, 93, 56]  [90, 106, 4, 93, 16, 87, 67, 85]
#
#              PointingTaskTargets_24            PointingTaskTargets_25  \
# 0  [34, 30, 47, 80, 14, 11, 22, 86]  [78, 60, 63, 107, 58, 44, 61, 0]
# 0  [34, 30, 47, 80, 14, 11, 22, 86]  [78, 60, 63, 107, 58, 44, 61, 0]
# 0  [34, 30, 47, 80, 14, 11, 22, 86]  [78, 60, 63, 107, 58, 44, 61, 0]
# 0  [34, 30, 47, 80, 14, 11, 22, 86]  [78, 60, 63, 107, 58, 44, 61, 0]
# 0  [34, 30, 47, 80, 14, 11, 22, 86]  [78, 60, 63, 107, 58, 44, 61, 0]
#
#           PointingTaskTargets_26           PointingTaskTargets_27  \
# 0  [75, 91, 3, 9, 12, 23, 4, 16]  [82, 98, 92, 91, 62, 73, 7, 48]
# 0  [75, 91, 3, 9, 12, 23, 4, 16]  [82, 98, 92, 91, 62, 73, 7, 48]
# 0  [75, 91, 3, 9, 12, 23, 4, 16]  [82, 98, 92, 91, 62, 73, 7, 48]
# 0  [75, 91, 3, 9, 12, 23, 4, 16]  [82, 98, 92, 91, 62, 73, 7, 48]
# 0  [75, 91, 3, 9, 12, 23, 4, 16]  [82, 98, 92, 91, 62, 73, 7, 48]
#
#              PointingTaskTargets_28 StartPointID
# 0  [36, 81, 95, 19, 93, 50, 45, 41]            1
# 0  [36, 81, 95, 19, 93, 50, 45, 41]            2
# 0  [36, 81, 95, 19, 93, 50, 45, 41]            3
# 0  [36, 81, 95, 19, 93, 50, 45, 41]            4
# 0  [36, 81, 95, 19, 93, 50, 45, 41]            5
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Exploding the target places accordingly
#
# Since it's necessary to explote 28 diferent variables into specific row ranges, this process starts by creating a list of the future row range conditionals `ExploteID` and a list of the variables to explote `ColumnList`.
#
# This two list are then merge into a dictionary `ExploteDic`

# %%
# Create list of future conditionals for query
ExploteID = []
for item in range(1,29):
    step = 'StartPointID == '  + str(item)
    ExploteID.append(step)

# %%
# Create a list of the column names of variables to explote
ColumnList = list(StartingPoints.iloc[:,7:35].columns)

# %%
# Create dictionary 
ExploteDic = dict(zip(ExploteID, ColumnList))
ExploteDic
# Out:
# {'StartPointID == 1': 'PointingTaskTargets_1',
#  'StartPointID == 2': 'PointingTaskTargets_2',
#  'StartPointID == 3': 'PointingTaskTargets_3',
#  'StartPointID == 4': 'PointingTaskTargets_4',
#  'StartPointID == 5': 'PointingTaskTargets_5',
#  'StartPointID == 6': 'PointingTaskTargets_6',
#  'StartPointID == 7': 'PointingTaskTargets_7',
#  'StartPointID == 8': 'PointingTaskTargets_8',
#  'StartPointID == 9': 'PointingTaskTargets_9',
#  'StartPointID == 10': 'PointingTaskTargets_10',
#  'StartPointID == 11': 'PointingTaskTargets_11',
#  'StartPointID == 12': 'PointingTaskTargets_12',
#  'StartPointID == 13': 'PointingTaskTargets_13',
#  'StartPointID == 14': 'PointingTaskTargets_14',
#  'StartPointID == 15': 'PointingTaskTargets_15',
#  'StartPointID == 16': 'PointingTaskTargets_16',
#  'StartPointID == 17': 'PointingTaskTargets_17',
#  'StartPointID == 18': 'PointingTaskTargets_18',
#  'StartPointID == 19': 'PointingTaskTargets_19',
#  'StartPointID == 20': 'PointingTaskTargets_20',
#  'StartPointID == 21': 'PointingTaskTargets_21',
#  'StartPointID == 22': 'PointingTaskTargets_22',
#  'StartPointID == 23': 'PointingTaskTargets_23',
#  'StartPointID == 24': 'PointingTaskTargets_24',
#  'StartPointID == 25': 'PointingTaskTargets_25',
#  'StartPointID == 26': 'PointingTaskTargets_26',
#  'StartPointID == 27': 'PointingTaskTargets_27',
#  'StartPointID == 28': 'PointingTaskTargets_28'}

# %%
def explote_multiple(dataframe, dic):
    
    """ Creates a list of dataframes that include one exploted variable based row conditionals derivated from
    keys, values contain of a Dictionary
    
Parameters
-------------
     
     :dataframe: your data frame,
     :dic: Dictionary contains a list of key values that will inform a query of the df
     and values that contain the names of columns to explote. 
returns 
----------

    List of DataFrames
     """

    tempdf = [] #Empty list to store each exploted data set
    for conditional, variable_to_explote in dic.items():
        data_q = dataframe.query(conditional).explode(variable_to_explote)
        ques = pd.DataFrame(data_q)
        tempdf.append(ques)
    data_frames_list = pd.concat(tempdf, axis=0)
    return data_frames_list

# %%
ExploteAplication = explote_multiple(StartingPoints, ExploteDic)
ExploteAplication.shape
# Out:
# (6496, 36)

# %%
ExploteAplication.set_index(['ParticipantID', 'StartPointID'], inplace= True)

# %%
# Probe of concept how to just retain integers AKA the exploted data
b = pd.DataFrame( ExploteAplication['PointingTaskTargets_1'][ExploteAplication['PointingTaskTargets_1'].map(type)==int])
b.tail()
# Out:
#                            PointingTaskTargets_1
# ParticipantID StartPointID
# 5191          1                               69
#               1                              107
#               1                                7
#               1                               17
#               1                                8

# %%
def integrate_explote(dataframe, list_variables):
    empty = []
    for l in  list_variables:
        step = dataframe[l][dataframe[l].map(type)==int]
        empty.append(step)
    finals = pd.DataFrame(pd.concat(empty, axis=0), columns= ['Target'])
    dataframe['Trials'] = finals['Target']
    return dataframe

# %%
Integrated = integrate_explote(ExploteAplication, ColumnList)
Integrated.info()
print(Integrated.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6496 entries, (5743, 1) to (5191, 28)
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      6496 non-null   int64
#  1   TaskOrder                      6496 non-null   object
#  2   Language                       6496 non-null   object
#  3   InitialOrientation             6496 non-null   object
#  4   PointingTaskRandomised         6496 non-null   object
#  5   PointingTaskStartingLocations  6496 non-null   object
#  6   PointingTaskTargets_1          6496 non-null   object
#  7   PointingTaskTargets_2          6496 non-null   object
#  8   PointingTaskTargets_3          6496 non-null   object
#  9   PointingTaskTargets_4          6496 non-null   object
#  10  PointingTaskTargets_5          6496 non-null   object
#  11  PointingTaskTargets_6          6496 non-null   object
#  12  PointingTaskTargets_7          6496 non-null   object
#  13  PointingTaskTargets_8          6496 non-null   object
#  14  PointingTaskTargets_9          6496 non-null   object
#  15  PointingTaskTargets_10         6496 non-null   object
#  16  PointingTaskTargets_11         6496 non-null   object
#  17  PointingTaskTargets_12         6496 non-null   object
#  18  PointingTaskTargets_13         6496 non-null   object
#  19  PointingTaskTargets_14         6496 non-null   object
#  20  PointingTaskTargets_15         6496 non-null   object
#  21  PointingTaskTargets_16         6496 non-null   object
#  22  PointingTaskTargets_17         6496 non-null   object
#  23  PointingTaskTargets_18         6496 non-null   object
#  24  PointingTaskTargets_19         6496 non-null   object
#  25  PointingTaskTargets_20         6496 non-null   object
#  26  PointingTaskTargets_21         6496 non-null   object
#  27  PointingTaskTargets_22         6496 non-null   object
#  28  PointingTaskTargets_23         6496 non-null   object
#  29  PointingTaskTargets_24         6496 non-null   object
#  30  PointingTaskTargets_25         6496 non-null   object
#  31  PointingTaskTargets_26         6496 non-null   object
#  32  PointingTaskTargets_27         6496 non-null   object
#  33  PointingTaskTargets_28         6496 non-null   object
#  34  Trials                         6496 non-null   object
# dtypes: int64(1), object(34)
# memory usage: 1.7+ MB
#                             SubjectID       TaskOrder Language  \
# ParticipantID StartPointID
# 5191          28                 5191  [PointingTask]  English
#               28                 5191  [PointingTask]  English
#               28                 5191  [PointingTask]  English
#               28                 5191  [PointingTask]  English
#               28                 5191  [PointingTask]  English
#
#                                                            InitialOrientation  \
# ParticipantID StartPointID
# 5191          28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#               28            {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                                        PointingTaskRandomised  \
# ParticipantID StartPointID
# 5191          28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               28            [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                            PointingTaskStartingLocations  \
# ParticipantID StartPointID
# 5191          28                                      25
#               28                                      25
#               28                                      25
#               28                                      25
#               28                                      25
#
#                                       PointingTaskTargets_1  \
# ParticipantID StartPointID
# 5191          28            [88, 69, 51, 69, 107, 7, 17, 8]
#               28            [88, 69, 51, 69, 107, 7, 17, 8]
#               28            [88, 69, 51, 69, 107, 7, 17, 8]
#               28            [88, 69, 51, 69, 107, 7, 17, 8]
#               28            [88, 69, 51, 69, 107, 7, 17, 8]
#
#                                         PointingTaskTargets_2  \
# ParticipantID StartPointID
# 5191          28            [14, 83, 93, 92, 107, 94, 68, 18]
#               28            [14, 83, 93, 92, 107, 94, 68, 18]
#               28            [14, 83, 93, 92, 107, 94, 68, 18]
#               28            [14, 83, 93, 92, 107, 94, 68, 18]
#               28            [14, 83, 93, 92, 107, 94, 68, 18]
#
#                                          PointingTaskTargets_3  \
# ParticipantID StartPointID
# 5191          28            [103, 2, 65, 100, 83, 111, 95, 62]
#               28            [103, 2, 65, 100, 83, 111, 95, 62]
#               28            [103, 2, 65, 100, 83, 111, 95, 62]
#               28            [103, 2, 65, 100, 83, 111, 95, 62]
#               28            [103, 2, 65, 100, 83, 111, 95, 62]
#
#                                        PointingTaskTargets_4  ...  \
# ParticipantID StartPointID                                    ...
# 5191          28            [95, 23, 73, 72, 36, 61, 28, 79]  ...
#               28            [95, 23, 73, 72, 36, 61, 28, 79]  ...
#               28            [95, 23, 73, 72, 36, 61, 28, 79]  ...
#               28            [95, 23, 73, 72, 36, 61, 28, 79]  ...
#               28            [95, 23, 73, 72, 36, 61, 28, 79]  ...
#
#                                          PointingTaskTargets_20  \
# ParticipantID StartPointID
# 5191          28            [15, 51, 44, 103, 96, 51, 108, 103]
#               28            [15, 51, 44, 103, 96, 51, 108, 103]
#               28            [15, 51, 44, 103, 96, 51, 108, 103]
#               28            [15, 51, 44, 103, 96, 51, 108, 103]
#               28            [15, 51, 44, 103, 96, 51, 108, 103]
#
#                                        PointingTaskTargets_21  \
# ParticipantID StartPointID
# 5191          28            [67, 17, 111, 29, 96, 14, 26, 46]
#               28            [67, 17, 111, 29, 96, 14, 26, 46]
#               28            [67, 17, 111, 29, 96, 14, 26, 46]
#               28            [67, 17, 111, 29, 96, 14, 26, 46]
#               28            [67, 17, 111, 29, 96, 14, 26, 46]
#
#                                      PointingTaskTargets_22  \
# ParticipantID StartPointID
# 5191          28            [84, 42, 79, 46, 60, 14, 5, 69]
#               28            [84, 42, 79, 46, 60, 14, 5, 69]
#               28            [84, 42, 79, 46, 60, 14, 5, 69]
#               28            [84, 42, 79, 46, 60, 14, 5, 69]
#               28            [84, 42, 79, 46, 60, 14, 5, 69]
#
#                                          PointingTaskTargets_23  \
# ParticipantID StartPointID
# 5191          28            [57, 88, 109, 106, 109, 53, 65, 50]
#               28            [57, 88, 109, 106, 109, 53, 65, 50]
#               28            [57, 88, 109, 106, 109, 53, 65, 50]
#               28            [57, 88, 109, 106, 109, 53, 65, 50]
#               28            [57, 88, 109, 106, 109, 53, 65, 50]
#
#                                     PointingTaskTargets_24  \
# ParticipantID StartPointID
# 5191          28            [3, 88, 25, 58, 39, 9, 48, 51]
#               28            [3, 88, 25, 58, 39, 9, 48, 51]
#               28            [3, 88, 25, 58, 39, 9, 48, 51]
#               28            [3, 88, 25, 58, 39, 9, 48, 51]
#               28            [3, 88, 25, 58, 39, 9, 48, 51]
#
#                                       PointingTaskTargets_25  \
# ParticipantID StartPointID
# 5191          28            [87, 18, 101, 92, 103, 3, 70, 3]
#               28            [87, 18, 101, 92, 103, 3, 70, 3]
#               28            [87, 18, 101, 92, 103, 3, 70, 3]
#               28            [87, 18, 101, 92, 103, 3, 70, 3]
#               28            [87, 18, 101, 92, 103, 3, 70, 3]
#
#                                      PointingTaskTargets_26  \
# ParticipantID StartPointID
# 5191          28            [26, 70, 49, 42, 86, 54, 0, 46]
#               28            [26, 70, 49, 42, 86, 54, 0, 46]
#               28            [26, 70, 49, 42, 86, 54, 0, 46]
#               28            [26, 70, 49, 42, 86, 54, 0, 46]
#               28            [26, 70, 49, 42, 86, 54, 0, 46]
#
#                                      PointingTaskTargets_27  \
# ParticipantID StartPointID
# 5191          28            [86, 46, 7, 53, 2, 105, 13, 60]
#               28            [86, 46, 7, 53, 2, 105, 13, 60]
#               28            [86, 46, 7, 53, 2, 105, 13, 60]
#               28            [86, 46, 7, 53, 2, 105, 13, 60]
#               28            [86, 46, 7, 53, 2, 105, 13, 60]
#
#                            PointingTaskTargets_28 Trials
# ParticipantID StartPointID
# 5191          28                               80     80
#               28                               38     38
#               28                               16     16
#               28                                8      8
#               28                               28     28
#
# [5 rows x 35 columns]

# %%
Integrated.sort_index(level= ['ParticipantID'], inplace=True)
Integrated.head()
# Out:
#                             SubjectID       TaskOrder Language  \
# ParticipantID StartPointID
# 1031          1                  1031  [PointingTask]  Deutsch
#               1                  1031  [PointingTask]  Deutsch
#               1                  1031  [PointingTask]  Deutsch
#               1                  1031  [PointingTask]  Deutsch
#               1                  1031  [PointingTask]  Deutsch
#
#                                                            InitialOrientation  \
# ParticipantID StartPointID
# 1031          1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#               1             {'x': 0.0008186895865940001, 'y': -0.906321287...
#
#                                                        PointingTaskRandomised  \
# ParticipantID StartPointID
# 1031          1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#               1             [{'Block': 1, 'LocationNumber': 1, 'StartingPo...
#
#                            PointingTaskStartingLocations  \
# ParticipantID StartPointID
# 1031          1                                       21
#               1                                       21
#               1                                       21
#               1                                       21
#               1                                       21
#
#                            PointingTaskTargets_1  \
# ParticipantID StartPointID
# 1031          1                               11
#               1                              106
#               1                               70
#               1                               62
#               1                               19
#
#                                        PointingTaskTargets_2  \
# ParticipantID StartPointID
# 1031          1             [12, 81, 20, 9, 48, 103, 21, 66]
#               1             [12, 81, 20, 9, 48, 103, 21, 66]
#               1             [12, 81, 20, 9, 48, 103, 21, 66]
#               1             [12, 81, 20, 9, 48, 103, 21, 66]
#               1             [12, 81, 20, 9, 48, 103, 21, 66]
#
#                                         PointingTaskTargets_3  \
# ParticipantID StartPointID
# 1031          1             [93, 44, 60, 26, 96, 85, 83, 109]
#               1             [93, 44, 60, 26, 96, 85, 83, 109]
#               1             [93, 44, 60, 26, 96, 85, 83, 109]
#               1             [93, 44, 60, 26, 96, 85, 83, 109]
#               1             [93, 44, 60, 26, 96, 85, 83, 109]
#
#                                       PointingTaskTargets_4  ...  \
# ParticipantID StartPointID                                   ...
# 1031          1             [6, 42, 11, 13, 56, 12, 46, 58]  ...
#               1             [6, 42, 11, 13, 56, 12, 46, 58]  ...
#               1             [6, 42, 11, 13, 56, 12, 46, 58]  ...
#               1             [6, 42, 11, 13, 56, 12, 46, 58]  ...
#               1             [6, 42, 11, 13, 56, 12, 46, 58]  ...
#
#                                       PointingTaskTargets_20  \
# ParticipantID StartPointID
# 1031          1             [58, 62, 25, 56, 96, 64, 57, 81]
#               1             [58, 62, 25, 56, 96, 64, 57, 81]
#               1             [58, 62, 25, 56, 96, 64, 57, 81]
#               1             [58, 62, 25, 56, 96, 64, 57, 81]
#               1             [58, 62, 25, 56, 96, 64, 57, 81]
#
#                                        PointingTaskTargets_21  \
# ParticipantID StartPointID
# 1031          1             [55, 97, 67, 29, 39, 105, 98, 59]
#               1             [55, 97, 67, 29, 39, 105, 98, 59]
#               1             [55, 97, 67, 29, 39, 105, 98, 59]
#               1             [55, 97, 67, 29, 39, 105, 98, 59]
#               1             [55, 97, 67, 29, 39, 105, 98, 59]
#
#                                        PointingTaskTargets_22  \
# ParticipantID StartPointID
# 1031          1             [44, 9, 78, 13, 62, 103, 109, 68]
#               1             [44, 9, 78, 13, 62, 103, 109, 68]
#               1             [44, 9, 78, 13, 62, 103, 109, 68]
#               1             [44, 9, 78, 13, 62, 103, 109, 68]
#               1             [44, 9, 78, 13, 62, 103, 109, 68]
#
#                                          PointingTaskTargets_23  \
# ParticipantID StartPointID
# 1031          1             [22, 100, 49, 103, 33, 89, 82, 107]
#               1             [22, 100, 49, 103, 33, 89, 82, 107]
#               1             [22, 100, 49, 103, 33, 89, 82, 107]
#               1             [22, 100, 49, 103, 33, 89, 82, 107]
#               1             [22, 100, 49, 103, 33, 89, 82, 107]
#
#                                       PointingTaskTargets_24  \
# ParticipantID StartPointID
# 1031          1             [92, 62, 19, 63, 62, 45, 33, 46]
#               1             [92, 62, 19, 63, 62, 45, 33, 46]
#               1             [92, 62, 19, 63, 62, 45, 33, 46]
#               1             [92, 62, 19, 63, 62, 45, 33, 46]
#               1             [92, 62, 19, 63, 62, 45, 33, 46]
#
#                                       PointingTaskTargets_25  \
# ParticipantID StartPointID
# 1031          1             [78, 52, 39, 101, 5, 84, 23, 34]
#               1             [78, 52, 39, 101, 5, 84, 23, 34]
#               1             [78, 52, 39, 101, 5, 84, 23, 34]
#               1             [78, 52, 39, 101, 5, 84, 23, 34]
#               1             [78, 52, 39, 101, 5, 84, 23, 34]
#
#                                      PointingTaskTargets_26  \
# ParticipantID StartPointID
# 1031          1             [89, 2, 76, 1, 105, 66, 67, 64]
#               1             [89, 2, 76, 1, 105, 66, 67, 64]
#               1             [89, 2, 76, 1, 105, 66, 67, 64]
#               1             [89, 2, 76, 1, 105, 66, 67, 64]
#               1             [89, 2, 76, 1, 105, 66, 67, 64]
#
#                                        PointingTaskTargets_27  \
# ParticipantID StartPointID
# 1031          1             [33, 108, 48, 48, 44, 50, 55, 49]
#               1             [33, 108, 48, 48, 44, 50, 55, 49]
#               1             [33, 108, 48, 48, 44, 50, 55, 49]
#               1             [33, 108, 48, 48, 44, 50, 55, 49]
#               1             [33, 108, 48, 48, 44, 50, 55, 49]
#
#                                       PointingTaskTargets_28 Trials
# ParticipantID StartPointID
# 1031          1             [39, 45, 49, 39, 55, 27, 53, 31]     11
#               1             [39, 45, 49, 39, 55, 27, 53, 31]    106
#               1             [39, 45, 49, 39, 55, 27, 53, 31]     70
#               1             [39, 45, 49, 39, 55, 27, 53, 31]     62
#               1             [39, 45, 49, 39, 55, 27, 53, 31]     19
#
# [5 rows x 35 columns]

# %%
Targets = Integrated.loc[:,['SubjectID','PointingTaskStartingLocations','Trials']]
Targets.head()
print(Targets.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6496 entries, (1031, 1) to (9627, 28)
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      6496 non-null   int64
#  1   PointingTaskStartingLocations  6496 non-null   object
#  2   Trials                         6496 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 167.6+ KB
# None

# %%
Final = Targets
#Include trial ID for all trials
Final['TrialID']= np.tile(np.arange(1,225,1), len(Final.SubjectID.unique()))
Final.head()
# Out:
#                             SubjectID PointingTaskStartingLocations Trials  \
# ParticipantID StartPointID
# 1031          1                  1031                            21     11
#               1                  1031                            21    106
#               1                  1031                            21     70
#               1                  1031                            21     62
#               1                  1031                            21     19
#
#                             TrialID
# ParticipantID StartPointID
# 1031          1                   1
#               1                   2
#               1                   3
#               1                   4
#               1                   5

# %%
#Include marker for each starting position
SubjectNum = len(df.SubjectID.unique())
#Final['MainID_for_StartingPosition']= np.tile(np.arange(1,29,12),SubjectNum)
Final['ID_for_StartingPosition']= np.tile(np.arange(1,9,1), (SubjectNum*28))
Final.head(16)
# Out:
#                             SubjectID PointingTaskStartingLocations Trials  \
# ParticipantID StartPointID
# 1031          1                  1031                            21     11
#               1                  1031                            21    106
#               1                  1031                            21     70
#               1                  1031                            21     62
#               1                  1031                            21     19
#               1                  1031                            21     93
#               1                  1031                            21     72
#               1                  1031                            21     67
#               2                  1031                             8     12
#               2                  1031                             8     81
#               2                  1031                             8     20
#               2                  1031                             8      9
#               2                  1031                             8     48
#               2                  1031                             8    103
#               2                  1031                             8     21
#               2                  1031                             8     66
#
#                             TrialID  ID_for_StartingPosition
# ParticipantID StartPointID
# 1031          1                   1                        1
#               1                   2                        2
#               1                   3                        3
#               1                   4                        4
#               1                   5                        5
#               1                   6                        6
#               1                   7                        7
#               1                   8                        8
#               2                   9                        1
#               2                  10                        2
#               2                  11                        3
#               2                  12                        4
#               2                  13                        5
#               2                  14                        6
#               2                  15                        7
#               2                  16                        8

# %%
np.tile(np.arange(1,29,1),(SubjectNum*12))
# Out:
# array([ 1,  2,  3, ..., 26, 27, 28])

# %%
FinalIds = Targets.reset_index()
FinalIds.head()
# Out:
#    ParticipantID  StartPointID  SubjectID PointingTaskStartingLocations  \
# 0           1031             1       1031                            21
# 1           1031             1       1031                            21
# 2           1031             1       1031                            21
# 3           1031             1       1031                            21
# 4           1031             1       1031                            21
#
#   Trials  TrialID  ID_for_StartingPosition
# 0     11        1                        1
# 1    106        2                        2
# 2     70        3                        3
# 3     62        4                        4
# 4     19        5                        5

# %% [markdown]
# # Reading the participants data from the pointingTask files

# %% [markdown]
# ## Loading performance data

# %%
#Setting a new path for performance data
os.chdir('/Volumes/TwoTeras/1_Experiment_2/Pointing_Task/Final')
os.getcwd()
path = "*.json"

# %%
# create empty dataframe
df = pd.DataFrame()

# read every file name in folder
for filename in glob.glob(path):
    if "TaskDataFrame" in filename and "EyeTracking" not in filename:
        with open(filename, 'r') as file:
            # make json files parsable
            data = "[" + file.read()
            data = data[:len(data)-2] + "]"

            # read data per file
            subjectdf = pd.read_json(data)
            if len(subjectdf) == 224:

                # insert participant id in every line
                subjectdf.insert(0, "SubjectID", [int(filename[0:4])] * subjectdf.shape[0], True)
                #subjectdf.insert(0, "SubjectID", [int(filename[6:10])] * subjectdf.shape[0], True)
                df = df.append(subjectdf, ignore_index=True)
df
# Out:
#       SubjectID  TrialNumber  ImageIndexNumber       ImageName  TimeOut  \
# 0          1843            1                95   27_SaNoAct_37    False
# 1          1843            2                55  03_CmANoAct_16    False
# 2          1843            3                71      44_SaNo_18    False
# 3          1843            4                47  02_CmANoAct_13    False
# 4          1843            5                26    24_CmAAct_11    False
# ...         ...          ...               ...             ...      ...
# 6939       5191          220                80        54_Sa_26    False
# 6940       5191          221                38    10_CmAAct_58    False
# 6941       5191          222                16       42_CmA_45    False
# 6942       5191          223                 8       36_CmA_57    False
# 6943       5191          224                28       35_CmA_42    False
#
#                     TimeStampBegin                  TimeStampEnd         RT  \
# 0    2023-03-30 11:41:55.468401408 2023-03-30 11:42:07.024395520  11.555994
# 1    2023-03-30 11:42:07.289725952 2023-03-30 11:42:21.834798848  14.545073
# 2    2023-03-30 11:42:22.102088704 2023-03-30 11:42:37.953455872  15.851367
# 3    2023-03-30 11:42:38.229200384 2023-03-30 11:42:48.501195520  10.271995
# 4    2023-03-30 11:42:48.768013056 2023-03-30 11:42:54.527908864   5.759896
# ...                            ...                           ...        ...
# 6939 2023-08-28 10:19:14.209730560 2023-08-28 10:19:18.296797952   4.087067
# 6940 2023-08-28 10:19:18.565134336 2023-08-28 10:19:25.141642752   6.576509
# 6941 2023-08-28 10:19:25.423867648 2023-08-28 10:19:28.515952896   3.092085
# 6942 2023-08-28 10:19:28.781313792 2023-08-28 10:19:30.896275968   2.114962
# 6943 2023-08-28 10:19:31.166097664 2023-08-28 10:19:32.740412160   1.574315
#
#            Angle  TriggerPressedFreq  ...  \
# 0       6.212492                   2  ...
# 1     176.476852                   2  ...
# 2      33.175674                   2  ...
# 3      44.411446                   2  ...
# 4      26.657282                   2  ...
# ...          ...                 ...  ...
# 6939  136.246887                   2  ...
# 6940   20.873833                   2  ...
# 6941   22.649485                   2  ...
# 6942   29.698551                   2  ...
# 6943   18.863068                   2  ...
#
#                                         PointerPosition  \
# 0     {'x': -65.58757019042969, 'y': -1.936135768890...
# 1     {'x': -65.92585754394531, 'y': -1.885559797286...
# 2     {'x': -65.12919616699219, 'y': -1.757662534713...
# 3     {'x': -65.36955261230469, 'y': -1.824475765228...
# 4     {'x': -65.27583312988281, 'y': -1.841671466827...
# ...                                                 ...
# 6939  {'x': -320.875244140625, 'y': 3.72459244728088...
# 6940  {'x': -320.623046875, 'y': 3.6546308994293213,...
# 6941  {'x': -320.924072265625, 'y': 3.71479725837707...
# 6942  {'x': -320.6651611328125, 'y': 3.7143204212188...
# 6943  {'x': -320.666748046875, 'y': 3.72280716896057...
#
#                                         PointerRotation  \
# 0     {'x': 1.18949544429779, 'y': 147.0052642822265...
# 1     {'x': 356.23907470703125, 'y': 255.32406616210...
# 2     {'x': 359.01812744140625, 'y': 71.007621765136...
# 3     {'x': 0.065276987850666, 'y': 14.0942058563232...
# 4     {'x': 0.7380660772323601, 'y': 91.204925537109...
# ...                                                 ...
# 6939  {'x': 3.714740514755249, 'y': 318.614990234375...
# 6940  {'x': 359.6407775878906, 'y': 85.2814178466796...
# 6941  {'x': 0.439910352230072, 'y': 171.726196289062...
# 6942  {'x': 359.70050048828125, 'y': 83.007820129394...
# 6943  {'x': 359.0130920410156, 'y': 94.8463516235351...
#
#                               PointerRotationQuaternion  \
# 0     {'x': -0.050354115664958, 'y': 0.9574624896049...
# 1     {'x': 0.07295900583267201, 'y': -0.78808623552...
# 2     {'x': -0.13389198482036502, 'y': 0.56513333320...
# 3     {'x': -0.016305413097143, 'y': 0.1215982064604...
# 4     {'x': -0.007493665907531001, 'y': 0.7144628167...
# ...                                                 ...
# 6939  {'x': -0.047023221850395, 'y': -0.351333111524...
# 6940  {'x': -0.21623107790946902, 'y': 0.64196109771...
# 6941  {'x': -0.431296199560165, 'y': 0.8993135690689...
# 6942  {'x': -0.28820413351058904, 'y': 0.59671795368...
# 6943  {'x': -0.33879950642585704, 'y': 0.65379709005...
#
#                                        PointerDirection  \
# 0     {'x': 0.544444680213928, 'y': -0.0207591187208...
# 1     {'x': -0.9652909636497491, 'y': 0.065593421459...
# 2     {'x': 0.9454231858253471, 'y': 0.0171360224485...
# 3     {'x': 0.243516772985458, 'y': -0.0011392980813...
# 4     {'x': 0.9996959567070001, 'y': -0.012881326489...
# ...                                                 ...
# 6939  {'x': -0.6597265601158141, 'y': -0.06478904187...
# 6940  {'x': 0.9965912103652951, 'y': 0.0062694549560...
# 6941  {'x': 0.14389958977699202, 'y': -0.00767780840...
# 6942  {'x': 0.9925492405891411, 'y': 0.0052273869514...
# 6943  {'x': 0.9962770342826841, 'y': 0.0172238051891...
#
#           TargetBuildingName  \
# 0            TaskBuilding_37
# 1     Church-TaskBuilding_16
# 2            TaskBuilding_18
# 3            TaskBuilding_13
# 4            TaskBuilding_11
# ...                      ...
# 6939         TaskBuilding_26
# 6940      BasketballCourt_58
# 6941         TaskBuilding_45
# 6942         Construction_57
# 6943         TaskBuilding_42
#
#                                  TargetBuildingPosition  \
# 0     {'x': -43.78580856323242, 'y': -4.851409912109...
# 1     {'x': 280.644775390625, 'y': -2.90533447265625...
# 2     {'x': 157.62081909179688, 'y': -1.219543457031...
# 3     {'x': 293.9781188964844, 'y': -1.6604042053222...
# 4     {'x': 341.9414367675781, 'y': -1.7288055419921...
# ...                                                 ...
# 6939  {'x': 87.63272094726562, 'y': -0.7474174499511...
# 6940  {'x': 104.33999633789062, 'y': -3.069999933242...
# 6941  {'x': -153.3925018310547, 'y': -2.514328002929...
# 6942  {'x': -71.80340576171875, 'y': 0.5511384606361...
# 6943  {'x': -134.4729766845703, 'y': 0.9746377468109...
#
#                                  TargetBuildingRotation  \
# 0     {'x': 2.9802322387695312e-08, 'y': 0.295501589...
# 1     {'x': 0.6761559247970581, 'y': -0.206913754343...
# 2     {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
# 3     {'x': -8.940696716308594e-08, 'y': 0.809439539...
# 4     {'x': 2.9802322387695312e-08, 'y': 0.961893081...
# ...                                                 ...
# 6939  {'x': 0.0, 'y': 0.9338998794555661, 'z': -2.08...
# 6940  {'x': 0.0, 'y': -0.353580743074417, 'z': 0.0, ...
# 6941  {'x': 0.0, 'y': 0.26263874769210804, 'z': -7.4...
# 6942  {'x': -0.638303041458129, 'y': -0.304252058267...
# 6943  {'x': 0.299532175064086, 'y': 0.64053124189376...
#
#                                   TargetBuildingForward DistanceToParticipant  \
# 0     {'x': 0.564610362052917, 'y': -1.0978263986771...             48.799427
# 1     {'x': -3.576278686523437e-07, 'y': -1.0, 'z': ...            352.905640
# 2     {'x': 0.783807098865509, 'y': -5.1893408681280...            363.397705
# 3     {'x': -0.9506110548973081, 'y': -3.94478263388...            421.682709
# 4     {'x': 0.5260127186775201, 'y': -2.456306162912...            451.145996
# ...                                                 ...                   ...
# 6939  {'x': 0.6678031682968141, 'y': -3.896533939951...            410.156464
# 6940  {'x': -0.661481738090515, 'y': 0.0, 'z': 0.749...            442.923798
# 6941  {'x': 0.5068372488021851, 'y': -3.913622492746...            326.605377
# 6942  {'x': 1.4901161193847648e-07, 'y': 1.000000119...            270.194916
# 6943  {'x': 2.9802322387695312e-08, 'y': -1.0, 'z': ...            203.804214
#
#                                       PointedDirections
# 0     [{'x': 0.544444680213928, 'y': -0.020759118720...
# 1     [{'x': -0.9652909636497491, 'y': 0.06559342145...
# 2     [{'x': 0.9454231858253471, 'y': 0.017136022448...
# 3     [{'x': 0.243516772985458, 'y': -0.001139298081...
# 4     [{'x': 0.9996959567070001, 'y': -0.01288132648...
# ...                                                 ...
# 6939  [{'x': -0.6597265601158141, 'y': -0.0647890418...
# 6940  [{'x': 0.9965912103652951, 'y': 0.006269454956...
# 6941  [{'x': 0.14389958977699202, 'y': -0.0076778084...
# 6942  [{'x': 0.9925492405891411, 'y': 0.005227386951...
# 6943  [{'x': 0.9962770342826841, 'y': 0.017223805189...
#
# [6944 rows x 28 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ## Extracting the Avatar number from the variable 'ImageName'

# %%
#The avatarID info is included in a string variable, here we extracted just the ID number and place it into a new variable
#df['avatarID'] = df['ImageName'].str.extractall('(\d+)').unstack().loc[:,0][0]
df['avatarID'] = df['ImageName'].str.extractall('(\d+)').unstack().loc[:,0][0]

# %%
AvaIDs = []
for idx, row in df.iterrows():
    num = re.findall(r'\d+', row['ImageName'])
    AvaIDs.append(num)
# Flatten the list: Every number was returned as a list of it's own with this we get one unified list
avatarIDsf = [item for sublist in AvaIDs for item in sublist]

# %%
df['AvatarPresence'] = df['ImageName'].str.contains('No')
df.loc[:, 'AvatarPresenceCategory'] = df['AvatarPresence'].replace({True: 'Omitted', False: 'Present'})
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber       ImageName  TimeOut  \
# 0       1843            1                95   27_SaNoAct_37    False
# 1       1843            2                55  03_CmANoAct_16    False
# 2       1843            3                71      44_SaNo_18    False
# 3       1843            4                47  02_CmANoAct_13    False
# 4       1843            5                26    24_CmAAct_11    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2023-03-30 11:41:55.468401408 2023-03-30 11:42:07.024395520  11.555994
# 1 2023-03-30 11:42:07.289725952 2023-03-30 11:42:21.834798848  14.545073
# 2 2023-03-30 11:42:22.102088704 2023-03-30 11:42:37.953455872  15.851367
# 3 2023-03-30 11:42:38.229200384 2023-03-30 11:42:48.501195520  10.271995
# 4 2023-03-30 11:42:48.768013056 2023-03-30 11:42:54.527908864   5.759896
#
#         Angle  TriggerPressedFreq  ...  \
# 0    6.212492                   2  ...
# 1  176.476852                   2  ...
# 2   33.175674                   2  ...
# 3   44.411446                   2  ...
# 4   26.657282                   2  ...
#
#                                     PointerDirection      TargetBuildingName  \
# 0  {'x': 0.544444680213928, 'y': -0.0207591187208...         TaskBuilding_37
# 1  {'x': -0.9652909636497491, 'y': 0.065593421459...  Church-TaskBuilding_16
# 2  {'x': 0.9454231858253471, 'y': 0.0171360224485...         TaskBuilding_18
# 3  {'x': 0.243516772985458, 'y': -0.0011392980813...         TaskBuilding_13
# 4  {'x': 0.9996959567070001, 'y': -0.012881326489...         TaskBuilding_11
#
#                               TargetBuildingPosition  \
# 0  {'x': -43.78580856323242, 'y': -4.851409912109...
# 1  {'x': 280.644775390625, 'y': -2.90533447265625...
# 2  {'x': 157.62081909179688, 'y': -1.219543457031...
# 3  {'x': 293.9781188964844, 'y': -1.6604042053222...
# 4  {'x': 341.9414367675781, 'y': -1.7288055419921...
#
#                               TargetBuildingRotation  \
# 0  {'x': 2.9802322387695312e-08, 'y': 0.295501589...
# 1  {'x': 0.6761559247970581, 'y': -0.206913754343...
# 2  {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
# 3  {'x': -8.940696716308594e-08, 'y': 0.809439539...
# 4  {'x': 2.9802322387695312e-08, 'y': 0.961893081...
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.564610362052917, 'y': -1.0978263986771...             48.799427
# 1  {'x': -3.576278686523437e-07, 'y': -1.0, 'z': ...            352.905640
# 2  {'x': 0.783807098865509, 'y': -5.1893408681280...            363.397705
# 3  {'x': -0.9506110548973081, 'y': -3.94478263388...            421.682709
# 4  {'x': 0.5260127186775201, 'y': -2.456306162912...            451.145996
#
#                                    PointedDirections avatarID AvatarPresence  \
# 0  [{'x': 0.544444680213928, 'y': -0.020759118720...       27           True
# 1  [{'x': -0.9652909636497491, 'y': 0.06559342145...       03           True
# 2  [{'x': 0.9454231858253471, 'y': 0.017136022448...       44           True
# 3  [{'x': 0.243516772985458, 'y': -0.001139298081...       02           True
# 4  [{'x': 0.9996959567070001, 'y': -0.01288132648...       24          False
#
#   AvatarPresenceCategory
# 0                Omitted
# 1                Omitted
# 2                Omitted
# 3                Omitted
# 4                Present
#
# [5 rows x 31 columns]

# %%
#Checking that value counts for Avatar presence [Should be 50/50]
df.AvatarPresenceCategory.value_counts()
# Out:
# Omitted    3476
# Present    3468
# Name: AvatarPresenceCategory, dtype: int64

# %%
df['meaningful'] = df['ImageName'].str.contains('CmA')
#df.loc[:, 'BuildingCategory'] = df['meaningful'].replace({True: 'Public', False: 'Residential'})
df.loc[:, 'meaningfulBuilding'] = df['meaningful'].replace({True: 'meaningful', False: 'Not meaningful'})
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber       ImageName  TimeOut  \
# 0       1843            1                95   27_SaNoAct_37    False
# 1       1843            2                55  03_CmANoAct_16    False
# 2       1843            3                71      44_SaNo_18    False
# 3       1843            4                47  02_CmANoAct_13    False
# 4       1843            5                26    24_CmAAct_11    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2023-03-30 11:41:55.468401408 2023-03-30 11:42:07.024395520  11.555994
# 1 2023-03-30 11:42:07.289725952 2023-03-30 11:42:21.834798848  14.545073
# 2 2023-03-30 11:42:22.102088704 2023-03-30 11:42:37.953455872  15.851367
# 3 2023-03-30 11:42:38.229200384 2023-03-30 11:42:48.501195520  10.271995
# 4 2023-03-30 11:42:48.768013056 2023-03-30 11:42:54.527908864   5.759896
#
#         Angle  TriggerPressedFreq  ...  \
# 0    6.212492                   2  ...
# 1  176.476852                   2  ...
# 2   33.175674                   2  ...
# 3   44.411446                   2  ...
# 4   26.657282                   2  ...
#
#                               TargetBuildingPosition  \
# 0  {'x': -43.78580856323242, 'y': -4.851409912109...
# 1  {'x': 280.644775390625, 'y': -2.90533447265625...
# 2  {'x': 157.62081909179688, 'y': -1.219543457031...
# 3  {'x': 293.9781188964844, 'y': -1.6604042053222...
# 4  {'x': 341.9414367675781, 'y': -1.7288055419921...
#
#                               TargetBuildingRotation  \
# 0  {'x': 2.9802322387695312e-08, 'y': 0.295501589...
# 1  {'x': 0.6761559247970581, 'y': -0.206913754343...
# 2  {'x': 0.0, 'y': 0.435313463211059, 'z': -5.960...
# 3  {'x': -8.940696716308594e-08, 'y': 0.809439539...
# 4  {'x': 2.9802322387695312e-08, 'y': 0.961893081...
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.564610362052917, 'y': -1.0978263986771...             48.799427
# 1  {'x': -3.576278686523437e-07, 'y': -1.0, 'z': ...            352.905640
# 2  {'x': 0.783807098865509, 'y': -5.1893408681280...            363.397705
# 3  {'x': -0.9506110548973081, 'y': -3.94478263388...            421.682709
# 4  {'x': 0.5260127186775201, 'y': -2.456306162912...            451.145996
#
#                                    PointedDirections avatarID AvatarPresence  \
# 0  [{'x': 0.544444680213928, 'y': -0.020759118720...       27           True
# 1  [{'x': -0.9652909636497491, 'y': 0.06559342145...       03           True
# 2  [{'x': 0.9454231858253471, 'y': 0.017136022448...       44           True
# 3  [{'x': 0.243516772985458, 'y': -0.001139298081...       02           True
# 4  [{'x': 0.9996959567070001, 'y': -0.01288132648...       24          False
#
#   AvatarPresenceCategory meaningful meaningfulBuilding
# 0                Omitted      False     Not meaningful
# 1                Omitted       True         meaningful
# 2                Omitted      False     Not meaningful
# 3                Omitted       True         meaningful
# 4                Present       True         meaningful
#
# [5 rows x 33 columns]

# %%
#Checking that value counts for Action and Standing avatars [Should be 50/50]
#df.BuildingCategory.value_counts()

# %% [markdown]
# ### Unesting variables

# %%
def unnest(dframe):

    """Unnest nested data that is needed from a JSON file by inserting each coordinates
    as a seperate column of the DataFrame.
    This Function is specific for the variable
Parameters
-------------
     dframe: your data frame
returns
----------
    DataFrame

    """

    TargetBuildingDirection = pd.DataFrame.from_records(dframe['TargetBuildingForward'])
    dframe.insert(25, "TargetBuildingDirection_z",TargetBuildingDirection['z'], True)
    dframe.insert(25, "TargetBuildingDirection_y",TargetBuildingDirection['y'], True)
    dframe.insert(25, "TargetBuildingDirection_x",TargetBuildingDirection['x'], True)

    TargetBuildingRotation = pd.DataFrame.from_records(dframe['TargetBuildingRotation'])
    dframe.insert(24, "TargetBuildingRotation_z",TargetBuildingRotation['z'], True)
    dframe.insert(24, "TargetBuildingRotation_y",TargetBuildingRotation['y'], True)
    dframe.insert(24, "TargetBuildingRotation_x",TargetBuildingRotation['x'], True)

    TargetBuildingPosition = pd.DataFrame.from_records(dframe['TargetBuildingPosition'])
    dframe.insert(23, "TargetBuildingPosition_z",TargetBuildingPosition['z'], True)
    dframe.insert(23, "TargetBuildingPosition_y",TargetBuildingPosition['y'], True)
    dframe.insert(23, "TargetBuildingPosition_x",TargetBuildingPosition['x'], True)

    PointerDirection = pd.DataFrame.from_records(dframe['PointerDirection'])
    dframe.insert(21, "PointerDirection_z",PointerDirection['z'], True)
    dframe.insert(21, "PointerDirection_y",PointerDirection['y'], True)
    dframe.insert(21, "PointerDirection_x",PointerDirection['x'], True)

    PointerRotation = pd.DataFrame.from_records(dframe['PointerRotation'])
    dframe.insert(19, "PointerRotation_z", PointerRotation['z'], True)
    dframe.insert(19, "PointerRotation_y", PointerRotation['y'], True)
    dframe.insert(19, "PointerRotation_x", PointerRotation['x'], True)

    PointerPosition = pd.DataFrame.from_records(dframe['PointerPosition'])
    dframe.insert(18, "PointerPosition_z", PointerPosition['z'], True)
    dframe.insert(18, "PointerPosition_y", PointerPosition['y'], True)
    dframe.insert(18, "PointerPosition_x", PointerPosition['x'], True)

    ParticipantRotation = pd.DataFrame.from_records(dframe['ParticipantRotation'])
    dframe.insert(17, "ParticipantRotation_z",ParticipantRotation['z'], True)
    dframe.insert(17, "ParticipantRotation_y", ParticipantRotation['y'], True)
    dframe.insert(17, "ParticipantRotation_x", ParticipantRotation['x'], True)

    ParticipantPosition = pd.DataFrame.from_records(dframe['ParticipantPosition'])
    dframe.insert(16, "ParticipantPosition_z", ParticipantPosition['z'], True)
    dframe.insert(16, "ParticipantPosition_y", ParticipantPosition['y'], True)
    dframe.insert(16, "ParticipantPosition_x", ParticipantPosition['x'], True)

    return dframe

# %%
df = unnest(df)
df.head()
# Out:
#    SubjectID  TrialNumber  ImageIndexNumber       ImageName  TimeOut  \
# 0       1843            1                95   27_SaNoAct_37    False
# 1       1843            2                55  03_CmANoAct_16    False
# 2       1843            3                71      44_SaNo_18    False
# 3       1843            4                47  02_CmANoAct_13    False
# 4       1843            5                26    24_CmAAct_11    False
#
#                  TimeStampBegin                  TimeStampEnd         RT  \
# 0 2023-03-30 11:41:55.468401408 2023-03-30 11:42:07.024395520  11.555994
# 1 2023-03-30 11:42:07.289725952 2023-03-30 11:42:21.834798848  14.545073
# 2 2023-03-30 11:42:22.102088704 2023-03-30 11:42:37.953455872  15.851367
# 3 2023-03-30 11:42:38.229200384 2023-03-30 11:42:48.501195520  10.271995
# 4 2023-03-30 11:42:48.768013056 2023-03-30 11:42:54.527908864   5.759896
#
#         Angle  TriggerPressedFreq  ...  TargetBuildingDirection_y  \
# 0    6.212492                   2  ...              -1.097826e-07
# 1  176.476852                   2  ...              -1.000000e+00
# 2   33.175674                   2  ...              -5.189341e-08
# 3   44.411446                   2  ...              -3.944783e-07
# 4   26.657282                   2  ...              -2.456306e-07
#
#    TargetBuildingDirection_z  \
# 0               8.253576e-01
# 1              -2.980232e-07
# 2               6.210043e-01
# 3              -3.103848e-01
# 4              -8.504766e-01
#
#                                TargetBuildingForward DistanceToParticipant  \
# 0  {'x': 0.564610362052917, 'y': -1.0978263986771...             48.799427
# 1  {'x': -3.576278686523437e-07, 'y': -1.0, 'z': ...            352.905640
# 2  {'x': 0.783807098865509, 'y': -5.1893408681280...            363.397705
# 3  {'x': -0.9506110548973081, 'y': -3.94478263388...            421.682709
# 4  {'x': 0.5260127186775201, 'y': -2.456306162912...            451.145996
#
#                                    PointedDirections avatarID  AvatarPresence  \
# 0  [{'x': 0.544444680213928, 'y': -0.020759118720...       27            True
# 1  [{'x': -0.9652909636497491, 'y': 0.06559342145...       03            True
# 2  [{'x': 0.9454231858253471, 'y': 0.017136022448...       44            True
# 3  [{'x': 0.243516772985458, 'y': -0.001139298081...       02            True
# 4  [{'x': 0.9996959567070001, 'y': -0.01288132648...       24           False
#
#    AvatarPresenceCategory  meaningful meaningfulBuilding
# 0                 Omitted       False     Not meaningful
# 1                 Omitted        True         meaningful
# 2                 Omitted       False     Not meaningful
# 3                 Omitted        True         meaningful
# 4                 Present        True         meaningful
#
# [5 rows x 57 columns]

# %%
os.chdir('/Volumes/TwoTeras/1_Experiment_2/Pointing_Task/Results')
os.getcwd()
# Out:
# '/Volumes/TwoTeras/1_Experiment_2/Pointing_Task/Results'

# %%
df.to_csv('BuildingPointingTask.csv')

# %%
df.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle', 'TriggerPressedFreq',
#        'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
#        'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
#        'PhotoReleasedTimeStamps', 'ParticipantPosition_x',
#        'ParticipantPosition_y', 'ParticipantPosition_z', 'ParticipantPosition',
#        'ParticipantRotation_x', 'ParticipantRotation_y',
#        'ParticipantRotation_z', 'ParticipantRotation', 'PointerPosition_x',
#        'PointerPosition_y', 'PointerPosition_z', 'PointerPosition',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding'],
#       dtype='object')

# %%
df.TrialNumber.describe()
# Out:
# count    6944.000000
# mean      112.500000
# std        64.667242
# min         1.000000
# 25%        56.750000
# 50%       112.500000
# 75%       168.250000
# max       224.000000
# Name: TrialNumber, dtype: float64

# %%
#PointingTask = pd.read_csv('/Users/tracysanchezpacheco/Documents/PointingTask.csv')
PointingTask = pd.read_csv('BuildingPointingTask.csv')

# %%
### Merging the two data frames (Data + Ids)

# %%
AnglesMerged = df.merge(FinalIds, how='right',
                                      left_on=['SubjectID', 'TrialNumber'],
                                      right_on=['SubjectID', 'TrialID'])
FinalIds.head()
# Out:
#    ParticipantID  StartPointID  SubjectID PointingTaskStartingLocations  \
# 0           1031             1       1031                            21
# 1           1031             1       1031                            21
# 2           1031             1       1031                            21
# 3           1031             1       1031                            21
# 4           1031             1       1031                            21
#
#   Trials  TrialID  ID_for_StartingPosition
# 0     11        1                        1
# 1    106        2                        2
# 2     70        3                        3
# 3     62        4                        4
# 4     19        5                        5

# %%
AnglesMerged.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle', 'TriggerPressedFreq',
#        'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
#        'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
#        'PhotoReleasedTimeStamps', 'ParticipantPosition_x',
#        'ParticipantPosition_y', 'ParticipantPosition_z', 'ParticipantPosition',
#        'ParticipantRotation_x', 'ParticipantRotation_y',
#        'ParticipantRotation_z', 'ParticipantRotation', 'PointerPosition_x',
#        'PointerPosition_y', 'PointerPosition_z', 'PointerPosition',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding', 'ParticipantID', 'StartPointID',
#        'PointingTaskStartingLocations', 'Trials', 'TrialID',
#        'ID_for_StartingPosition'],
#       dtype='object')

# %%
AnglesMerged[['TrialNumber', 'StartPointID']].head(300)
# Out:
#      TrialNumber  StartPointID
# 0              1             1
# 1              2             1
# 2              3             1
# 3              4             1
# 4              5             1
# ..           ...           ...
# 295           72             9
# 296           73            10
# 297           74            10
# 298           75            10
# 299           76            10
#
# [300 rows x 2 columns]

# %%
# Dropping unnecessary columns
AnglesMerged = AnglesMerged.drop(['TriggerPressedFreq',
                   'CancelPressedFreq', 'PhotoToCenterFreq', 'TriggerPressedTimeStamps',
                   'CancelPressedTimeStamps', 'PhotoToCenterTimeStamps',
                   'PhotoReleasedTimeStamps','ParticipantPosition', 'PointerPosition'], axis=1)

# %%
# Creating trial time duration
AnglesMerged['TimeStampEnd'] = pd.to_datetime(AnglesMerged['TimeStampEnd'])
AnglesMerged['TimeStampBegin'] = pd.to_datetime(AnglesMerged['TimeStampBegin'])
AnglesMerged['TimeDelta'] = AnglesMerged['TimeStampEnd'] - AnglesMerged['TimeStampBegin']

# %% [markdown]
# Checking if the columns `Trials` and `ImageIndexNumber` coincide, in theory both of them hold the buildings reference number

# %%
c = AnglesMerged
c['Equals'] = np.where((c['Trials'] == c['ImageIndexNumber']), 1, 0)
c['Equals2'] = np.where((c['TrialNumber'] == c['TrialID']), 1, 0)

# %%
d = c[c['Equals'] == 0 ]
d.SubjectID.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: SubjectID, dtype: float64

# %%
AnglesMerged.columns
# Out:
# Index(['SubjectID', 'TrialNumber', 'ImageIndexNumber', 'ImageName', 'TimeOut',
#        'TimeStampBegin', 'TimeStampEnd', 'RT', 'Angle',
#        'ParticipantPosition_x', 'ParticipantPosition_y',
#        'ParticipantPosition_z', 'ParticipantRotation_x',
#        'ParticipantRotation_y', 'ParticipantRotation_z', 'ParticipantRotation',
#        'PointerPosition_x', 'PointerPosition_y', 'PointerPosition_z',
#        'PointerRotation_x', 'PointerRotation_y', 'PointerRotation_z',
#        'PointerRotation', 'PointerRotationQuaternion', 'PointerDirection_x',
#        'PointerDirection_y', 'PointerDirection_z', 'PointerDirection',
#        'TargetBuildingName', 'TargetBuildingPosition_x',
#        'TargetBuildingPosition_y', 'TargetBuildingPosition_z',
#        'TargetBuildingPosition', 'TargetBuildingRotation_x',
#        'TargetBuildingRotation_y', 'TargetBuildingRotation_z',
#        'TargetBuildingRotation', 'TargetBuildingDirection_x',
#        'TargetBuildingDirection_y', 'TargetBuildingDirection_z',
#        'TargetBuildingForward', 'DistanceToParticipant', 'PointedDirections',
#        'avatarID', 'AvatarPresence', 'AvatarPresenceCategory', 'meaningful',
#        'meaningfulBuilding', 'ParticipantID', 'StartPointID',
#        'PointingTaskStartingLocations', 'Trials', 'TrialID',
#        'ID_for_StartingPosition', 'TimeDelta', 'Equals', 'Equals2'],
#       dtype='object')

# %%
final = AnglesMerged[['SubjectID', 'ParticipantPosition_x', 'ParticipantPosition_z', 'PointerPosition_x','PointerPosition_z', 'PointerDirection_x', 'PointerDirection_z', 'PointerDirection_y',  'TargetBuildingPosition_x', 'TargetBuildingPosition_z','DistanceToParticipant','avatarID','AvatarPresence', 'AvatarPresenceCategory', 'meaningful','meaningfulBuilding','StartPointID','PointingTaskStartingLocations', 'Trials', 'TrialNumber', 'StartPointID' ,'ID_for_StartingPosition','ImageIndexNumber','ImageName','TimeDelta','RT', 'TimeOut', 'TimeStampBegin', 'TimeStampEnd','Angle' ]]
#final = AnglesMerged[['SubjectID', 'ParticipantPosition_x', 'ParticipantPosition_z', 'PointerPosition_x','PointerPosition_z', 'PointerDirection_x', 'PointerDirection_z', 'PointerDirection_y',  'TargetBuildingPosition_x', 'TargetBuildingPosition_z','DistanceToParticipant','avatarID','AvatarPresence', 'AvatarPresenceCategory', 'meaningful','BuildingCategory','StartPointID','PointingTaskStartingLocations', 'Trials', 'TrialNumber', 'StartPointID' ,'ID_for_StartingPosition','ImageIndexNumber','ImageName','TimeDelta','RT', 'TimeOut', 'TimeStampBegin', 'TimeStampEnd','Angle' ]]
final.head()
# Out:
#    SubjectID  ParticipantPosition_x  ParticipantPosition_z  PointerPosition_x  \
# 0       1031            -114.399338            -139.684418        -114.045883
# 1       1031            -114.331833            -139.548859        -114.119827
# 2       1031            -114.299484            -139.607758        -113.805893
# 3       1031            -114.337112            -139.590088        -114.753433
# 4       1031            -114.365067            -139.634033        -113.916641
#
#    PointerPosition_z  PointerDirection_x  PointerDirection_z  \
# 0        -139.305084            0.383350            0.922763
# 1        -139.836395            0.998390           -0.049025
# 2        -139.339294            0.851683            0.524017
# 3        -139.490936           -0.930045           -0.366954
# 4        -139.287994            0.523005            0.852030
#
#    PointerDirection_y  TargetBuildingPosition_x  TargetBuildingPosition_z  \
# 0            0.039385                184.293533                -67.024742
# 1            0.028542               -334.536285                 -4.953291
# 2            0.006571                157.620819                127.239502
# 3            0.018994               -192.461411               -173.510040
# 4            0.022600               -311.341309                -93.570641
#
#    ...  StartPointID ID_for_StartingPosition  ImageIndexNumber    ImageName  \
# 0  ...             1                       1                11  33_CmANo_20
# 1  ...             1                       2               106     43_Sa_55
# 2  ...             1                       3                70     44_Sa_18
# 3  ...             1                       4                62     55_Sa_07
# 4  ...             1                       5                19  37_CmANo_08
#
#                   TimeDelta         RT  TimeOut                TimeStampBegin  \
# 0 0 days 00:00:25.217632256  25.217632    False 2022-11-22 13:16:19.698233088
# 1 0 days 00:00:24.303504640  24.303504    False 2022-11-22 13:16:45.193128960
# 2 0 days 00:00:13.345377280  13.345377    False 2022-11-22 13:17:09.767945472
# 3 0 days 00:00:17.190865408  17.190866    False 2022-11-22 13:17:23.388105728
# 4 0 days 00:00:24.513808128  24.513808    False 2022-11-22 13:17:40.845818112
#
#                    TimeStampEnd       Angle
# 0 2022-11-22 13:16:44.915865344   53.821247
# 1 2022-11-22 13:17:09.496633600  151.346756
# 2 2022-11-22 13:17:23.113322752   12.880881
# 3 2022-11-22 13:17:40.578971136    2.110998
# 4 2022-11-22 13:18:05.359626240  108.504898
#
# [5 rows x 30 columns]

# %%
final[['avatarID', 'ImageName']]
# Out:
#      avatarID    ImageName
# 0          33  33_CmANo_20
# 1          43     43_Sa_55
# 2          44     44_Sa_18
# 3          55     55_Sa_07
# 4          37  37_CmANo_08
# ...       ...          ...
# 6491       27  27_SaAct_37
# 6492       51     51_Sa_17
# 6493       49     49_Sa_19
# 6494       56     56_Sa_06
# 6495       06  06_SaAct_04
#
# [6496 rows x 2 columns]

# %%
#PointingTask = final.to_csv('/Users/tracysanchezpacheco/Documents/PointingTask.csv')
PointingTask = final.to_csv('BuildingPointingTask_exp2.csv')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496 entries, 0 to 6495
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SubjectID                      6496 non-null   int64
#  1   ParticipantPosition_x          6496 non-null   float64
#  2   ParticipantPosition_z          6496 non-null   float64
#  3   PointerPosition_x              6496 non-null   float64
#  4   PointerPosition_z              6496 non-null   float64
#  5   PointerDirection_x             6496 non-null   float64
#  6   PointerDirection_z             6496 non-null   float64
#  7   PointerDirection_y             6496 non-null   float64
#  8   TargetBuildingPosition_x       6496 non-null   float64
#  9   TargetBuildingPosition_z       6496 non-null   float64
#  10  DistanceToParticipant          6496 non-null   float64
#  11  avatarID                       6496 non-null   object
#  12  AvatarPresence                 6496 non-null   bool
#  13  AvatarPresenceCategory         6496 non-null   object
#  14  meaningful                     6496 non-null   bool
#  15  meaningfulBuilding             6496 non-null   object
#  16  StartPointID                   6496 non-null   int64
#  17  PointingTaskStartingLocations  6496 non-null   object
#  18  Trials                         6496 non-null   object
#  19  TrialNumber                    6496 non-null   int64
#  20  StartPointID                   6496 non-null   int64
#  21  ID_for_StartingPosition        6496 non-null   int64
#  22  ImageIndexNumber               6496 non-null   int64
#  23  ImageName                      6496 non-null   object
#  24  TimeDelta                      6496 non-null   timedelta64[ns]
#  25  RT                             6496 non-null   float64
#  26  TimeOut                        6496 non-null   bool
#  27  TimeStampBegin                 6496 non-null   datetime64[ns]
#  28  TimeStampEnd                   6496 non-null   datetime64[ns]
#  29  Angle                          6496 non-null   float64
# dtypes: bool(3), datetime64[ns](2), float64(12), int64(6), object(6), timedelta64[ns](1)
# memory usage: 1.4+ MB
