# %%
import pandas as pd
pointing_sum= pd.read_csv('E:/HumanA/Data/Data_Tracy/AgentTask/AgentPointingSummary.csv')
#pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
pointing_sum.head()
# Out:
#    Unnamed: 0    ID  AbsolutError  SignedAngle-+180        IQR         RT  \
# 0           0  1031     73.239902         73.239902  44.370344   9.057461
# 1           1  1031     18.559074        -18.559074  44.370344  28.543825
# 2           2  1031     76.164533        -76.164533  44.370344   5.412356
# 3           3  1031     32.789460        -32.789460  44.370344   8.281719
# 4           4  1031     12.043860         12.043860  44.370344   3.833091
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0             172.425797                             15            1
# 1             378.171112                             23           67
# 2              61.858631                             21          110
# 3             133.832611                              4          127
# 4             321.284546                             15            2
#
#    StartPointID  ID_for_StartingPosition  avatarID AvatarPresenceCategory  \
# ...

# %%
#import pandas as pd
pointing_sum= pd.read_csv('E:/HumanA/Data/Data_Tracy/BuildingTask/BuildingPointingSummary.csv')
#pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
pointing_sum.head()
# Out:
#    Unnamed: 0    ID  AbsolutError  SignedAngle-+180        IQR         RT  \
# 0           0  1031     53.795348         53.795348  37.943541  25.217632
# 1           1  1031     49.112601         49.112601  37.943541  26.154576
# 2           2  1031     30.743297         30.743297  37.943541   5.969860
# 3           3  1031    151.423249       -151.423249  37.943541  24.303504
# 4           4  1031     26.825266         26.825266  37.943541  27.219497
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0             307.299805                             21            1
# 1             189.228897                             13           27
# 2             381.328827                              4          144
# 3             258.106903                             21            2
# 4              83.646942                             25           45
#
#    StartPointID  ID_for_StartingPosition  avatarID AvatarPresenceCategory  \
# ...

# %%
pointing_sum.sort_values(by="AbsolutError")
# Out:
#       Unnamed: 0    ID  AbsolutError  SignedAngle-+180        IQR         RT  \
# 1873        1873  6406      0.006760         -0.006760  59.214930  10.071329
# 135          135  1031      0.026454         -0.026454  37.943541  16.490029
# 2391        2391  7935      0.029189         -0.029189  67.408948  15.195432
# 443          443  4580      0.064744         -0.064744  48.989986  16.836693
# 1823        1823  6406      0.073464         -0.073464  59.214930   2.408092
# ...          ...   ...           ...               ...        ...        ...
# 1881        1881  6406    179.545868        179.545868  59.214930  14.093413
# 719          719  4847    179.731526       -179.731526  59.044518  11.748762
# 2211        2211  7081    179.801385        179.801385  76.951264   1.765757
# 3000        3000  9627    179.897109       -179.897109  84.440034  16.624990
# 1058        1058  5189    179.971653       -179.971653  40.310596  14.543196
#
# ...

# %%
pointing_sum.groupby()

# %%
pointing_iqr= pd.read_csv('E:/HumanA/Data/Data_Tracy/BuildingTask/BuildingPointingTask_IQR_Final.csv')
#pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
pointing_iqr.head()
# Out:
#    Unnamed: 0  SubjectID        IQR   IQRlimit   IQRlimit2  Unnamed: 0.1  \
# 0           0       1031  37.943541  56.915311  113.830622             0
# 1           1       1031  37.943541  56.915311  113.830622             2
# 2           2       1031  37.943541  56.915311  113.830622             4
# 3           3       1031  37.943541  56.915311  113.830622           120
# 4           4       1031  37.943541  56.915311  113.830622           122
#
#    ParticipantPosition_x  ParticipantPosition_z  PointerPosition_x  \
# 0            -114.399338            -139.684418        -114.045883
# 1              38.724716              53.831726          39.091354
# 2            -185.645920            -159.544128        -185.358322
# 3            -114.331833            -139.548859        -114.119827
# 4            -321.040771              77.530136        -321.208557
#
#    PointerPosition_z  ...   radians    degrees  atanPointer  atanBuild-Part  \
# ...

# %%
pointing_iqr.groupby("SubjectID").mean()
# Out:
#            Unnamed: 0        IQR    IQRlimit   IQRlimit2  Unnamed: 0.1  \
# SubjectID
# 1031            111.5  37.943541   56.915311  113.830622   2854.625000
# 2069           3247.5  68.997178  103.495767  206.991535   3671.776786
# 4580            335.5  48.989986   73.484979  146.969958   3596.357143
# 4598            559.5  40.977081   61.465622  122.931244   3293.794643
# 4847            783.5  59.044518   88.566776  177.133553   3362.964286
# 5189           1007.5  40.310596   60.465894  120.931788   3267.544643
# 5743           1231.5  36.920567   55.380850  110.761700   3078.375000
# 5766           1455.5  27.146517   40.719776   81.439552   3451.392857
# 5972           1679.5  43.756151   65.634227  131.268453   3352.330357
# 6406           1903.5  59.214930   88.822395  177.644791   3328.491071
# 7081           2127.5  76.951264  115.426897  230.853793   3529.776786
# 7935           2351.5  67.408948  101.113421  202.226843   3277.830357
# ...

# %%
pointing__agent_iqr= pd.read_csv('E:/HumanA/Data/Data_Tracy/AgentTask/AgentPointingTask_IQR_Final.csv')
#pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
pointing__agent_iqr.groupby("SubjectID").mean()
# Out:
#    Unnamed: 0  SubjectID        IQR   IQRlimit   IQRlimit2  Unnamed: 0.1  \
# 0           0       1031  44.370344  66.555516  133.111031             0
# 1           1       1031  44.370344  66.555516  133.111031             1
# 2           2       1031  44.370344  66.555516  133.111031             2
# 3           3       1031  44.370344  66.555516  133.111031             3
# 4           4       1031  44.370344  66.555516  133.111031            41
#
#    ParticipantPosition_x  ParticipantPosition_z  PointerPosition_x  \
# 0             -61.486801              27.881790         -61.211075
# 1            -228.978378             189.947388        -228.935959
# 2            -114.120316            -139.545837        -114.626694
# 3            -185.544052            -159.559296        -185.290756
# 4             -61.538162              27.714478         -61.177170
#
#    PointerPosition_z  ...   radians    degrees  atanPointer  atanAgent-Part  \
# ...

# %%
pointing__agent_iqr.groupby("SubjectID").mean()
# Out:
#            Unnamed: 0        IQR    IQRlimit   IQRlimit2  Unnamed: 0.1  \
# SubjectID
# 1031             83.5  44.370344   66.555516  133.111031   1135.839286
# 2069            251.5  76.211173  114.316759  228.633518   1203.952381
# 4580            419.5  69.568971  104.353457  208.706914   1278.244048
# 4598            587.5  55.165528   82.748292  165.496584   1177.244048
# 4847            755.5  63.192045   94.788068  189.576136   1253.714286
# 5189            923.5  56.165709   84.248563  168.497126   1173.970238
# 5743           1091.5  42.764168   64.146252  128.292505   1323.345238
# 5766           1259.5  62.246054   93.369082  186.738163   1290.273810
# 5972           1427.5  67.188503  100.782755  201.565510   1228.434524
# 6406           1595.5  80.780508  121.170762  242.341524   1326.202381
# 7081           1763.5  79.913070  119.869605  239.739211   1240.648810
# 7935           1931.5  76.065399  114.098099  228.196198   1361.994048
# ...
