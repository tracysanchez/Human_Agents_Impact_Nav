# %% [markdown]
# # Joining final data sets

# %%
import os
import pandas as pd
from functools import reduce

# %%
# Loading the final datasets data come as a result of the jupiter notebooks contained in  
FRSquest = pd.read_csv('E:\HumanA\Data\Data_Tracy\Questionnaires\Adjusted\FRSsubs.csv')
FRSquest.drop('Unnamed: 0', axis=1, inplace=True)
FRSquest.head()
# Out:
#      ID  Alter   Global  Overview  Cardinal
# 0  8629      23     4.3  5.714286       2.0
# 1  9627      31     3.3  4.000000       1.0
# 2  4598      21     5.1  4.857143       2.5
# 3  1031      20     5.6  5.000000       1.0
# 4  4847      19     5.3  2.285714       2.0

# %%
affiliative = pd.read_csv('E:\HumanA\Data\Data_Tracy\Questionnaires\Adjusted/AffilliativeTend.csv')
affiliative = affiliative[['ID', 'AffiliativeQ_average']]
affiliative.head(18)
# Out:
#       ID  AffiliativeQ_average
# 0   9627                   2.8
# 1   4598                   3.8
# 2   1031                   3.4
# 3   8629                   5.8
# 4   4847                   3.6
# 5   5766                   2.8
# 6   9297                   4.0
# 7   7081                   3.8
# 8   5189                   5.0
# 9   5743                   5.6
# 10  6406                   4.2
# 11  5972                   4.8
# 12  7935                   1.8
# 13  2069                   3.8
# 14  4508                   4.8
# 15  7393                   1.4
# 16  5161                   3.0
# 17  5851                   3.6

# %%
context = pd.read_csv('E:\HumanA\Data\Data_Tracy\Questionnaires\Adjusted/ContextQuest.csv')
context = context[['ID', 'item3','ContextQ_average']]
context.head()
# Out:
#      ID  item3  ContextQ_average
# 0  9627      2               5.0
# 1  4598      4               5.5
# 2  1031      2               6.5
# 3  8629      2               4.5
# 4  4847      5               4.5

# %%
avatar_sum = pd.read_csv('E:\HumanA\Data\Data_Tracy\Questionnaires\Adjusted\AgentQuest.csv')
avatar_sum.head(21)
# Out:
#       ID  remember_action_likert  remember_standing_likert  \
# 0   1031                3.892857                  2.750000
# 1   1843                3.892857                  1.892857
# 2   2069                4.035714                  1.678571
# 3   3540                2.607143                  2.035714
# 4   4580                2.714286                  1.571429
# 5   4598                3.642857                  2.642857
# 6   4847                2.571429                  1.678571
# 7   5161                3.000000                  1.607143
# 8   5189                3.714286                  2.392857
# 9   5743                3.678571                  2.250000
# 10  5766                3.571429                  2.607143
# 11  5851                2.535714                  1.357143
# 12  5972                3.392857                  1.785714
# 13  6406                2.392857                  1.178571
# 14  7081                3.392857                  1.714286
# 15  7393                3.571429                  1.464286
# 16  7935                4.214286                  1.928571
# 17  8629                3.714286                  2.392857
# 18  9297                4.071429                  2.750000
# 19  9627                2.357143                  1.142857
#
#     attractive_action_likert  attractive_standing_likert  \
# 0                   3.321429                    2.678571
# 1                   2.642857                    1.964286
# 2                   2.285714                    1.892857
# 3                   2.071429                    1.785714
# 4                   1.607143                    1.357143
# 5                   2.464286                    2.357143
# 6                   2.285714                    1.571429
# 7                   1.928571                    1.535714
# 8                   2.607143                    2.678571
# 9                   2.678571                    1.928571
# 10                  2.714286                    2.428571
# 11                  2.142857                    1.571429
# 12                  1.928571                    1.607143
# 13                  1.535714                    1.035714
# 14                  1.928571                    1.607143
# 15                  2.107143                    1.785714
# 16                  4.285714                    2.000000
# 17                  2.142857                    2.107143
# 18                  2.964286                    2.571429
# 19                  2.392857                    1.464286
#
#     realistic_action_likert  realistic_standing_likert
# 0                  4.428571                   4.107143
# 1                  4.071429                   3.000000
# 2                  3.785714                   3.000000
# 3                  3.178571                   3.142857
# 4                  2.714286                   1.964286
# 5                  4.000000                   4.000000
# 6                  3.857143                   3.107143
# 7                  3.642857                   2.428571
# 8                  3.428571                   3.750000
# 9                  3.321429                   3.107143
# 10                 3.178571                   2.464286
# 11                 3.785714                   3.357143
# 12                 2.035714                   2.107143
# 13                 3.071429                   2.928571
# 14                 2.535714                   3.250000
# 15                 3.000000                   2.500000
# 16                 4.428571                   1.857143
# 17                 3.892857                   3.250000
# 18                 3.571429                   3.142857
# 19                 4.857143                   4.392857

# %%
# TODO: add pointing summary for Building and Agent Task & rename RT to RT_building/ RT_agent, as well as AbsolutError
building_pointing_sum= pd.read_csv('E:\HumanA\Data\Data_Tracy\BuildingTask\BuildingPointingSummary.csv')
building_pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
building_pointing_sum.head()
# Out:
#      ID  AbsolutError  SignedAngle-+180        IQR         RT  \
# 0  1031     53.795348         53.795348  37.943541  25.217632
# 1  1031     49.112601         49.112601  37.943541  26.154576
# 2  1031     30.743297         30.743297  37.943541   5.969860
# 3  1031    151.423249       -151.423249  37.943541  24.303504
# 4  1031     26.825266         26.825266  37.943541  27.219497
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0             307.299805                             21            1
# 1             189.228897                             13           27
# 2             381.328827                              4          144
# 3             258.106903                             21            2
# 4              83.646942                             25           45
#
#    StartPointID  ID_for_StartingPosition  avatarID AvatarPresenceCategory  \
# 0             1                        1        33                Omitted
# 1             4                        3        33                Omitted
# 2            18                        8        33                Omitted
# 3             1                        2        43                Present
# 4             6                        5        43                Omitted
#
#    Context BuildingCategory    ImageName
# 0     True       meaningful  33_CmANo_20
# 1     True       meaningful  33_CmANo_20
# 2     True       meaningful  33_CmANo_20
# 3    False   Not meaningful     43_Sa_55
# 4    False   Not meaningful   43_SaNo_55

# %%
#building_pointing_sum=building_pointing_sum.set_index(['ID']).add_prefix('Building_').reset_index()

# %%
building_pointing_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4251 entries, 0 to 4250
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             4251 non-null   int64
#  1   AbsolutError                   4251 non-null   float64
#  2   SignedAngle-+180               4251 non-null   float64
#  3   IQR                            4251 non-null   float64
#  4   RT                             4251 non-null   float64
#  5   DistanceToParticipant          4251 non-null   float64
#  6   PointingTaskStartingLocations  4251 non-null   int64
#  7   TrialNumber                    4251 non-null   int64
#  8   StartPointID                   4251 non-null   int64
#  9   ID_for_StartingPosition        4251 non-null   int64
#  10  avatarID                       4251 non-null   int64
#  11  AvatarPresenceCategory         4251 non-null   object
#  12  Context                        4251 non-null   bool
#  13  BuildingCategory               4251 non-null   object
#  14  ImageName                      4251 non-null   object
# dtypes: bool(1), float64(5), int64(6), object(3)
# memory usage: 469.2+ KB

# %%
# TODO: add pointing summary for Building and Agent Task & rename RT to RT_building/ RT_agent, as well as AbsolutError
agent_pointing_sum= pd.read_csv('E:\HumanA\Data\Data_Tracy\AgentTask\AgentPointingSummary.csv')
agent_pointing_sum.drop('Unnamed: 0', axis=1, inplace=True)
agent_pointing_sum.head()
# Out:
#      ID  AbsolutError  SignedAngle-+180        IQR         RT  \
# 0  1031     73.239902         73.239902  44.370344   9.057461
# 1  1031     18.559074        -18.559074  44.370344  28.543825
# 2  1031     76.164533        -76.164533  44.370344   5.412356
# 3  1031     32.789460        -32.789460  44.370344   8.281719
# 4  1031     12.043860         12.043860  44.370344   3.833091
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0             172.425797                             15            1
# 1             378.171112                             23           67
# 2              61.858631                             21          110
# 3             133.832611                              4          127
# 4             321.284546                             15            2
#
#    StartPointID  ID_for_StartingPosition  avatarID AvatarPresenceCategory  \
# 0             1                        1        16                Present
# 1            12                        1        16                Present
# 2            19                        2        16                Present
# 3            22                        1        16                Present
# 4             1                        2        50                Present
#
#    Context meaningfulBuilding AgentCategory       ImageName
# 0    False     Not meaningful        Active  16_SaAct_92_36
# 1    False     Not meaningful        Active  16_SaAct_92_36
# 2    False     Not meaningful        Active  16_SaAct_92_36
# 3    False     Not meaningful        Active  16_SaAct_92_36
# 4    False     Not meaningful       Passive     50_Sa_66_15

# %%
#agent_pointing_sum=agent_pointing_sum.set_index(['ID']).add_prefix('Agent_').reset_index()

# %%
agent_pointing_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             3192 non-null   int64
#  1   AbsolutError                   3192 non-null   float64
#  2   SignedAngle-+180               3192 non-null   float64
#  3   IQR                            3192 non-null   float64
#  4   RT                             3192 non-null   float64
#  5   DistanceToParticipant          3192 non-null   float64
#  6   PointingTaskStartingLocations  3192 non-null   int64
#  7   TrialNumber                    3192 non-null   int64
#  8   StartPointID                   3192 non-null   int64
#  9   ID_for_StartingPosition        3192 non-null   int64
#  10  avatarID                       3192 non-null   int64
#  11  AvatarPresenceCategory         3192 non-null   object
#  12  Context                        3192 non-null   bool
#  13  meaningfulBuilding             3192 non-null   object
#  14  AgentCategory                  3192 non-null   object
#  15  ImageName                      3192 non-null   object
# dtypes: bool(1), float64(5), int64(6), object(4)
# memory usage: 377.3+ KB

# %%
#data_frames = [FRSquest, affiliative, context, avatar_sum, building_pointing_sum, agent_pointing_sum]
data_frames = [FRSquest, affiliative, context, avatar_sum, building_pointing_sum]
humanA_Behavioural_Building = reduce(lambda  left,right: pd.merge(left,right,on=['ID'],
                                                how='outer'), data_frames)

# %%
data_frames = [FRSquest, affiliative, context, avatar_sum, agent_pointing_sum]
humanA_Behavioural_Agent = reduce(lambda  left,right: pd.merge(left,right,on=['ID'],
                                                how='outer'), data_frames)

# %%
humanA_Behavioural_Building.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4259 entries, 0 to 4258
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             4259 non-null   int64
#  1   Alter                          4258 non-null   float64
#  2   Global                         4258 non-null   float64
#  3   Overview                       4258 non-null   float64
#  4   Cardinal                       4258 non-null   float64
#  5   AffiliativeQ_average           3808 non-null   float64
#  6   item3                          3808 non-null   float64
#  7   ContextQ_average               3808 non-null   float64
#  8   remember_action_likert         4029 non-null   float64
#  9   remember_standing_likert       4029 non-null   float64
#  10  attractive_action_likert       4029 non-null   float64
#  11  attractive_standing_likert     4029 non-null   float64
#  12  realistic_action_likert        4029 non-null   float64
#  13  realistic_standing_likert      4029 non-null   float64
#  14  AbsolutError                   4251 non-null   float64
#  15  SignedAngle-+180               4251 non-null   float64
#  16  IQR                            4251 non-null   float64
#  17  RT                             4251 non-null   float64
#  18  DistanceToParticipant          4251 non-null   float64
#  19  PointingTaskStartingLocations  4251 non-null   float64
#  20  TrialNumber                    4251 non-null   float64
#  21  StartPointID                   4251 non-null   float64
#  22  ID_for_StartingPosition        4251 non-null   float64
#  23  avatarID                       4251 non-null   float64
#  24  AvatarPresenceCategory         4251 non-null   object
#  25  Context                        4251 non-null   object
#  26  BuildingCategory               4251 non-null   object
#  27  ImageName                      4251 non-null   object
# dtypes: float64(23), int64(1), object(4)
# memory usage: 964.9+ KB

# %%
humanA_Behavioural_Agent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3200 entries, 0 to 3199
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             3200 non-null   int64
#  1   Alter                          3199 non-null   float64
#  2   Global                         3199 non-null   float64
#  3   Overview                       3199 non-null   float64
#  4   Cardinal                       3199 non-null   float64
#  5   AffiliativeQ_average           2861 non-null   float64
#  6   item3                          2861 non-null   float64
#  7   ContextQ_average               2861 non-null   float64
#  8   remember_action_likert         3026 non-null   float64
#  9   remember_standing_likert       3026 non-null   float64
#  10  attractive_action_likert       3026 non-null   float64
#  11  attractive_standing_likert     3026 non-null   float64
#  12  realistic_action_likert        3026 non-null   float64
#  13  realistic_standing_likert      3026 non-null   float64
#  14  AbsolutError                   3192 non-null   float64
#  15  SignedAngle-+180               3192 non-null   float64
#  16  IQR                            3192 non-null   float64
#  17  RT                             3192 non-null   float64
#  18  DistanceToParticipant          3192 non-null   float64
#  19  PointingTaskStartingLocations  3192 non-null   float64
#  20  TrialNumber                    3192 non-null   float64
#  21  StartPointID                   3192 non-null   float64
#  22  ID_for_StartingPosition        3192 non-null   float64
#  23  avatarID                       3192 non-null   float64
#  24  AvatarPresenceCategory         3192 non-null   object
#  25  Context                        3192 non-null   object
#  26  meaningfulBuilding             3192 non-null   object
#  27  AgentCategory                  3192 non-null   object
#  28  ImageName                      3192 non-null   object
# dtypes: float64(23), int64(1), object(5)
# memory usage: 750.0+ KB

# %%
humanA_Behavioural_Building.to_csv('E:\HumanA\Data\Data_Tracy\Resulting_CSVs\humanA_Behavioural_Building_withoutSuf.csv')
humanA_Behavioural_Agent.to_csv('E:\HumanA\Data\Data_Tracy\Resulting_CSVs\humanA_Behavioural_Agent_withoutSuf.csv')

# %%
#humanA_Behavioural_Building[['Building_ImageName', 'Building_avatarID']]
