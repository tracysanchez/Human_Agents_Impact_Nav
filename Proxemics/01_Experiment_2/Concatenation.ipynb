# %%
import os
import pandas as pd
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/Volumes/TwoTeras/1_Experiment_2/Proxemics/Minimal_Distance_Faces/" 

# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    One_participant = pd.read_csv(filename)
    print(filename[-10:-4])
    content.append(One_participant)

# converting content to data frame
data_frame = pd.concat(content)
# Out:
# 4580_2
# 4580_3
# 4580_4
# 4580_5
# 4598_1
# 4598_2
# 4598_3
# 4598_4
# 1031_1
# 1031_2
# 1031_3
# 1031_4
# 1031_5
# 1268_1
# 1268_2
# 1268_3
# 1268_4
# 1268_5
# 1574_1
# 1574_2
# 1574_3
# 1574_4
# 1574_5
# 1843_1
# 1843_2
# 1843_3
# 1843_4
# 1843_5
# 2069_1
# 2069_2
# 2069_3
# 2069_4
# 2069_5
# 3193_1
# 3193_2
# 3193_3
# 3193_4
# 3193_5
# 3540_1
# 3540_3
# 3540_4
# 3540_5
# 4580_1
# 4598_5
# 4847_1
# 4847_2
# 4847_3
# 4847_4
# 4847_5
# 4875_1
# 4875_2
# 4875_3
# 4875_4
# 4875_5
# 5161_1
# 5161_2
# 5161_3
# 5161_4
# 5161_5
# 5189_1
# 5189_2
# 5189_3
# 5189_4
# 5189_5
# 5743_1
# 5743_2
# 5743_3
# 5743_4
# 5743_5
# 5766_1
# 5766_2
# 5766_3
# 5766_4
# 5766_5
# 5851_1
# 5851_2
# 5851_3
# 5851_4
# 5851_5
# 5972_1
# 5972_2
# 5972_3
# 5972_4
# 5972_5
# 6406_1
# 6406_2
# 6406_3
# 6406_4
# 6406_5
# 7081_1
# 7081_2
# 7081_3
# 7081_4
# 7081_5
# 7393_1
# 7393_2
# 7393_3
# 7393_4
# 7393_5
# 7823_1
# 7823_2
# 7823_3
# 7823_4
# 7823_5
# 7935_1
# 7935_2
# 7935_3
# 7935_4
# 7935_5
# 8629_1
# 8629_2
# ...

# %%
data_frame.ped_id.unique()
# Out:
# array(['14_Cma', '28_Cma', '38_Sa', '48_Sa', '03_Cma', '11_Cma', '09_Cma',
#        '41_Sa', '45_Sa', '35_Sa', '36_Sa', '53_Sa', '17_Cma', '26_Cma',
#        '29_Sa', '23_Cma', '25_Cma', '01_Cma', '22_Cma', '19_Cma', '54_Sa',
#        '40_Sa', '33_Sa', '10_Cma', '46_Sa', '27_Cma', '06_Cma', '20_Cma',
#        '55_Sa', '42_Sa', '16_Cma', '07_Cma', '37_Sa', '21_Cma', '49_Sa',
#        '31_Sa', '34_Sa', '12_Cma', '43_Sa', '39_Sa', '51_Sa', '44_Sa',
#        '04_Cma', '13_Cma', '24_Cma', '56_Sa', '05_Cma', '32_Sa', '18_Cma',
#        '52_Sa', '47_Sa', '30_Sa', '50_Sa', '02_Cma', '08_Cma', '15_Cma'],
#       dtype=object)

# %%
# Create the 'Agent_Type' column based on the condition in ped_id
data_frame['Agent_Type'] = data_frame['ped_id'].apply(lambda x: 'Passive' if x.endswith('Sa') else 'Active' if x.endswith('Cma') else 'Unknown')

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1598 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1598 non-null   object
#  1   ped_id            1598 non-null   object
#  2   minimal_distance  1598 non-null   float64
#  3   num_interactions  1598 non-null   object
#  4   SubjectID         1598 non-null   object
#  5   Session           1598 non-null   object
#  6   Agent_Type        1598 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 99.9+ KB

# %%
data_frame.to_csv("/Volumes/TwoTeras/1_Experiment_2/Proxemics/Minimal_Distances_Experiment_Two_Faces.csv")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the datasets
Face = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Proxemics/Minimal_Distances_Experiment_One_Faces.csv")
Body = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Proxemics/Minimal_Distances_Experiment_One.csv")

# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Create the distribution plot for Faces dataset on the left
sns.kdeplot(data=Face, x='minimal_distance', hue='Agent_Type', fill=True, palette="Set2", ax=axes[0])
axes[0].set_title('Distribution of Minimal Distance (Faces)', size=16)
axes[0].set_xlabel('Minimal Distance', size=14)
axes[0].set_ylabel('Density', size=14)

# Create the distribution plot for Body dataset on the right
sns.kdeplot(data=Body, x='minimal_distance', hue='Agent_Type', fill=True, palette="Set2", ax=axes[1])
axes[1].set_title('Distribution of Minimal Distance (Body)', size=16)
axes[1].set_xlabel('Minimal Distance', size=14)
axes[1].set_ylabel('Density', size=14)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
affiliative = pd.read_csv('/Volumes/TwoTeras/0_Experiment_1/Questionnaires/Results/AffilliativeTend_exp1.csv')
affiliative_2 = pd.read_csv('/Volumes/TwoTeras/1_Experiment_2/Questionnaires/Results/AffilliativeTend_exp2.csv')
affiliative = affiliative[['ID', 'AffiliativeQ_average']]
affiliative_2 = affiliative_2[['ID', 'AffiliativeQ_average']]

# Stack them (i.e., concatenate)
stacked_affiliative = pd.concat([affiliative, affiliative_2], ignore_index=True)
stacked_affiliative.head(18)
# Out:
#       ID  AffiliativeQ_average
# 0   8469                   3.8
# 1   7264                   1.4
# 2   3572                   4.0
# 3    365                   5.2
# 4   6642                   4.2
# 5   5741                   2.8
# 6   7842                   3.4
# 7   4176                   3.4
# 8   9472                   4.6
# 9   4623                   2.2
# 10  9502                   2.4
# 11  7093                   3.6
# 12  2258                   5.0
# 13  1754                   2.4
# 14  5238                   5.0
# 15  8695                   4.8
# 16  3976                   2.4
# 17  5531                   5.6

# %%
# Load the datasets
Face = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Proxemics/Minimal_Distances_Experiment_One_Faces.csv")
Face_2 = pd.read_csv("/Volumes/TwoTeras/1_Experiment_2/Proxemics/Minimal_Distances_Experiment_Two_Faces.csv")
Face_Group = pd.DataFrame(Face.groupby(['SubjectID', 'Agent_Type'])['minimal_distance'].median())
Face_Group.reset_index(inplace=True)
Face_Group.head()
Face_Group_2 = pd.DataFrame(Face_2.groupby(['SubjectID', 'Agent_Type'])['minimal_distance'].median())
Face_Group_2.reset_index(inplace=True)
Face_Group_2.head()
stacked_Face_Group = pd.concat([Face_Group, Face_Group_2], ignore_index=True)
stacked_Face_Group.head(18)
# Out:
#     SubjectID Agent_Type  minimal_distance
# 0         365     Active          8.273467
# 1         365    Passive          6.427654
# 2         479     Active          2.483956
# 3         479    Passive          2.475976
# 4        1754     Active          4.292772
# 5        1754    Passive          3.398182
# 6        2258     Active          5.220973
# 7        2258    Passive          3.962601
# 8        2361     Active          4.085136
# 9        2361    Passive          4.240449
# 10       2693     Active          5.506279
# 11       2693    Passive          4.673700
# 12       3246     Active          7.916852
# 13       3246    Passive          5.166564
# 14       3310     Active          4.454782
# 15       3310    Passive          7.330309
# 16       3572     Active          3.419060
# 17       3572    Passive          4.735019

# %%
#import the merged data set
HumanA= pd.read_csv('/Users/tracysanchezpacheco/Documents/Resources/humanA_Behavioural.csv')
HumanA.dropna(axis=0, inplace=True)
HumanAf = HumanA[HumanA['ID'] != 4623]
HumanAf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9381 entries, 0 to 9717
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     9381 non-null   int64
#  1   ID                             9381 non-null   float64
#  2   Alter                          9381 non-null   float64
#  3   Global                         9381 non-null   float64
#  4   Overview                       9381 non-null   float64
#  5   Cardinal                       9381 non-null   float64
#  6   AffiliativeQ_average           9381 non-null   float64
#  7   item3                          9381 non-null   float64
#  8   ContextQ_average               9381 non-null   float64
#  9   remember_action_likert         9381 non-null   float64
#  10  remember_standing_likert       9381 non-null   float64
#  11  attractive_action_likert       9381 non-null   float64
# ...

# %%
HumanAf.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Alter ', 'Global', 'Overview', 'Cardinal',
#        'AffiliativeQ_average', 'item3', 'ContextQ_average',
#        'remember_action_likert', 'remember_standing_likert',
#        'attractive_action_likert', 'attractive_standing_likert',
#        'realistic_action_likert', 'realistic_standing_likert', 'AbsolutError',
#        'SignedAngle-+180', 'IQR', 'RT', 'DistanceToParticipant',
#        'PointingTaskStartingLocations', 'TrialNumber', 'StartPointID',
#        'ID_for_StartingPosition', 'avatarID', 'AvatarPresenceCategory',
#        'Context', 'meaningfulBuilding', 'ImageName'],
#       dtype='object')

# %%
Questionares = HumanAf[['ID','AffiliativeQ_average', 'remember_action_likert', 'remember_standing_likert',
       'attractive_action_likert', 'attractive_standing_likert',
       'realistic_action_likert', 'realistic_standing_likert']].copy()

# %%
Grouped_Quest = pd.DataFrame(Questionares.groupby('ID').max())
Grouped_Quest.reset_index(inplace=True)
merged = pd.merge(stacked_Face_Group, Grouped_Quest, left_on='SubjectID', right_on='ID')
merged.head()
# Out:
#    SubjectID Agent_Type  minimal_distance      ID  AffiliativeQ_average  \
# 0        365     Active          8.273467   365.0                   5.2
# 1        365    Passive          6.427654   365.0                   5.2
# 2        479     Active          2.483956   479.0                   6.8
# 3        479    Passive          2.475976   479.0                   6.8
# 4       1754     Active          4.292772  1754.0                   2.4
#
#    remember_action_likert  remember_standing_likert  attractive_action_likert  \
# 0                2.714286                  1.107143                  2.214286
# 1                2.714286                  1.107143                  2.214286
# 2                4.178571                  2.214286                  1.000000
# 3                4.178571                  2.214286                  1.000000
# 4                1.678571                  1.035714                  3.107143
#
#    attractive_standing_likert  realistic_action_likert  \
# ...

# %%
sns.lmplot(y='minimal_distance', x='AffiliativeQ_average', hue="Agent_Type", data=merged)

# %%
sns.lmplot(y='minimal_distance', x='remember_standing_likert', hue="Agent_Type", data=merged)

# %%
# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Create the box plot for Faces dataset on the left
sns.boxplot(data=Face, x='Agent_Type', y='minimal_distance', palette="Set2", ax=axes[0])
axes[0].set_title('Box Plot of Minimal Distance (Faces)', size=16)
axes[0].set_xlabel('Agent Type', size=14)
axes[0].set_ylabel('Minimal Distance', size=14)

# Create the box plot for Body dataset on the right
sns.boxplot(data=Body, x='Agent_Type', y='minimal_distance', palette="Set2", ax=axes[1])
axes[1].set_title('Box Plot of Minimal Distance (Body)', size=16)
axes[1].set_xlabel('Agent Type', size=14)
axes[1].set_ylabel('Minimal Distance', size=14)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Create the KDE plot for Faces dataset on the left
sns.kdeplot(data=Face, x='minimal_distance', hue='ped_id', fill=True, palette="Set2", ax=axes[0])
axes[0].set_title('Distribution of Minimal Distance (Faces)', size=16)
axes[0].set_xlabel('Minimal Distance', size=14)
axes[0].set_ylabel('Density', size=14)

# Create the KDE plot for Body dataset on the right
sns.kdeplot(data=Body, x='minimal_distance', hue='ped_id', fill=True, palette="Set2", ax=axes[1])
axes[1].set_title('Distribution of Minimal Distance (Body)', size=16)
axes[1].set_xlabel('Minimal Distance', size=14)
axes[1].set_ylabel('Density', size=14)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/3p/lxg47mnx0ks_st66vkzkx1640000gn/T/ipykernel_9583/118139173.py:17: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Calculate the mean minimal distance for each ped_id for both datasets
order_face = Face.groupby('ped_id')['minimal_distance'].mean().sort_values().index
order_body = Body.groupby('ped_id')['minimal_distance'].mean().sort_values().index

# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(25, 10))

# Create the box plot for the Faces dataset, ordered by mean minimal distance
sns.boxplot(data=Face, x='ped_id', y='minimal_distance', palette="Set2", order=order_face, ax=axes[0])
axes[0].set_title('Box Plot of Minimal Distance (Faces)', size=16)
axes[0].set_xlabel('Pedestrian ID', size=14)
axes[0].set_ylabel('Minimal Distance', size=14)
axes[0].tick_params(axis='x', rotation=90)

# Create the box plot for the Body dataset, ordered by mean minimal distance
sns.boxplot(data=Body, x='ped_id', y='minimal_distance', palette="Set2", order=order_body, ax=axes[1])
axes[1].set_title('Box Plot of Minimal Distance (Body)', size=16)
axes[1].set_xlabel('Pedestrian ID', size=14)
axes[1].set_ylabel('Minimal Distance', size=14)
axes[1].tick_params(axis='x', rotation=90)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
order_face = Face.groupby('ped_id')['minimal_distance'].mean().sort_values()
order_body = Body.groupby('ped_id')['minimal_distance'].mean().sort_values()
display(order_face.head())
display(order_body.head())
# Out:
# ped_id
# 03_Cma    1.768437
# 53_Sa     2.376250
# 52_Sa     2.429821
# 42_Sa     2.559886
# 43_Sa     3.636511
# Name: minimal_distance, dtype: float64
# ped_id
# 42_Sa     2.572446
# 03_Cma    3.267729
# 43_Sa     3.773681
# 21_Cma    4.141686
# 54_Sa     4.172509
# Name: minimal_distance, dtype: float64

# %%
# Calculate the mean minimal distance for each ped_id for both datasets
order_face = Face.groupby('SubjectID')['minimal_distance'].mean().sort_values().index
order_body = Body.groupby('SubjectID')['minimal_distance'].mean().sort_values().index

# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(20, 10))

# Create the box plot for the Faces dataset, ordered by mean minimal distance
sns.boxplot(data=Face, x='SubjectID', y='minimal_distance', palette="Set2", order=order_face, ax=axes[0])
axes[0].set_title('Box Plot of Minimal Distance (Faces)', size=16)
axes[0].set_xlabel('Pedestrian ID', size=14)
axes[0].set_ylabel('Minimal Distance', size=14)
axes[0].tick_params(axis='x', rotation=45)

# Create the box plot for the Body dataset, ordered by mean minimal distance
sns.boxplot(data=Body, x='SubjectID', y='minimal_distance', palette="Set2", order=order_body, ax=axes[1])
axes[1].set_title('Box Plot of Minimal Distance (Body)', size=16)
axes[1].set_xlabel('Pedestrian ID', size=14)
axes[1].set_ylabel('Minimal Distance', size=14)
axes[1].tick_params(axis='x', rotation=45)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by SubjectID and Session to calculate the mean and std minimal distance for each person per session for both datasets
subject_session_stats_face = Face.groupby(['SubjectID', 'Session'])['minimal_distance'].agg(['mean', 'std']).reset_index()
subject_session_stats_face.rename(columns={'mean': 'mean_minimal_distance', 'std': 'std_minimal_distance'}, inplace=True)

subject_session_stats_body = Body.groupby(['SubjectID', 'Session'])['minimal_distance'].agg(['mean', 'std']).reset_index()
subject_session_stats_body.rename(columns={'mean': 'mean_minimal_distance', 'std': 'std_minimal_distance'}, inplace=True)

# Set up the subplots for side-by-side comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot for the Face dataset
sns.lineplot(data=subject_session_stats_face, x='Session', y='mean_minimal_distance', hue='SubjectID', marker='o', ax=axes[0])
axes[0].set_title('Mean Minimal Distance per Person (Faces)', size=16)
axes[0].set_xlabel('Session', size=14)
axes[0].set_ylabel('Mean Minimal Distance', size=14)

# Plot for the Body dataset
sns.lineplot(data=subject_session_stats_body, x='Session', y='mean_minimal_distance', hue='SubjectID', marker='o', ax=axes[1])
axes[1].set_title('Mean Minimal Distance per Person (Body)', size=16)
axes[1].set_xlabel('Session', size=14)
axes[1].set_ylabel('Mean Minimal Distance', size=14)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
sns.scatterplot(data=Face, y='SubjectID',  x='minimal_distance')
# Out:
# <Axes: xlabel='minimal_distance', ylabel='SubjectID'>

# %%
Face.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ped_id  minimal_distance  num_interactions  \
# 0             0           0   46_Sa          7.496148                 1
# 1             1           1  03_Cma          1.606597                 1
# 2             2           2  22_Cma          3.535074                 1
# 3             3           3  19_Cma          2.241916                 1
# 4             4           4   50_Sa          2.402347                 1
#
#    SubjectID  Session Agent_Type
# 0        479        2    Passive
# 1        479        2     Active
# 2        479        2     Active
# 3        479        2     Active
# 4        479        2    Passive
